# %%
import cobra.test
import os
from os.path import join
from cobra.io import read_sbml_model
model = cobra.io.load_json_model(join("RehMBEL1391_sbml_L3V1.json"))

# %%
#model.metabolites

# %%
####Check if it´s glycerin####
model.metabolites.gly_c
model.metabolites.gly_c.elements
###gly_c is glycine
model.metabolites.glyc3p_c
model.metabolites.glyc3p_c
###glyc3p_c is Glycerol 3-phosphate and included in the glycerol pathway
# Out:
# <Metabolite glyc3p_c at 0x245545b7700>

# %%
for metabolite in model.metabolites.query('glycerin', 'name'):
    print(metabolite.name)

# %%
### Check for glycerol
for metabolite in model.metabolites.query('glycerol', 'name'):
    print(metabolite.name)
### No direct glycerol pathway so far
# Out:
# CDP-diacylglycerol
# D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate
# Triacylglycerol
# 1,2-Diacyl-sn-glycerol
# Phosphatidylglycerol
# Glycerophosphoglycerol
# 1-Acyl-sn-glycerol 3-phosphate
# 1-Acylglycerol
# C1-(3-Indolyl)-glycerol 3-phosphate

# %%
from cobra.io import read_sbml_model
from cobra import Reaction, Metabolite, flux_analysis
from cobra.flux_analysis import flux_variability_analysis
import pandas as pd

# %%
### TEST #### 
model.metabolites.h_c
model.metabolites.nadph_c
model.metabolites.nadp_c
model.metabolites.h2o_c
model.metabolites
# Out:
# [<Metabolite zoe_c at 0x24554188fa0>,
#  <Metabolite 3hbz_c at 0x2454d1605e0>,
#  <Metabolite hco3_c at 0x2454d1600d0>,
#  <Metabolite actp_c at 0x2454d1607f0>,
#  <Metabolite glytrna_c at 0x2454d160580>,
#  <Metabolite phaccoa_c at 0x2454d160a00>,
#  <Metabolite 2h3mbzpyr_c at 0x2454d160fd0>,
#  <Metabolite mettrna_c at 0x2454d1608e0>,
#  <Metabolite ugmd_c at 0x2454d160df0>,
#  <Metabolite adprib_c at 0x2454d160130>,
#  <Metabolite nicrnt_c at 0x2454d160640>,
#  <Metabolite selnp_c at 0x24554192a00>,
#  <Metabolite gln__L_c at 0x24554192580>,
#  <Metabolite c170_c at 0x24554192430>,
#  <Metabolite c2ch4cmo_c at 0x245541921f0>,
#  <Metabolite gln__L_e at 0x24554192280>,
#  <Metabolite galctn__D_c at 0x24554192070>,
#  <Metabolite trnaile_c at 0x24554192040>,
#  <Metabolite dctp_c at 0x245541920a0>,
#  <Metabolite hppr_c at 0x245541920d0>,
#  <Metabolite galctn__D_e at 0x24554192100>,
#  <Metabolite ps_cho_c at 0x24554192130>,
#  <Metabolite alac__S_c at 0x24554192160>,
#  <Metabolite im4ac_c at 0x24554343d90>,
#  <Metabolite peamn_c at 0x24554354130>,
#  <Metabolite 2m2ecoa_c at 0x24554354160>,
#  <Metabolite tetdecacid_e at 0x24554354190>,
#  <Metabolite 15dap_e at 0x245543541c0>,
#  <Metabolite 15dap_c at 0x245543541f0>,
#  <Metabolite tetdecacid_c at 0x24554354220>,
#  <Metabolite id3act_c at 0x24554354250>,
#  <Metabolite cinnm_c at 0x24554354280>,
#  <Metabolite gcarmclc_c at 0x245543542b0>,
#  <Metabolite quln_c at 0x245543542e0>,
#  <Metabolite 5ch2hmcs_c at 0x24554354310>,
#  <Metabolite 5a4ic_c at 0x24554354340>,
#  <Metabolite dhf_c at 0x24554354370>,
#  <Metabolite pppi_c at 0x245543543a0>,
#  <Metabolite 5mta_c at 0x245543543d0>,
#  <Metabolite 4hmdn_c at 0x24554354400>,
#  <Metabolite thcys_c at 0x24554354430>,
#  <Metabolite cdpdag_MRSA_c at 0x24554354460>,
#  <Metabolite 3hbz_e at 0x24554354490>,
#  <Metabolite 4faac_c at 0x245543544c0>,
#  <Metabolite 4nph_c at 0x245543544f0>,
#  <Metabolite anthcoa_c at 0x24554354520>,
#  <Metabolite cenchddd_c at 0x24554354550>,
#  <Metabolite 4aphdob_c at 0x24554354580>,
#  <Metabolite fum_c at 0x245543545b0>,
#  <Metabolite amdz_c at 0x245543545e0>,
#  <Metabolite glycolate_e at 0x24554354610>,
#  <Metabolite glycolate_c at 0x24554354640>,
#  <Metabolite acac_e at 0x24554354670>,
#  <Metabolite fum_e at 0x245543546a0>,
#  <Metabolite met__D_e at 0x245543546d0>,
#  <Metabolite acac_c at 0x24554354700>,
#  <Metabolite adrn_c at 0x24554354730>,
#  <Metabolite gam1p_c at 0x24554354760>,
#  <Metabolite ctbtcoa_c at 0x24554354790>,
#  <Metabolite xu5p__D_c at 0x245543547c0>,
#  <Metabolite met__D_c at 0x245543547f0>,
#  <Metabolite trnaphe_c at 0x24554354820>,
#  <Metabolite bglycogen_c at 0x24554354850>,
#  <Metabolite rdmbzi_c at 0x24554354880>,
#  <Metabolite 34dhmald_c at 0x245543548b0>,
#  <Metabolite gmhep17bp_c at 0x245543548e0>,
#  <Metabolite ac_c at 0x24554354910>,
#  <Metabolite 4sulcat_c at 0x24554354940>,
#  <Metabolite ac_e at 0x24554354970>,
#  <Metabolite acala_c at 0x245543549a0>,
#  <Metabolite octadecacid_e at 0x245543549d0>,
#  <Metabolite b2coa_c at 0x24554354a00>,
#  <Metabolite palmACP_c at 0x24554354a30>,
#  <Metabolite pe_cho_c at 0x24554354a60>,
#  <Metabolite octadecacid_c at 0x24554354a90>,
#  <Metabolite sql_c at 0x24554354ac0>,
#  <Metabolite trnaser_c at 0x24554354af0>,
#  <Metabolite pacald_c at 0x24554354b20>,
#  <Metabolite nad_c at 0x24554354b50>,
#  <Metabolite cacac_c at 0x24554354b80>,
#  <Metabolite 3flcmuc_c at 0x24554354bb0>,
#  <Metabolite 2oad_c at 0x24554354be0>,
#  <Metabolite HC00229_c at 0x24554354c10>,
#  <Metabolite 2hhpdd_c at 0x24554354c40>,
#  <Metabolite ptolat_c at 0x24554354c70>,
#  <Metabolite HC00229_e at 0x24554354ca0>,
#  <Metabolite 15gl_c at 0x24554354cd0>,
#  <Metabolite g3ps_c at 0x24554354d00>,
#  <Metabolite ppcoa_c at 0x24554354d30>,
#  <Metabolite 16dh24checc_c at 0x24554354d60>,
#  <Metabolite hmnapth_c at 0x24554354d90>,
#  <Metabolite 2amoeccoa_c at 0x24554354dc0>,
#  <Metabolite micit_c at 0x24554354df0>,
#  <Metabolite dcyt_c at 0x24554354e20>,
#  <Metabolite e4p_c at 0x24554354e50>,
#  <Metabolite dcyt_e at 0x24554354e80>,
#  <Metabolite rmn_e at 0x24554354eb0>,
#  <Metabolite cytd_e at 0x24554354ee0>,
#  <Metabolite c141ACP_c at 0x24554354f10>,
#  <Metabolite rmn_c at 0x24554354f40>,
#  <Metabolite cytd_c at 0x24554354f70>,
#  <Metabolite 4nphp_c at 0x24554354fa0>,
#  <Metabolite 13dpg_c at 0x24554354fd0>,
#  <Metabolite pser_c at 0x24554e01040>,
#  <Metabolite tol4sul_c at 0x24554e01070>,
#  <Metabolite 3hpcoa_c at 0x24554e010a0>,
#  <Metabolite c150ACP_c at 0x24554e010d0>,
#  <Metabolite betald_c at 0x24554e01100>,
#  <Metabolite eig3p_c at 0x24554e01130>,
#  <Metabolite 5apru_c at 0x24554e01160>,
#  <Metabolite dhna_c at 0x24554e01190>,
#  <Metabolite 2h3cbzpyr_c at 0x24554e011c0>,
#  <Metabolite dmpp_c at 0x24554e011f0>,
#  <Metabolite lac__L_c at 0x24554e01220>,
#  <Metabolite crn_c at 0x24554e01250>,
#  <Metabolite LPS_c at 0x24554e01280>,
#  <Metabolite guadbutn_c at 0x24554e012b0>,
#  <Metabolite gtspmd_c at 0x24554e012e0>,
#  <Metabolite lac__L_e at 0x24554e01310>,
#  <Metabolite crn_e at 0x24554e01340>,
#  <Metabolite glu1sa_c at 0x24554e01370>,
#  <Metabolite fol_c at 0x24554e013a0>,
#  <Metabolite g3p_c at 0x24554e013d0>,
#  <Metabolite trnamet_c at 0x24554e01400>,
#  <Metabolite aicar_c at 0x24554e01430>,
#  <Metabolite thm_c at 0x24554e01460>,
#  <Metabolite thm_e at 0x24554e01490>,
#  <Metabolite napth2ms_c at 0x24554e014c0>,
#  <Metabolite cdp4dh6doglc_c at 0x24554e014f0>,
#  <Metabolite 26dchhq_c at 0x24554e01520>,
#  <Metabolite laminoacid_c at 0x24554e01550>,
#  <Metabolite thmpp_c at 0x24554e01580>,
#  <Metabolite 2hba_e at 0x24554e015b0>,
#  <Metabolite 2mp2coa_c at 0x24554e015e0>,
#  <Metabolite 2hba_c at 0x24554e01610>,
#  <Metabolite 2fchdc_c at 0x24554e01640>,
#  <Metabolite 4chphac_c at 0x24554e01670>,
#  <Metabolite sbzcoa_c at 0x24554e016a0>,
#  <Metabolite g3pe_c at 0x24554e016d0>,
#  <Metabolite c161_c at 0x24554e01700>,
#  <Metabolite 24danit_c at 0x24554e01730>,
#  <Metabolite fe2_c at 0x24554e01760>,
#  <Metabolite tchrocat_c at 0x24554e01790>,
#  <Metabolite fe2_e at 0x24554e017c0>,
#  <Metabolite BIOMASS_c at 0x24554e017f0>,
#  <Metabolite phe__L_c at 0x24554e01820>,
#  <Metabolite 25dop_c at 0x24554e01850>,
#  <Metabolite tcynt_c at 0x24554e01880>,
#  <Metabolite cholp_c at 0x24554e018b0>,
#  <Metabolite xylt_c at 0x24554e018e0>,
#  <Metabolite 2aobut_c at 0x24554e01910>,
#  <Metabolite phe__L_e at 0x24554e01940>,
#  <Metabolite trnaleu_c at 0x24554e01970>,
#  <Metabolite mk_c at 0x24554e019a0>,
#  <Metabolite dann_c at 0x24554e019d0>,
#  <Metabolite ggbap_c at 0x24554e01a00>,
#  <Metabolite protmn_c at 0x24554e01a30>,
#  <Metabolite 2pg_c at 0x24554e01a60>,
#  <Metabolite 2pg_e at 0x24554e01a90>,
#  <Metabolite psdp_c at 0x24554e01ac0>,
#  <Metabolite 3hxkynam_c at 0x24554e01af0>,
#  <Metabolite 5hxkyn_c at 0x24554e01b20>,
#  <Metabolite hmb4pp_c at 0x24554e01b50>,
#  <Metabolite g3pi_c at 0x24554e01b80>,
#  <Metabolite 3sulmc_c at 0x24554e01bb0>,
#  <Metabolite 4ampm_c at 0x24554e01be0>,
#  <Metabolite lk2lipiv_c at 0x24554e01c10>,
#  <Metabolite dpcoa_c at 0x24554e01c40>,
#  <Metabolite cchexo_c at 0x24554e01c70>,
#  <Metabolite thbn_c at 0x24554e01ca0>,
#  <Metabolite val__L_c at 0x24554e01cd0>,
#  <Metabolite val__L_e at 0x24554e01d00>,
#  <Metabolite 3aibt_c at 0x24554e01d30>,
#  <Metabolite cyst__L_c at 0x24554e01d60>,
#  <Metabolite d3dg_c at 0x24554e01d90>,
#  <Metabolite pmcoa_c at 0x24554e01dc0>,
#  <Metabolite valtrna_c at 0x24554e01df0>,
#  <Metabolite succoa_c at 0x24554e01e20>,
#  <Metabolite trnahis_c at 0x24554e01e50>,
#  <Metabolite RNA_c at 0x24554e01e80>,
#  <Metabolite thymd_c at 0x24554e01eb0>,
#  <Metabolite pbng_c at 0x24554e01ee0>,
#  <Metabolite 5fthf_c at 0x24554e01f10>,
#  <Metabolite dhpt_c at 0x24554e01f40>,
#  <Metabolite 56dthm_c at 0x24554e01f70>,
#  <Metabolite thymd_e at 0x24554e01fa0>,
#  <Metabolite mlzac_c at 0x24554e01fd0>,
#  <Metabolite ala_B_c at 0x24554e0b040>,
#  <Metabolite fadh2_c at 0x24554e0b070>,
#  <Metabolite 3psme_c at 0x24554e0b0a0>,
#  <Metabolite im4act_c at 0x24554e0b0d0>,
#  <Metabolite 2h2hpd_c at 0x24554e0b100>,
#  <Metabolite damp_c at 0x24554e0b130>,
#  <Metabolite dadp_c at 0x24554e0b160>,
#  <Metabolite ala__L_c at 0x24554e0b190>,
#  <Metabolite seasmet_c at 0x24554e0b1c0>,
#  <Metabolite ala__L_e at 0x24554e0b1f0>,
#  <Metabolite udpgal_c at 0x24554e0b220>,
#  <Metabolite Lcyst_c at 0x24554e0b250>,
#  <Metabolite gcoa_c at 0x24554e0b280>,
#  <Metabolite 3flrcatech_c at 0x24554e0b2b0>,
#  <Metabolite op4en_c at 0x24554e0b2e0>,
#  <Metabolite hccho_c at 0x24554e0b310>,
#  <Metabolite gagcya_c at 0x24554e0b340>,
#  <Metabolite ppp9_c at 0x24554e0b370>,
#  <Metabolite 46dhoxquin_c at 0x24554e0b3a0>,
#  <Metabolite 3ophb_c at 0x24554e0b3d0>,
#  <Metabolite dhcinnm_c at 0x24554e0b400>,
#  <Metabolite hcys__L_c at 0x24554e0b430>,
#  <Metabolite 2hchd_c at 0x24554e0b460>,
#  <Metabolite 34dhoxpeg_c at 0x24554e0b490>,
#  <Metabolite trnatyr_c at 0x24554e0b4c0>,
#  <Metabolite 5m3o4hcoa_c at 0x24554e0b4f0>,
#  <Metabolite pran_c at 0x24554e0b520>,
#  <Metabolite hcyst_c at 0x24554e0b550>,
#  <Metabolite protrna_c at 0x24554e0b580>,
#  <Metabolite cchlam_c at 0x24554e0b5b0>,
#  <Metabolite 3hcinnm_e at 0x24554e0b5e0>,
#  <Metabolite 3hcinnm_c at 0x24554e0b610>,
#  <Metabolite f1p_c at 0x24554e0b640>,
#  <Metabolite q8_c at 0x24554e0b670>,
#  <Metabolite cechddd_c at 0x24554e0b6a0>,
#  <Metabolite prbamp_c at 0x24554e0b6d0>,
#  <Metabolite skm_c at 0x24554e0b700>,
#  <Metabolite glutrna_c at 0x24554e0b730>,
#  <Metabolite so3_c at 0x24554e0b760>,
#  <Metabolite tg160_c at 0x24554e0b790>,
#  <Metabolite didp_c at 0x24554e0b7c0>,
#  <Metabolite pc_c at 0x24554e0b7f0>,
#  <Metabolite Largn_c at 0x24554e0b820>,
#  <Metabolite styrene_c at 0x24554e0b850>,
#  <Metabolite prpp_c at 0x24554e0b880>,
#  <Metabolite 12dgr_TB_c at 0x24554e0b8b0>,
#  <Metabolite bf26p_c at 0x24554e0b8e0>,
#  <Metabolite pydx_c at 0x24554e0b910>,
#  <Metabolite mg2_c at 0x24554e0b940>,
#  <Metabolite hmbil_c at 0x24554e0b970>,
#  <Metabolite mg2_e at 0x24554e0b9a0>,
#  <Metabolite apoACP_c at 0x24554e0b9d0>,
#  <Metabolite bf2p_c at 0x24554e0ba00>,
#  <Metabolite 4h2ohep_c at 0x24554e0ba30>,
#  <Metabolite 12anthcd_c at 0x24554e0ba60>,
#  <Metabolite pg_c at 0x24554e0ba90>,
#  <Metabolite 5mtglu_c at 0x24554e0bac0>,
#  <Metabolite mnapth_c at 0x24554e0baf0>,
#  <Metabolite idon__L_e at 0x24554e0bb20>,
#  <Metabolite idon__L_c at 0x24554e0bb50>,
#  <Metabolite npthld_c at 0x24554e0bb80>,
#  <Metabolite amob_c at 0x24554e0bbb0>,
#  <Metabolite ppacp_c at 0x24554e0bbe0>,
#  <Metabolite up4g_c at 0x24554e0bc10>,
#  <Metabolite aa_c at 0x24554e0bc40>,
#  <Metabolite 4c2hmucsah_c at 0x24554e0bc70>,
#  <Metabolite thdp_c at 0x24554e0bca0>,
#  <Metabolite gbbtn_c at 0x24554e0bcd0>,
#  <Metabolite adocbip_c at 0x24554e0bd00>,
#  <Metabolite 3b1a_c at 0x24554e0bd30>,
#  <Metabolite u1car_c at 0x24554e0bd60>,
#  <Metabolite gbbtn_e at 0x24554e0bd90>,
#  <Metabolite sulald_c at 0x24554e0bdc0>,
#  <Metabolite prbatp_c at 0x24554e0bdf0>,
#  <Metabolite 2dmmq8_c at 0x24554e0be20>,
#  <Metabolite trnagly_c at 0x24554e0be50>,
#  <Metabolite gallate_c at 0x24554e0be80>,
#  <Metabolite trnapro_c at 0x24554e0beb0>,
#  <Metabolite cit_e at 0x24554e0bee0>,
#  <Metabolite iletrna_c at 0x24554e0bf10>,
#  <Metabolite cit_c at 0x24554e0bf40>,
#  <Metabolite caiz_c at 0x24554e0bf70>,
#  <Metabolite s2mbdlipo_c at 0x24554e0bfa0>,
#  <Metabolite 2a3cms_c at 0x24554e0bfd0>,
#  <Metabolite fprica_c at 0x24554e14040>,
#  <Metabolite 6pgc_c at 0x24554e14070>,
#  <Metabolite 5aprbu_c at 0x24554e140a0>,
#  <Metabolite 2naptha_c at 0x24554e140d0>,
#  <Metabolite 3hpp_c at 0x24554e14100>,
#  <Metabolite catechol_c at 0x24554e14130>,
#  <Metabolite dad_2_c at 0x24554e14160>,
#  <Metabolite dad_2_e at 0x24554e14190>,
#  <Metabolite sarcs_c at 0x24554e141c0>,
#  <Metabolite catechol_e at 0x24554e141f0>,
#  <Metabolite trnaasp_c at 0x24554e14220>,
#  <Metabolite msalc4_c at 0x24554e14250>,
#  <Metabolite ahser_c at 0x24554e14280>,
#  <Metabolite shser_c at 0x24554e142b0>,
#  <Metabolite nitbz_c at 0x24554e142e0>,
#  <Metabolite nicatol_c at 0x24554e14310>,
#  <Metabolite 4c2o4pent_c at 0x24554e14340>,
#  <Metabolite dhid_c at 0x24554e14370>,
#  <Metabolite gtp_c at 0x24554e143a0>,
#  <Metabolite kdo8p_c at 0x24554e143d0>,
#  <Metabolite adn_e at 0x24554e14400>,
#  <Metabolite u23ga_c at 0x24554e14430>,
#  <Metabolite g3pg_c at 0x24554e14460>,
#  <Metabolite adn_c at 0x24554e14490>,
#  <Metabolite bz_c at 0x24554e144c0>,
#  <Metabolite glu__L_e at 0x24554e144f0>,
#  <Metabolite aspsa_c at 0x24554e14520>,
#  <Metabolite glu__L_c at 0x24554e14550>,
#  <Metabolite 3o4mp_c at 0x24554e14580>,
#  <Metabolite bz_e at 0x24554e145b0>,
#  <Metabolite grdp_c at 0x24554e145e0>,
#  <Metabolite mm_c at 0x24554e14610>,
#  <Metabolite rhcys_c at 0x24554e14640>,
#  <Metabolite gly_c at 0x24554e14670>,
#  <Metabolite 4ethp_c at 0x24554e146a0>,
#  <Metabolite c161ACP_c at 0x24554e146d0>,
#  <Metabolite ian_c at 0x24554e14700>,
#  <Metabolite 2omhmbl_c at 0x24554e14730>,
#  <Metabolite HC01712_c at 0x24554e14760>,
#  <Metabolite 2omph_c at 0x24554e14790>,
#  <Metabolite mi_c at 0x24554e147c0>,
#  <Metabolite gly_e at 0x24554e147f0>,
#  <Metabolite 2e5mhdcoa_c at 0x24554e14820>,
#  <Metabolite Sfglutth_c at 0x24554e14850>,
#  <Metabolite 1ag3p_c at 0x24554e14880>,
#  <Metabolite ethap_c at 0x24554e148b0>,
#  <Metabolite man1p_c at 0x24554e148e0>,
#  <Metabolite 5fmuclac_c at 0x24554e14910>,
#  <Metabolite trnaval_c at 0x24554e14940>,
#  <Metabolite rbflvrd_c at 0x24554e14970>,
#  <Metabolite thmmp_c at 0x24554e149a0>,
#  <Metabolite pyam5p_c at 0x24554e149d0>,
#  <Metabolite pi_e at 0x24554e14a00>,
#  <Metabolite gsn_e at 0x24554e14a30>,
#  <Metabolite ctbt_c at 0x24554e14a60>,
#  <Metabolite urdglyc_c at 0x24554e14a90>,
#  <Metabolite gsn_c at 0x24554e14ac0>,
#  <Metabolite i3aa_c at 0x24554e14af0>,
#  <Metabolite phenol_e at 0x24554e14b20>,
#  <Metabolite phenol_c at 0x24554e14b50>,
#  <Metabolite tchccm_c at 0x24554e14b80>,
#  <Metabolite cchccoa_c at 0x24554e14bb0>,
#  <Metabolite n2o_c at 0x24554e14be0>,
#  <Metabolite dopa_c at 0x24554e14c10>,
#  <Metabolite 3chccm_c at 0x24554e14c40>,
#  <Metabolite gl1coa_c at 0x24554e14c70>,
#  <Metabolite pi_c at 0x24554e14ca0>,
#  <Metabolite 23dhmp_c at 0x24554e14cd0>,
#  <Metabolite tsul_e at 0x24554e14d00>,
#  <Metabolite acmanap_c at 0x24554e14d30>,
#  <Metabolite acgam6p_c at 0x24554e14d60>,
#  <Metabolite c171ACP_c at 0x24554e14d90>,
#  <Metabolite tsul_c at 0x24554e14dc0>,
#  <Metabolite crtn_c at 0x24554e14df0>,
#  <Metabolite malcoa_c at 0x24554e14e20>,
#  <Metabolite l1p3h5c_c at 0x24554e14e50>,
#  <Metabolite ugmda_c at 0x24554e14e80>,
#  <Metabolite 4fmuclac_c at 0x24554e14eb0>,
#  <Metabolite dhptn_c at 0x24554e14ee0>,
#  <Metabolite aamppn_c at 0x24554e14f10>,
#  <Metabolite n2_c at 0x24554e14f40>,
#  <Metabolite hpmhmbq_c at 0x24554e14f70>,
#  <Metabolite cobalt2_e at 0x24554e14fa0>,
#  <Metabolite cobalt2_c at 0x24554e14fd0>,
#  <Metabolite adocbi_c at 0x24554e1f040>,
#  <Metabolite acetol_c at 0x24554e1f070>,
#  <Metabolite asntrna_c at 0x24554e1f0a0>,
#  <Metabolite slnt_c at 0x24554e1f0d0>,
#  <Metabolite 3oppcoa_c at 0x24554e1f100>,
#  <Metabolite dhtolen_c at 0x24554e1f130>,
#  <Metabolite cys__L_c at 0x24554e1f160>,
#  <Metabolite uppg3_c at 0x24554e1f190>,
#  <Metabolite 5cohe_c at 0x24554e1f1c0>,
#  <Metabolite tartr_c at 0x24554e1f1f0>,
#  <Metabolite 2c4h6at_c at 0x24554e1f220>,
#  <Metabolite hppp_c at 0x24554e1f250>,
#  <Metabolite adipcoa_c at 0x24554e1f280>,
#  <Metabolite tartr_e at 0x24554e1f2b0>,
#  <Metabolite uppg1_c at 0x24554e1f2e0>,
#  <Metabolite maltpt_e at 0x24554e1f310>,
#  <Metabolite trnalys_c at 0x24554e1f340>,
#  <Metabolite oaa_c at 0x24554e1f370>,
#  <Metabolite cdpetn_c at 0x24554e1f3a0>,
#  <Metabolite r3rhbb_c at 0x24554e1f3d0>,
#  <Metabolite cys__L_e at 0x24554e1f400>,
#  <Metabolite trnathr_c at 0x24554e1f430>,
#  <Metabolite pyr_e at 0x24554e1f460>,
#  <Metabolite 2kchccoa_c at 0x24554e1f490>,
#  <Metabolite cpppg1_c at 0x24554e1f4c0>,
#  <Metabolite citr__L_c at 0x24554e1f4f0>,
#  <Metabolite maltpt_c at 0x24554e1f520>,
#  <Metabolite s7p_c at 0x24554e1f550>,
#  <Metabolite pyr_c at 0x24554e1f580>,
#  <Metabolite pheacnit_c at 0x24554e1f5b0>,
#  <Metabolite uaccg_c at 0x24554e1f5e0>,
#  <Metabolite idlac_c at 0x24554e1f610>,
#  <Metabolite icit_c at 0x24554e1f640>,
#  <Metabolite duri_e at 0x24554e1f670>,
#  <Metabolite fad_c at 0x24554e1f6a0>,
#  <Metabolite icit_e at 0x24554e1f6d0>,
#  <Metabolite uaagtmda_c at 0x24554e1f700>,
#  <Metabolite gua_e at 0x24554e1f730>,
#  <Metabolite 4mcat_c at 0x24554e1f760>,
#  <Metabolite carbs_c at 0x24554e1f790>,
#  <Metabolite 3cresol_c at 0x24554e1f7c0>,
#  <Metabolite duri_c at 0x24554e1f7f0>,
#  <Metabolite gua_c at 0x24554e1f820>,
#  <Metabolite homogen_c at 0x24554e1f850>,
#  <Metabolite CARBO_c at 0x24554e1f880>,
#  <Metabolite 4maac_c at 0x24554e1f8b0>,
#  <Metabolite pa_c at 0x24554e1f8e0>,
#  <Metabolite r3hbn2_c at 0x24554e1f910>,
#  <Metabolite galt1p_c at 0x24554e1f940>,
#  <Metabolite s2mpdlipo_c at 0x24554e1f970>,
#  <Metabolite napmsccoa_c at 0x24554e1f9a0>,
#  <Metabolite hcchccoa_c at 0x24554e1f9d0>,
#  <Metabolite fdp_c at 0x24554e1fa00>,
#  <Metabolite hpyr_c at 0x24554e1fa30>,
#  <Metabolite lipa_c at 0x24554e1fa60>,
#  <Metabolite trnagln_c at 0x24554e1fa90>,
#  <Metabolite r5p_c at 0x24554e1fac0>,
#  <Metabolite lipoe_c at 0x24554e1faf0>,
#  <Metabolite acgam_e at 0x24554e1fb20>,
#  <Metabolite spmd_e at 0x24554e1fb50>,
#  <Metabolite 3oxoadp_c at 0x24554e1fb80>,
#  <Metabolite butanal_c at 0x24554e1fbb0>,
#  <Metabolite amppo_c at 0x24554e1fbe0>,
#  <Metabolite acglu_c at 0x24554e1fc10>,
#  <Metabolite seld_c at 0x24554e1fc40>,
#  <Metabolite 5mcsn_c at 0x24554e1fc70>,
#  <Metabolite bzonit_c at 0x24554e1fca0>,
#  <Metabolite hemeO_c at 0x24554e1fcd0>,
#  <Metabolite aniline_c at 0x24554e1fd00>,
#  <Metabolite dhnpt_c at 0x24554e1fd30>,
#  <Metabolite norad_c at 0x24554e1fd60>,
#  <Metabolite csn_c at 0x24554e1fd90>,
#  <Metabolite 2flcmuc_c at 0x24554e1fdc0>,
#  <Metabolite salc_c at 0x24554e1fdf0>,
#  <Metabolite csn_e at 0x24554e1fe20>,
#  <Metabolite hemeA_c at 0x24554e1fe50>,
#  <Metabolite 4hpro_c at 0x24554e1fe80>,
#  <Metabolite s_c at 0x24554e1feb0>,
#  <Metabolite dhnapthsul_c at 0x24554e1fee0>,
#  <Metabolite omaenol_c at 0x24554e1ff10>,
#  <Metabolite opp_c at 0x24554e1ff40>,
#  <Metabolite uamag_c at 0x24554e1ff70>,
#  <Metabolite gam6p_c at 0x24554e1ffa0>,
#  <Metabolite 4fchcd_c at 0x24554e1ffd0>,
#  <Metabolite cl_c at 0x24554599040>,
#  <Metabolite mtolat_c at 0x24554599070>,
#  <Metabolite mlt_c at 0x245545990a0>,
#  <Metabolite cysgly_c at 0x245545990d0>,
#  <Metabolite cl_e at 0x24554599100>,
#  <Metabolite HC01522_c at 0x24554599130>,
#  <Metabolite selcyst_c at 0x24554599160>,
#  <Metabolite adip_e at 0x24554599190>,
#  <Metabolite hom__L_c at 0x245545991c0>,
#  <Metabolite adip_c at 0x245545991f0>,
#  <Metabolite isoppam_c at 0x24554599220>,
#  <Metabolite urocan_e at 0x24554599250>,
#  <Metabolite ump_c at 0x24554599280>,
#  <Metabolite namd_c at 0x245545992b0>,
#  <Metabolite 2ommb_c at 0x245545992e0>,
#  <Metabolite L_dpchrm_c at 0x24554599310>,
#  <Metabolite mlt_e at 0x24554599340>,
#  <Metabolite urocan_c at 0x24554599370>,
#  <Metabolite 24dab_c at 0x245545993a0>,
#  <Metabolite argtrna_c at 0x245545993d0>,
#  <Metabolite chhmsald_c at 0x24554599400>,
#  <Metabolite lystrna_c at 0x24554599430>,
#  <Metabolite cn_c at 0x24554599460>,
#  <Metabolite thrtrna_c at 0x24554599490>,
#  <Metabolite 2mnapth_c at 0x245545994c0>,
#  <Metabolite 3mccoa_c at 0x245545994f0>,
#  <Metabolite pphn_c at 0x24554599520>,
#  <Metabolite lprot_c at 0x24554599550>,
#  <Metabolite gam_e at 0x24554599580>,
#  <Metabolite dttp_c at 0x245545995b0>,
#  <Metabolite h2_c at 0x245545995e0>,
#  <Metabolite k_e at 0x24554599610>,
#  <Metabolite mclact_e at 0x24554599640>,
#  <Metabolite phb_e at 0x24554599670>,
#  <Metabolite k_c at 0x245545996a0>,
#  <Metabolite c151_c at 0x245545996d0>,
#  <Metabolite galt_e at 0x24554599700>,
#  <Metabolite asp__L_e at 0x24554599730>,
#  <Metabolite phb_c at 0x24554599760>,
#  <Metabolite asp__L_c at 0x24554599790>,
#  <Metabolite galt_c at 0x245545997c0>,
#  <Metabolite malth_e at 0x245545997f0>,
#  <Metabolite mclact_c at 0x24554599820>,
#  <Metabolite dgsn_c at 0x24554599850>,
#  <Metabolite malth_c at 0x24554599880>,
#  <Metabolite dgsn_e at 0x245545998b0>,
#  <Metabolite kdo_c at 0x245545998e0>,
#  <Metabolite bapa_c at 0x24554599910>,
#  <Metabolite dtdpglu_c at 0x24554599940>,
#  <Metabolite 4r5au_c at 0x24554599970>,
#  <Metabolite aacald_c at 0x245545999a0>,
#  <Metabolite guadbut_c at 0x245545999d0>,
#  <Metabolite 3c2hmp_c at 0x24554599a00>,
#  <Metabolite udcpdp_c at 0x24554599a30>,
#  <Metabolite alltt_c at 0x24554599a60>,
#  <Metabolite 2me4p_c at 0x24554599a90>,
#  <Metabolite c4cmbo_c at 0x24554599ac0>,
#  <Metabolite cbl1_e at 0x24554599af0>,
#  <Metabolite c3chroc_c at 0x24554599b20>,
#  <Metabolite met__L_e at 0x24554599b50>,
#  <Metabolite phacgly_c at 0x24554599b80>,
#  <Metabolite 3mop_c at 0x24554599bb0>,
#  <Metabolite cbl1_c at 0x24554599be0>,
#  <Metabolite mmcoa__S_c at 0x24554599c10>,
#  <Metabolite uri_c at 0x24554599c40>,
#  <Metabolite met__L_c at 0x24554599c70>,
#  <Metabolite 12dhflu_c at 0x24554599ca0>,
#  <Metabolite 4hoxoh_c at 0x24554599cd0>,
#  <Metabolite amet_c at 0x24554599d00>,
#  <Metabolite hop_c at 0x24554599d30>,
#  <Metabolite kdolipid4_c at 0x24554599d60>,
#  <Metabolite 5fchdc_c at 0x24554599d90>,
#  <Metabolite cbp_c at 0x24554599dc0>,
#  <Metabolite flald_c at 0x24554599df0>,
#  <Metabolite forant_c at 0x24554599e20>,
#  <Metabolite fe3_e at 0x24554599e50>,
#  <Metabolite 2h4hmbnpyr_c at 0x24554599e80>,
#  <Metabolite cynt_e at 0x24554599eb0>,
#  <Metabolite cyanr_c at 0x24554599ee0>,
#  <Metabolite 5mh4ecoa_c at 0x24554599f10>,
#  <Metabolite fe3_c at 0x24554599f40>,
#  <Metabolite cynt_c at 0x24554599f70>,
#  <Metabolite uri_e at 0x24554599fa0>,
#  <Metabolite 5prdmbz_c at 0x24554599fd0>,
#  <Metabolite idp_c at 0x245545a2040>,
#  <Metabolite ckdo_c at 0x245545a2070>,
#  <Metabolite prlp_c at 0x245545a20a0>,
#  <Metabolite itcn_c at 0x245545a20d0>,
#  <Metabolite lipidA_c at 0x245545a2100>,
#  <Metabolite 2hohphd_c at 0x245545a2130>,
#  <Metabolite hpimcoa_c at 0x245545a2160>,
#  <Metabolite c120_c at 0x245545a2190>,
#  <Metabolite ammld_c at 0x245545a21c0>,
#  <Metabolite chcatol_c at 0x245545a21f0>,
#  <Metabolite succ_e at 0x245545a2220>,
#  <Metabolite succ_c at 0x245545a2250>,
#  <Metabolite itp_c at 0x245545a2280>,
#  <Metabolite 4mhetz_c at 0x245545a22b0>,
#  <Metabolite 3hmrsACP_c at 0x245545a22e0>,
#  <Metabolite 3vcat_c at 0x245545a2310>,
#  <Metabolite 4hbt_e at 0x245545a2340>,
#  <Metabolite cdpmde_c at 0x245545a2370>,
#  <Metabolite 4hbt_c at 0x245545a23a0>,
#  <Metabolite napomsuccoa_c at 0x245545a23d0>,
#  <Metabolite glcur_c at 0x245545a2400>,
#  <Metabolite ahcys_c at 0x245545a2430>,
#  <Metabolite 2dhp_c at 0x245545a2460>,
#  <Metabolite aptrc_c at 0x245545a2490>,
#  <Metabolite 12ppd__R_c at 0x245545a24c0>,
#  <Metabolite Nforglu_c at 0x245545a24f0>,
#  <Metabolite glcur_e at 0x245545a2520>,
#  <Metabolite sbt__D_c at 0x245545a2550>,
#  <Metabolite sbt__D_e at 0x245545a2580>,
#  <Metabolite 6hcecoa_c at 0x245545a25b0>,
#  <Metabolite ribflav_c at 0x245545a25e0>,
#  <Metabolite 3h2napth_c at 0x245545a2610>,
#  <Metabolite 4ppan_c at 0x245545a2640>,
#  <Metabolite acald_c at 0x245545a2670>,
#  <Metabolite ascb6p_c at 0x245545a26a0>,
#  <Metabolite acald_e at 0x245545a26d0>,
#  <Metabolite tre_e at 0x245545a2700>,
#  <Metabolite dcamp_c at 0x245545a2730>,
#  <Metabolite c3chp_c at 0x245545a2760>,
#  <Metabolite selmeth_c at 0x245545a2790>,
#  <Metabolite spmd_c at 0x245545a27c0>,
#  <Metabolite tre_c at 0x245545a27f0>,
#  <Metabolite nadh_c at 0x245545a2820>,
#  <Metabolite kdpg_c at 0x245545a2850>,
#  <Metabolite gensa_c at 0x245545a2880>,
#  <Metabolite gensa_e at 0x245545a28b0>,
#  <Metabolite ddm_c at 0x245545a28e0>,
#  <Metabolite acgam1p_c at 0x245545a2910>,
#  <Metabolite no2_e at 0x245545a2940>,
#  <Metabolite urea_e at 0x245545a2970>,
#  <Metabolite 4aabut_c at 0x245545a29a0>,
#  <Metabolite no2_c at 0x245545a29d0>,
#  <Metabolite 246tchph_c at 0x245545a2a00>,
#  <Metabolite 6fchdc_c at 0x245545a2a30>,
#  <Metabolite PHOSPHOLIPID_c at 0x245545a2a60>,
#  <Metabolite 3mox4hpac_c at 0x245545a2a90>,
#  <Metabolite leutrna_c at 0x245545a2ac0>,
#  <Metabolite 2dr1p_c at 0x245545a2af0>,
#  <Metabolite pythp_c at 0x245545a2b20>,
#  <Metabolite sbt6p_c at 0x245545a2b50>,
#  <Metabolite glc__D_c at 0x245545a2b80>,
#  <Metabolite agl_c at 0x245545a2bb0>,
#  <Metabolite urea_c at 0x245545a2be0>,
#  <Metabolite acser_c at 0x245545a2c10>,
#  <Metabolite 2dhglcn6p_c at 0x245545a2c40>,
#  <Metabolite pppg9_c at 0x245545a2c70>,
#  <Metabolite 4hpheacoa_c at 0x245545a2ca0>,
#  <Metabolite ht5p_c at 0x245545a2cd0>,
#  <Metabolite scl_c at 0x245545a2d00>,
#  <Metabolite pheth910o_c at 0x245545a2d30>,
#  <Metabolite ade_e at 0x245545a2d60>,
#  <Metabolite 2hohphod_c at 0x245545a2d90>,
#  <Metabolite flac_c at 0x245545a2dc0>,
#  <Metabolite ade_c at 0x245545a2df0>,
#  <Metabolite hsulpob_c at 0x245545a2e20>,
#  <Metabolite gp4g_c at 0x245545a2e50>,
#  <Metabolite dudp_c at 0x245545a2e80>,
#  <Metabolite meli_c at 0x245545a2eb0>,
#  <Metabolite arbt_c at 0x245545a2ee0>,
#  <Metabolite meli_e at 0x245545a2f10>,
#  <Metabolite z4hphea_c at 0x245545a2f40>,
#  <Metabolite propen_c at 0x245545a2f70>,
#  <Metabolite ura_c at 0x245545a2fa0>,
#  <Metabolite ascb__L_e at 0x245545a2fd0>,
#  <Metabolite acACP_c at 0x245545ad040>,
#  <Metabolite dad_5_c at 0x245545ad070>,
#  <Metabolite 22bhpp_c at 0x245545ad0a0>,
#  <Metabolite ura_e at 0x245545ad0d0>,
#  <Metabolite pnpq_c at 0x245545ad100>,
#  <Metabolite gdpddman_c at 0x245545ad130>,
#  <Metabolite anthr910d_c at 0x245545ad160>,
#  <Metabolite glntrna_c at 0x245545ad190>,
#  <Metabolite 4hglusa_c at 0x245545ad1c0>,
#  <Metabolite gal_c at 0x245545ad1f0>,
#  <Metabolite tym_c at 0x245545ad220>,
#  <Metabolite uaagmda_c at 0x245545ad250>,
#  <Metabolite asn__L_e at 0x245545ad280>,
#  <Metabolite 2mac_c at 0x245545ad2b0>,
#  <Metabolite sl26da_c at 0x245545ad2e0>,
#  <Metabolite asn__L_c at 0x245545ad310>,
#  <Metabolite 6hidlac_c at 0x245545ad340>,
#  <Metabolite 6hnld_c at 0x245545ad370>,
#  <Metabolite iasp_c at 0x245545ad3a0>,
#  <Metabolite formt_c at 0x245545ad3d0>,
#  <Metabolite 4abutn_c at 0x245545ad400>,
#  <Metabolite hbzal_c at 0x245545ad430>,
#  <Metabolite methf_c at 0x245545ad460>,
#  <Metabolite phentrc_c at 0x245545ad490>,
#  <Metabolite pap_c at 0x245545ad4c0>,
#  <Metabolite pep_c at 0x245545ad4f0>,
#  <Metabolite xp4g_c at 0x245545ad520>,
#  <Metabolite 14hpeth_c at 0x245545ad550>,
#  <Metabolite altrn_c at 0x245545ad580>,
#  <Metabolite ipdp_c at 0x245545ad5b0>,
#  <Metabolite uamr_c at 0x245545ad5e0>,
#  <Metabolite gdpmann_c at 0x245545ad610>,
#  <Metabolite nicrns_c at 0x245545ad640>,
#  <Metabolite 4obtc_c at 0x245545ad670>,
#  <Metabolite glycogen_c at 0x245545ad6a0>,
#  <Metabolite histd_c at 0x245545ad6d0>,
#  <Metabolite his__L_e at 0x245545ad700>,
#  <Metabolite his__L_c at 0x245545ad730>,
#  <Metabolite g6p_c at 0x245545ad760>,
#  <Metabolite acg5sa_c at 0x245545ad790>,
#  <Metabolite pram_c at 0x245545ad7c0>,
#  <Metabolite 6hhn_c at 0x245545ad7f0>,
#  <Metabolite trptrna_c at 0x245545ad820>,
#  <Metabolite t3chc_c at 0x245545ad850>,
#  <Metabolite e3mmal_c at 0x245545ad880>,
#  <Metabolite 3mob_c at 0x245545ad8b0>,
#  <Metabolite g6p_e at 0x245545ad8e0>,
#  <Metabolite hochphhd_c at 0x245545ad910>,
#  <Metabolite 1btol_c at 0x245545ad940>,
#  <Metabolite 1btol_e at 0x245545ad970>,
#  <Metabolite ins_e at 0x245545ad9a0>,
#  <Metabolite ins_c at 0x245545ad9d0>,
#  <Metabolite oxadpcoa_c at 0x245545ada00>,
#  <Metabolite dmlz_c at 0x245545ada30>,
#  <Metabolite glu5sa_c at 0x245545ada60>,
#  <Metabolite phetrna_c at 0x245545ada90>,
#  <Metabolite pppn_e at 0x245545adac0>,
#  <Metabolite 23doddt_c at 0x245545adaf0>,
#  <Metabolite pppn_c at 0x245545adb20>,
#  <Metabolite hpheac_c at 0x245545adb50>,
#  <Metabolite ala__D_c at 0x245545adb80>,
#  <Metabolite 2mahmp_c at 0x245545adbb0>,
#  <Metabolite ala__D_e at 0x245545adbe0>,
#  <Metabolite omcmc_c at 0x245545adc10>,
#  <Metabolite c34dhphe_c at 0x245545adc40>,
#  <Metabolite din_e at 0x245545adc70>,
#  <Metabolite c171_c at 0x245545adca0>,
#  <Metabolite grxox_c at 0x245545adcd0>,
#  <Metabolite din_c at 0x245545add00>,
#  <Metabolite acmana_e at 0x245545add30>,
#  <Metabolite butn_c at 0x245545add60>,
#  <Metabolite butn_e at 0x245545add90>,
#  <Metabolite 2hmc_c at 0x245545addc0>,
#  <Metabolite udpacgal_c at 0x245545addf0>,
#  <Metabolite ccppccoa_c at 0x245545ade20>,
#  <Metabolite adlipo_c at 0x245545ade50>,
#  <Metabolite mlttr_c at 0x245545ade80>,
#  <Metabolite u3aga_c at 0x245545adeb0>,
#  <Metabolite mlttr_e at 0x245545adee0>,
#  <Metabolite acmana_c at 0x245545adf10>,
#  <Metabolite 4adcho_c at 0x245545adf40>,
#  <Metabolite aps_c at 0x245545adf70>,
#  <Metabolite acha_c at 0x245545adfa0>,
#  <Metabolite hcl_c at 0x245545adfd0>,
#  <Metabolite accoa_c at 0x245545b7040>,
#  <Metabolite tag6p__D_c at 0x245545b7070>,
#  <Metabolite agdpcbi_c at 0x245545b70a0>,
#  <Metabolite 8aonn_c at 0x245545b70d0>,
#  <Metabolite gthrd_c at 0x245545b7100>,
#  <Metabolite dtdp4d6dm_c at 0x245545b7130>,
#  <Metabolite 12ppd__S_c at 0x245545b7160>,
#  <Metabolite paps_c at 0x245545b7190>,
#  <Metabolite 12ppd__S_e at 0x245545b71c0>,
#  <Metabolite 1pyr5c_c at 0x245545b71f0>,
#  <Metabolite 2obut_c at 0x245545b7220>,
#  <Metabolite 2obut_e at 0x245545b7250>,
#  <Metabolite 3aib_c at 0x245545b7280>,
#  <Metabolite dchrooe_c at 0x245545b72b0>,
#  <Metabolite dtdpgal_c at 0x245545b72e0>,
#  <Metabolite glyc__R_c at 0x245545b7310>,
#  <Metabolite so4_c at 0x245545b7340>,
#  <Metabolite so4_e at 0x245545b7370>,
#  <Metabolite 3moxtyr_c at 0x245545b73a0>,
#  <Metabolite 2napald_c at 0x245545b73d0>,
#  <Metabolite coadip_c at 0x245545b7400>,
#  <Metabolite thf_c at 0x245545b7430>,
#  <Metabolite nac_e at 0x245545b7460>,
#  <Metabolite ile__L_c at 0x245545b7490>,
#  <Metabolite dtdprmn_c at 0x245545b74c0>,
#  <Metabolite ile__L_e at 0x245545b74f0>,
#  <Metabolite 4hthr_c at 0x245545b7520>,
#  <Metabolite 3c4mop_c at 0x245545b7550>,
#  <Metabolite dchdchche_c at 0x245545b7580>,
#  <Metabolite utp_c at 0x245545b75b0>,
#  <Metabolite nac_c at 0x245545b75e0>,
#  <Metabolite 3chroald_c at 0x245545b7610>,
#  <Metabolite 5hxkynam_c at 0x245545b7640>,
#  <Metabolite r15bp_c at 0x245545b7670>,
#  <Metabolite hxsp_c at 0x245545b76a0>,
#  <Metabolite alatrna_c at 0x245545b76d0>,
#  <Metabolite glyc3p_c at 0x245545b7700>,
#  <Metabolite glyc3p_e at 0x245545b7730>,
#  <Metabolite ccpam_c at 0x245545b7760>,
#  <Metabolite dnad_c at 0x245545b7790>,
#  <Metabolite 3but_c at 0x245545b77c0>,
#  <Metabolite adphep_LD_c at 0x245545b77f0>,
#  <Metabolite ap4a_c at 0x245545b7820>,
#  <Metabolite benzcoa_c at 0x245545b7850>,
#  <Metabolite 4hmsial_c at 0x245545b7880>,
#  <Metabolite hf_c at 0x245545b78b0>,
#  <Metabolite prfp_c at 0x245545b78e0>,
#  <Metabolite 10fthf_c at 0x245545b7910>,
#  <Metabolite 3hib_c at 0x245545b7940>,
#  <Metabolite 3hmcat_c at 0x245545b7970>,
#  <Metabolite 1h2nap_c at 0x245545b79a0>,
#  <Metabolite 26dap_LL_c at 0x245545b79d0>,
#  <Metabolite orn_c at 0x245545b7a00>,
#  <Metabolite mhista_c at 0x245545b7a30>,
#  <Metabolite 34dhpheac_c at 0x245545b7a60>,
#  <Metabolite orn_e at 0x245545b7a90>,
#  <Metabolite tol_e at 0x245545b7ac0>,
#  <Metabolite tol_c at 0x245545b7af0>,
#  <Metabolite 2mcit_c at 0x245545b7b20>,
#  <Metabolite heppp_c at 0x245545b7b50>,
#  <Metabolite gdptp_c at 0x245545b7b80>,
#  <Metabolite PEPTIDO_c at 0x245545b7bb0>,
#  <Metabolite dscl_c at 0x245545b7be0>,
#  <Metabolite 4sullac_c at 0x245545b7c10>,
#  <Metabolite srb1p_c at 0x245545b7c40>,
#  <Metabolite arg__L_e at 0x245545b7c70>,
#  <Metabolite lald__L_c at 0x245545b7ca0>,
#  <Metabolite arg__L_c at 0x245545b7cd0>,
#  <Metabolite 4ahmmp_c at 0x245545b7d00>,
#  <Metabolite c141_c at 0x245545b7d30>,
#  <Metabolite urate_c at 0x245545b7d60>,
#  <Metabolite histrna_c at 0x245545b7d90>,
#  <Metabolite ssaltpp_c at 0x245545b7dc0>,
#  <Metabolite malte_c at 0x245545b7df0>,
#  <Metabolite co1dam_c at 0x245545b7e20>,
#  <Metabolite acnam_c at 0x245545b7e50>,
#  <Metabolite 3hpppn_e at 0x245545b7e80>,
#  <Metabolite 3hpppn_c at 0x245545b7eb0>,
#  <Metabolite acnam_e at 0x245545b7ee0>,
#  <Metabolite fpram_c at 0x245545b7f10>,
#  <Metabolite 3h5ohcoa_c at 0x245545b7f40>,
#  <Metabolite aso3_c at 0x245545b7f70>,
#  <Metabolite aso3_e at 0x245545b7fa0>,
#  <Metabolite citnlcoa_c at 0x245545b7fd0>,
#  <Metabolite thr__L_c at 0x245545c1040>,
#  <Metabolite udp_c at 0x245545c1070>,
#  <Metabolite thr__L_e at 0x245545c10a0>,
#  <Metabolite acorn_c at 0x245545c10d0>,
#  <Metabolite k2lipiv_c at 0x245545c1100>,
#  <Metabolite sel_c at 0x245545c1130>,
#  <Metabolite fru_e at 0x245545c1160>,
#  <Metabolite ppap_c at 0x245545c1190>,
#  <Metabolite fru_c at 0x245545c11c0>,
#  <Metabolite 2mm__R_c at 0x245545c11f0>,
#  <Metabolite dgtp_c at 0x245545c1220>,
#  <Metabolite 5mthf_c at 0x245545c1250>,
#  <Metabolite gcald_c at 0x245545c1280>,
#  <Metabolite akg_c at 0x245545c12b0>,
#  <Metabolite 3hbcoa_c at 0x245545c12e0>,
#  <Metabolite 7m3o6ocoa_c at 0x245545c1310>,
#  <Metabolite lipidX_c at 0x245545c1340>,
#  <Metabolite c34dhdhf_c at 0x245545c1370>,
#  <Metabolite nacyllaminoacid_c at 0x245545c13a0>,
#  <Metabolite fuc__L_e at 0x245545c13d0>,
#  <Metabolite carboxylate_c at 0x245545c1400>,
#  <Metabolite fuc__L_c at 0x245545c1430>,
#  <Metabolite applp_c at 0x245545c1460>,
#  <Metabolite dlipop_c at 0x245545c1490>,
#  <Metabolite hatrz_c at 0x245545c14c0>,
#  <Metabolite mlthf_c at 0x245545c14f0>,
#  <Metabolite 2naptcoa_c at 0x245545c1520>,
#  <Metabolite 4hmscald_c at 0x245545c1550>,
#  <Metabolite HC01668_c at 0x245545c1580>,
#  <Metabolite lald__D_c at 0x245545c15b0>,
#  <Metabolite malACP_c at 0x245545c15e0>,
#  <Metabolite 4hlmdnit_c at 0x245545c1610>,
#  <Metabolite hmccms_c at 0x245545c1640>,
#  <Metabolite rib__D_c at 0x245545c1670>,
#  <Metabolite udpg_c at 0x245545c16a0>,
#  <Metabolite rib__D_e at 0x245545c16d0>,
#  <Metabolite glyc_c at 0x245545c1700>,
#  <Metabolite glyc_e at 0x245545c1730>,
#  <Metabolite no_c at 0x245545c1760>,
#  <Metabolite lipidAds_c at 0x245545c1790>,
#  <Metabolite 4met2obut_c at 0x245545c17c0>,
#  <Metabolite carpcoa_c at 0x245545c17f0>,
#  <Metabolite metp_c at 0x245545c1820>,
#  <Metabolite grxrd_c at 0x245545c1850>,
#  <Metabolite normete__L_c at 0x245545c1880>,
#  <Metabolite 2ippm_c at 0x245545c18b0>,
#  <Metabolite cbasp_c at 0x245545c18e0>,
#  <Metabolite 2mppacoa_c at 0x245545c1910>,
#  <Metabolite 4pasp_c at 0x245545c1940>,
#  <Metabolite hodhiybe_c at 0x245545c1970>,
#  <Metabolite ccmuc_c at 0x245545c19a0>,
#  <Metabolite ccmuc_e at 0x245545c19d0>,
#  <Metabolite aobzac_e at 0x245545c1a00>,
#  <Metabolite pantcys_c at 0x245545c1a30>,
#  <Metabolite hgcoa_c at 0x245545c1a60>,
#  <Metabolite air_c at 0x245545c1a90>,
#  <Metabolite dhpmp_c at 0x245545c1ac0>,
#  <Metabolite 3hmbcoa_c at 0x245545c1af0>,
#  <Metabolite carccm_c at 0x245545c1b20>,
#  <Metabolite dgdp_c at 0x245545c1b50>,
#  <Metabolite glu5p_c at 0x245545c1b80>,
#  <Metabolite 2py46dc_c at 0x245545c1bb0>,
#  <Metabolite 2h6ot_c at 0x245545c1be0>,
#  <Metabolite galct__D_c at 0x245545c1c10>,
#  <Metabolite ctp_c at 0x245545c1c40>,
#  <Metabolite galct__D_e at 0x245545c1c70>,
#  <Metabolite PROTEIN_c at 0x245545c1ca0>,
#  <Metabolite e4hglu_c at 0x245545c1cd0>,
#  <Metabolite alaala_c at 0x245545c1d00>,
#  <Metabolite dgmp_c at 0x245545c1d30>,
#  <Metabolite 3pg_e at 0x245545c1d60>,
#  <Metabolite 3pg_c at 0x245545c1d90>,
#  <Metabolite spm_c at 0x245545c1dc0>,
#  <Metabolite 3mhdd_c at 0x245545c1df0>,
#  <Metabolite igly_c at 0x245545c1e20>,
#  <Metabolite hodhiyb2e_c at 0x245545c1e50>,
#  <Metabolite pro__L_c at 0x245545c1e80>,
#  <Metabolite 4chbenz_c at 0x245545c1eb0>,
#  <Metabolite thym_c at 0x245545c1ee0>,
#  <Metabolite r1p_c at 0x245545c1f10>,
#  <Metabolite 2cpr5p_c at 0x245545c1f40>,
#  <Metabolite bzop_c at 0x245545c1f70>,
#  <Metabolite agm_c at 0x245545c1fa0>,
#  <Metabolite 26dchp_c at 0x245545c1fd0>,
#  <Metabolite dtdp_c at 0x245545cb040>,
#  <Metabolite nmn_e at 0x245545cb070>,
#  <Metabolite 5cmhm_c at 0x245545cb0a0>,
#  <Metabolite phatol_c at 0x245545cb0d0>,
#  <Metabolite dcmp_c at 0x245545cb100>,
#  <Metabolite 23dhmb_c at 0x245545cb130>,
#  <Metabolite nmn_c at 0x245545cb160>,
#  <Metabolite 35cgmp_c at 0x245545cb190>,
#  <Metabolite aeioh_c at 0x245545cb1c0>,
#  <Metabolite 2dda7p_c at 0x245545cb1f0>,
#  <Metabolite so2_c at 0x245545cb220>,
#  <Metabolite 2mm_c at 0x245545cb250>,
#  <Metabolite forkn_c at 0x245545cb280>,
#  <Metabolite ph_c at 0x245545cb2b0>,
#  <Metabolite 12bhpp_c at 0x245545cb2e0>,
#  <Metabolite aobzac_c at 0x245545cb310>,
#  <Metabolite ara5p_c at 0x245545cb340>,
#  <Metabolite dhap_c at 0x245545cb370>,
#  <Metabolite 2amcs_c at 0x245545cb3a0>,
#  <Metabolite hivcoa_c at 0x245545cb3d0>,
#  <Metabolite 4abut_c at 0x245545cb400>,
#  <Metabolite c160_c at 0x245545cb430>,
#  <Metabolite i3ac_c at 0x245545cb460>,
#  <Metabolite citnl_c at 0x245545cb490>,
#  <Metabolite msa_c at 0x245545cb4c0>,
#  <Metabolite dxyl5p_c at 0x245545cb4f0>,
#  <Metabolite cpppg3_c at 0x245545cb520>,
#  <Metabolite 25drapp_c at 0x245545cb550>,
#  <Metabolite mnl1p_c at 0x245545cb580>,
#  <Metabolite xyl__D_c at 0x245545cb5b0>,
#  <Metabolite 4abut_e at 0x245545cb5e0>,
#  <Metabolite gcys_c at 0x245545cb610>,
#  <Metabolite 4mmclac_c at 0x245545cb640>,
#  <Metabolite pro__L_e at 0x245545cb670>,
#  <Metabolite fmn_c at 0x245545cb6a0>,
#  <Metabolite sucsal_c at 0x245545cb6d0>,
#  <Metabolite tyrtrna_c at 0x245545cb700>,
#  <Metabolite 3rbleu_c at 0x245545cb730>,
#  <Metabolite arab__L_c at 0x245545cb760>,
#  <Metabolite arab__L_e at 0x245545cb790>,
#  <Metabolite 2maaccoa_c at 0x245545cb7c0>,
#  <Metabolite 23bhpp_c at 0x245545cb7f0>,
#  <Metabolite hpmmbq_c at 0x245545cb820>,
#  <Metabolite dcdp_c at 0x245545cb850>,
#  <Metabolite cair_c at 0x245545cb880>,
#  <Metabolite 56dhu_c at 0x245545cb8b0>,
#  <Metabolite parax_c at 0x245545cb8e0>,
#  <Metabolite 4hbald_c at 0x245545cb910>,
#  <Metabolite hmgth_c at 0x245545cb940>,
#  <Metabolite saicar_c at 0x245545cb970>,
#  <Metabolite 5co46dp_c at 0x245545cb9a0>,
#  <Metabolite for_c at 0x245545cb9d0>,
#  <Metabolite datp_c at 0x245545cba00>,
#  <Metabolite 3hadpcoa_c at 0x245545cba30>,
#  <Metabolite for_e at 0x245545cba60>,
#  <Metabolite c160_e at 0x245545cba90>,
#  <Metabolite etha_c at 0x245545cbac0>,
#  <Metabolite 48dhoxquin_c at 0x245545cbaf0>,
#  <Metabolite 4hphac_c at 0x245545cbb20>,
#  <Metabolite M02451_c at 0x245545cbb50>,
#  <Metabolite 4aanit_c at 0x245545cbb80>,
#  <Metabolite gmp_c at 0x245545cbbb0>,
#  <Metabolite 4hphac_e at 0x245545cbbe0>,
#  <Metabolite ohchtcht_c at 0x245545cbc10>,
#  <Metabolite seahcys_c at 0x245545cbc40>,
#  <Metabolite trnacys_c at 0x245545cbc70>,
#  <Metabolite ahdt_c at 0x245545cbca0>,
#  <Metabolite M02451_e at 0x245545cbcd0>,
#  <Metabolite idpyr_c at 0x245545cbd00>,
#  <Metabolite uacgam_c at 0x245545cbd30>,
#  <Metabolite hophd_c at 0x245545cbd60>,
#  <Metabolite pac_c at 0x245545cbd90>,
#  <Metabolite pac_e at 0x245545cbdc0>,
#  <Metabolite chor_c at 0x245545cbdf0>,
#  <Metabolite bzaccoa_c at 0x245545cbe20>,
#  <Metabolite fsalac_c at 0x245545cbe50>,
#  <Metabolite fuc1p__L_c at 0x245545cbe80>,
#  <Metabolite lgt_s_c at 0x245545cbeb0>,
#  <Metabolite fuc1p__L_e at 0x245545cbee0>,
#  <Metabolite phthr_c at 0x245545cbf10>,
#  <Metabolite cyaala_c at 0x245545cbf40>,
#  <Metabolite selcys_c at 0x245545cbf70>,
#  <Metabolite nh4_e at 0x245545cbfa0>,
#  <Metabolite bhb_e at 0x245545cbfd0>,
#  <Metabolite oohoch_c at 0x245545d5040>,
#  <Metabolite nh4_c at 0x245545d5070>,
#  <Metabolite bhb_c at 0x245545d50a0>,
#  <Metabolite acg5p_c at 0x245545d50d0>,
#  <Metabolite ccpamd_c at 0x245545d5100>,
#  <Metabolite slfcys_c at 0x245545d5130>,
#  <Metabolite 4chcat_c at 0x245545d5160>,
#  <Metabolite camp_c at 0x245545d5190>,
#  <Metabolite q8h2_c at 0x245545d51c0>,
#  <Metabolite 4ppcys_c at 0x245545d51f0>,
#  <Metabolite anth_c at 0x245545d5220>,
#  <Metabolite anth_e at 0x245545d5250>,
#  <Metabolite 4hbzcoa_c at 0x245545d5280>,
#  <Metabolite 3hibutcoa_c at 0x245545d52b0>,
#  <Metabolite fmettrna_c at 0x245545d52e0>,
#  <Metabolite b5amp_c at 0x245545d5310>,
#  <Metabolite phllqne_c at 0x245545d5340>,
#  <Metabolite tglu_c at 0x245545d5370>,
#  <Metabolite pheborn_c at 0x245545d53a0>,
#  <Metabolite dmi1p_c at 0x245545d53d0>,
#  <Metabolite gmhep1p_c at 0x245545d5400>,
#  <Metabolite mal__D_c at 0x245545d5430>,
#  <Metabolite strcg_c at 0x245545d5460>,
#  <Metabolite 3php_c at 0x245545d5490>,
#  <Metabolite M00673_c at 0x245545d54c0>,
#  <Metabolite man6p_e at 0x245545d54f0>,
#  <Metabolite hisp_c at 0x245545d5520>,
#  <Metabolite 2flrbz_c at 0x245545d5550>,
#  <Metabolite mnl_e at 0x245545d5580>,
#  <Metabolite 4flthr_c at 0x245545d55b0>,
#  <Metabolite glx_e at 0x245545d55e0>,
#  <Metabolite man6p_c at 0x245545d5610>,
#  <Metabolite 4flthr_e at 0x245545d5640>,
#  <Metabolite glx_c at 0x245545d5670>,
#  <Metabolite 4hactph_c at 0x245545d56a0>,
#  <Metabolite hmccm_c at 0x245545d56d0>,
#  <Metabolite 2p1a_c at 0x245545d5700>,
#  <Metabolite suchms_c at 0x245545d5730>,
#  <Metabolite ru5p__D_c at 0x245545d5760>,
#  <Metabolite ppi_c at 0x245545d5790>,
#  <Metabolite 5hoxindact_c at 0x245545d57c0>,
#  <Metabolite 3m4hpga_c at 0x245545d57f0>,
#  <Metabolite malthp_c at 0x245545d5820>,
#  <Metabolite naphmsuccoa_c at 0x245545d5850>,
#  <Metabolite 3urdpp_c at 0x245545d5880>,
#  <Metabolite 2mbcoa_c at 0x245545d58b0>,
#  <Metabolite dchrocmo_c at 0x245545d58e0>,
#  <Metabolite 2napthm_c at 0x245545d5910>,
#  <Metabolite ACP_c at 0x245545d5940>,
#  <Metabolite ccppc_c at 0x245545d5970>,
#  <Metabolite 4mop_c at 0x245545d59a0>,
#  <Metabolite bbtcoa_c at 0x245545d59d0>,
#  <Metabolite amuco_c at 0x245545d5a00>,
#  <Metabolite malpyr_c at 0x245545d5a30>,
#  <Metabolite 6chq_c at 0x245545d5a60>,
#  <Metabolite trdrd_c at 0x245545d5a90>,
#  <Metabolite 3flrbz_c at 0x245545d5ac0>,
#  ...]

# %%
############### ADDING NEW REACTIONS FOR Glycerolipid metabolism
################################################################
### glycerol + NADP+ = D-glyceraldehyde + NADPH + H+ [RN:R01041]

### Check for glycerol
print("###### check glycerol")
for metabolite in model.metabolites.query('glycerol', 'name'):
    print(metabolite.name)
### No direct glycerol pathway so far
#Add glycerol
EX_glycerol_e = Metabolite(id='EX_glycerol_e', compartment='e')

### Check for NADP+
print("###### check NADP+")
for metabolite in model.metabolites.query('nadp', 'name'):
    print(metabolite.name)
### No NADP+
### Found in model
print(model.metabolites.nadp_c)

### Check for D-glyceraldehyde
print("###### check D-glyceraldehyde")
for metabolite in model.metabolites.query('d-glyceraldehyde', 'name'):
    print(metabolite.name)
### No D-glyceraldehyde 
#add D-glyceraldehyde
glyceraldehyde_c = Metabolite(id='glyceraldehyde_c', compartment='c')

### Check for NADPH
print("###### check NADPH")
for metabolite in model.metabolites.query('nadph', 'name'):
    print(metabolite.name)
### NADPH not found
### NADPH found in model
print(model.metabolites.nadph_c)

### Check for  H+
print("###### check H+")
for metabolite in model.metabolites.query('h', 'name'):
    print(metabolite.name)
### H+ found
# Out:
# ###### check glycerol
# CDP-diacylglycerol
# D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate
# Triacylglycerol
# 1,2-Diacyl-sn-glycerol
# Phosphatidylglycerol
# Glycerophosphoglycerol
# 1-Acyl-sn-glycerol 3-phosphate
# 1-Acylglycerol
# C1-(3-Indolyl)-glycerol 3-phosphate
# ###### check NADP+
# nadp_c
# ###### check D-glyceraldehyde
# ###### check NADPH
# nadph_c
# ###### check H+
# (Z)-5-Oxohex-2-enedioate
# Acetyl phosphate
# Phenylacetyl-CoA
# 2-Hydroxy-3-methylbenzalpyruvate
# L-Methionyl-tRNA (Met)
# Selenophosphate
# heptadecanoic acid (C17:0)
# cis-2-Chloro-4-carboxymethylenebut-2-en-1,4-olide
# Phosphatidylserine
# Phenethylamine
# 2-Methylbut-2-enoyl-CoATiglyl-CoA
# 5-Chloro-2-hydroxymuconic semialdehyde
# Dihydrofolate
# Inorganic triphosphate
# 5'-Methylthioadenosine
# Thiocysteine
# 4-Nitrophenol
# Anthranilyl-CoA
# cis-3-(3-Carboxyethenyl)-3,5-cyclohexadiene-1,2-diol
# 4-(2-Aminophenyl)-2,4-dioxobutanoate
# D-Methionine
# D-Glucosamine 1-phosphate
# D-Xylulose 5-phosphate
# D-Methionine
# tRNA(Phe)
# branching glycogen
# N1-(alpha-D-ribosyl)-5,6-dimethylbenzimidazole
# 3,4-Dihydroxymandelaldehyde
# D-Glycero-D-manno-heptose 1,7-bisphosphate
# 4-Sulfocatechol
# Phosphatidylethanolamine
# Phenylacetaldehyde
# 2-Hydroxyhepta-2,4-dienedioate
# Glycerophosphoserine
# 1,6-Dihydroxy-cis-2,4-cyclohexadiene-1- carboxylic acid
# 1-Hydroxymethylnaphthalene
# 2-Amino-5-oxocyclohex-1-enecarbonyl-CoA
# methylisocitrate
# D-Erythrose 4-phosphate
# L-Rhamnose
# L-Rhamnose
# 4-Nitrophenyl phosphate
# 3-Phospho-D-glyceroyl phosphate
# O-Phospho-L-serine
# Betaine aldehyde
# D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate
# 5-Amino-6-(5'-phosphoribosylamino)uracil
# 1,4-Dihydroxy-2-naphthoate
# Dimethylallyl diphosphate
# lipopolisaccharide
# Glutathionylspermidine
# L-Glutamate 1-semialdehyde
# D-Glyceraldehyde 3-phosphate
# 1-(5'-Phosphoribosyl)-5-amino-4-imidazolecarboxamide
# Thiamin
# Thiamin
# Naphthyl-2-methyl-succinic acid
# CDP-4-dehydro-6-deoxy-D-glucose
# 2,6-Dichlorohydroquinone
# Thiamine diphosphate
# 2-Methylprop-2-enoyl-CoA
# 2-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 4-Chlorophenylacetate
# sn-Glycero-3-phosphoethanolamine
# hexadecenoate (n-C16:1)
# 3,4,6-Trichlorocatechol
# L-Phenylalanine
# Thiocyanate
# Choline phosphate
# L-Phenylalanine
# D-Glycerate 2-phosphate
# D-Glycerate 2-phosphate
# Presqualene diphosphate
# 1-Hydroxy-2-methyl-2-butenyl 4-diphosphate
# sn-Glycero-3-phospho-1-inositol
# 4-Amino-2-methyl-5-phosphomethylpyrimidine
# Dephospho-CoA
# Cyclohexanone
# L-Cystathionine
# 2-Dehydro-3-deoxy-D-glucarate
# Thymidine
# Porphobilinogen
# 5-Formyltetrahydrofolate
# Dihydropteroate
# 5,6-Dihydrothymine
# Thymidine
# Methylimidazole acetaldehyde
# 5-O-(1-Carboxyvinyl)-3-phosphoshikimate
# Imidazole-4-acetaldehyde
# 2-Hydroxy-2-hydropyrone-4,6-dicarboxylate
# Se-Adenosylselenomethionine
# 3-Fluorocatechol
# 2-Hydroxycyclohexan-1-one
# Protoporphyrin
# 4,6-Dihydroxyquinoline
# 3-Octaprenyl-4-hydroxybenzoate
# trans-2,3-Dihydroxycinnamate
# 2-Hydroxy-cis-hex-2,4-dienoate
# 3,4-Dihydroxyphenylethyleneglycol
# 5-Methyl-3-oxo-4-hexenoyl-CoA
# N-(5-Phospho-D-ribosyl)anthranilate
# Cyclohexylamine
# D-Fructose 1-phosphate
# cis-3-(Carboxy-ethyl)-3,5-cyclohexadiene-1,2-diol
# 1-(5-Phosphoribosyl)-AMP
# Shikimate
# phosphatidylcholine
# 5-Phospho-alpha-D-ribose
# beta-D-Fructose 2,6-bisphosphate
# Hydroxymethylbilane
# beta-D-Fructose 2-phosphate
# 4-Hydroxy-2-oxo-heptanedioate
# 1,2-Anthracenediol
# Phosphatidylglycerol
# 5-Methyltetrahydropteroyltri-L-glutamate
# 1-Methylnaphthalene
# Naphthalene-1,2-diol
# S-Adenosyl-4-methylthio-2-oxobutanoate
# P1,P4-Bis(5'-uridyl) tetraphosphate
# 4-Carboxy-2-hydroxymuconate semialdehyde
# 2,3,4,5-Tetrahydrodipicolinate
# Adenosyl cobinamide phosphate
# Sulfoacetaldehyde
# 1-(5-Phosphoribosyl)-ATP
# 2-Demethylmenaquinone
# 5-carboxyamino-1-(5-phospho-D-ribosyl)imidazole
# S-(2-Methylbutanoyl)-dihydrolipoamide-E
# 2-Amino-3-carboxymuconate semialdehyde
# 5-Formamido-1-(5-phospho-D-ribosyl)
# 6-Phospho-D-gluconate
# 5-Amino-6-(5'-phosphoribitylamino)uracil
# 2-Naphthoic acid
# Catechol
# Catechol
# 4-Methylsalicylate
# O-Acetylhomoserine
# O-Succinylhomoserine
# 4-Nitrocatechol
# 5,6-Dihydroxyindole
# 3-Deoxy-D-manno-octulosonate 8-phosphate
# UDP-2,3-bis(3-hydroxytetradecanoyl)glucosamine
# Glycerophosphoglycerol
# L-Aspartate 4-semialdehyde
# 3-Oxo-4-methylpentanoic acid
# Geranyl diphosphate
# Methylmalonate
# S-Ribosyl-L-homocysteine
# 4-Ethylphenol
# cis-hexadec-9-enoyl-[acyl-carrier protein]
# 2-Octaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinone
# S-Glutaryldihydrolipoamide
# 2-Octaprenyl-6-methoxyphenol
# (2E)-5-Methylhexa-2,4-dienoyl-CoA
# S-Formylglutathione
# 1-Acyl-sn-glycerol 3-phosphate
# Ethanolamine phosphate
# D-Mannose 1-phosphate
# Thiamin monophosphate
# Pyridoxamine 5'-phosphate
# Phosphate
# 4-(Trimethylammonio)but-2-enoate
# Indole-3-acetaldehyde
# Phenol
# Phenol
# 2,3,5-Trichloro-cis,cis-muconate
# Cyclohexane-1-carboxyl-CoA
# 3-Chloro-cis,cis-muconate
# Phosphate
# (R)-2,3-Dihydroxy-3-methylpentanoate
# Thiosulfate
# N-Acetyl-D-mannosamine 6-phosphate
# N-Acetyl-D-glucosamine 6-phosphate
# heptadecenoyl-ACP (C17:1 ACP)
# Thiosulfate
# L-1-Pyrroline-3-hydroxy-5-carboxylate
# Dihydrobiopterin
# alpha-Aminopropiononitrile
# 2-Hexaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinone
# 2,3-Dihydroxytoluene
# Uroporphyrinogen III
# 5-Carboxy-2-oxohept-3-enedioate
# 2-Chloro-4-hydroxy-6-amino-1,3,5-triazine
# all-trans-Hexaprenyl diphosphate
# Uroporphyrinogen I
# CDP-ethanolamine
# tRNA(Thr)
# 2-Ketocyclohexane-1-carboxyl-CoA
# Coproporphyrinogen I
# Sedoheptulose 7-phosphate
# Phenylacetonitrile
# Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutaminyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# 4-Methylcatechol
# carbohydrate
# Phosphatidate
# Galactitol 1-phosphate
# S-(2-Methylpropionyl)-dihydrolipoamide-E
# Naphthyl-2-methyl-succinyl-CoA
# 2-Hydroxycyclohexane-1-carboxyl-CoA
# D-Fructose 1,6-bisphosphate
# alpha-D-Ribose 5-phosphate
# 5-Methylcytosine
# Dihydroneopterin
# 1,2-Dihydroxynaphthalene-6-sulfonate
# 4-Carboxy-2-hydroxyhexa-2,4-dienedioate
# all-trans-Octaprenyl diphosphate
# D-Glucosamine 6-phosphate
# 4-Fluorocyclohexadiene-cis,cis-1,2-diol
# Chloride
# m-Methylbenzoate
# Chloride
# Gentisate aldehyde
# Selenocystathionine
# 2-Octaprenyl-3-methyl-6-methoxy-1,4-benzoquinone
# L-Dopachrome
# 3-Chloro-2-hydroxymuconic semialdehyde
# L-Threonyl-tRNA(Thr)
# 2-Methylnaphthalene
# 3-Methylcrotonyl-CoA
# Prephenate
# (S)-5-Oxo-2,5-dihydrofuran-2-acetate
# Poly-beta-hydroxybutyrate
# Poly-beta-hydroxybutyrate
# Maltohexaose
# (S)-5-Oxo-2,5-dihydrofuran-2-acetate
# Maltohexaose
# beta-Aminopropion aldehyde
# Aminoacetaldehyde
# 3-Carboxy-2-hydroxy-4-methylpentanoate
# Undecaprenyl diphosphate
# 2-C-methyl-D-erythritol 4-phosphate
# cis-4-Carboxymethylenebut-2-en-4-olide
# cis-3-Chloroacrylic acid
# L-Methionine
# Phenylacetylglycine
# (S)-3-Methyl-2-oxopentanoate
# (S)-Methylmalonyl-CoA
# L-Methionine
# 1,2-Dihydroxyfluorene
# 4-Hydroxy-2-oxohexanoic acid
# S-Adenosyl-L-methionine
# 5-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# Carbamoyl phosphate
# Fluoroacetaldehyde
# Formylanthranilate
# 2-Hydroxy-4-hydroxymethylbenzalpyruvate
# 5-Methylhex-4-enoyl-CoA
# N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole
# 5-[(5-Phospho-1-deoxyribulos-1-ylamino)methylideneamino]-1-(5-phosphoribosyl)imidazole-4-carboxamide
# 2,3,2'3'-Tetrakis(3-hydroxytetradecanoyl)-D-glucosaminyl-1,6-beta-D-glucosamine 1,4'-bisphosphate
# 2-Hydroxy-6-oxo-6-(2-hydroxyphenyl)-hexa-2,4-dienoate
# 3-Chlorocatechol
# 5-(2-Hydroxyethyl)-4-methylthiazole
# 3-Vinylcatechol
# 4-(Cytidine 5'-diphospho)-2-C-methyl-Derythritol
# Naphthyl-2-oxomethyl-succinyl-CoA
# S-Adenosyl-L-homocysteine
# 2-Dehydropantoate
# 6-Hydroxycyclohex-1-enecarbonyl-CoA
# 3-Hydroxy-2-naphthoate
# D-4'-Phosphopantothenate
# Acetaldehyde
# L-Ascorbate 6-phosphate
# Acetaldehyde
# Trehalose
# N6-(1,2-Dicarboxyethyl)-AMP
# cis-3-Chloro-2-propene-1-ol
# Selenomethionine
# Trehalose
# 2-Dehydro-3-deoxy-6-phospho-D-gluconate
# 2,5-Dihydroxybenzoate
# 2,5-Dihydroxybenzoate
# Bis(4'-chlorophenyl)methane
# N-Acetyl-D-glucosamine 1-phosphate
# 2,4,6-Trichlorophenol
# 6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# phospholipid
# 3-Methoxy-4-hydroxyphenylacetaldehyde
# 2-Deoxy-D-ribose 1-phosphate
# 6-Pyruvoyltetrahydropterin
# D-Sorbitol 6-phosphate
# 2-Dehydro-D-gluconate 6-phosphate
# Protoporphyrinogen IX
# 4-Hydroxyphenylacetyl-CoA
# Sirohydrochlorin
# Phenanthrene-9,10-oxide
# 2-Hydroxy-6-oxo-6-(2-hydroxyphenoxy)-hexa-2,4-dienoate
# (Z)-4-(2-Hydroxy-5-sulfonatophenyl)-2-oxo-3-butenoate
# P1,P4-Bis(5'-guanosyl) tetraphosphate
# (Z)-4-Hydroxyphenylacetaldehyde-oxime
# 2,2-Bis(4-hydroxyphenyl)-1-propanol
# 2-Phytyl-1,4-naphthoquinone
# GDP-4-dehydro-6-deoxy-D-mannose
# Anthracene-9,10-dihydrodiol
# L-4-Hydroxyglutamate semialdehyde
# Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# N-Succinyl-LL-2,6-diaminoheptanedioate
# N-Formyl-L-methionine
# 3-Hydroxybenzyl alcohol
# 5,10-Methenyltetrahydrofolate
# Phenanthracene
# Adenosine 3',5'-bisphosphate
# Phosphoenolpyruvate
# P1,P4-Bis(5'-xanthosyl) tetraphosphate
# 1-(4'-Hydroxyphenyl)ethanol
# Isopentenyl diphosphate
# D-Glucose 6-phosphate
# N-Acetyl-L-glutamate 5-semialdehyde
# 5-Phosphoribosylamine
# 6-Hydroxyhexanoic acid
# L-Tryptophanyl-tRNA(Trp)
# trans-3-Chloroacrylic acid
# D-erythro-3-Methylmalate
# 3-Methyl-2-oxobutanoate
# D-Glucose 6-phosphate
# 2-Hydroxy-6-oxo-6-(4'-chlorophenyl)-hexa-2,4-dienoate
# 6,7-Dimethyl-8-(1-D-ribityl)lumazine
# L-Glutamate 5-semialdehyde
# L-Phenylalanyl-tRNA(Phe)
# Phenylpropanoate
# 2,3-Dihydroxy 1,1,1-Trichloro-2,2-bis(4'-chlorophenyl)ethane
# Phenylpropanoate
# 3-Hydroxyphenylacetate
# 2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate
# 2-Oxo-5-methyl-cis-muconate
# (+)-cis-3,4-Dihydrophenanthrene-3,4-diol
# Thioredoxin disulfide
# S-Acetyldihydrolipoamide-E
# UDP-3-O-(3-hydroxytetradecanoyl)-N-acetylglucosamine
# 4-amino-4-deoxychorismate
# Adenosyl cobyrinate hexaamide
# hcl
# D-Tagatose 6-phosphate
# Reduced glutathione
# dTDP-4-dehydro-6-deoxy-L-mannose
# 3'-Phosphoadenylyl sulfate
# 2,5-Dichloro-4-oxohex-2-enedioate
# 3-Methoxytyramine
# 2-Naphthaldehyde
# 2-Chloro-3-oxoadipate
# 5,6,7,8-Tetrahydrofolate
# dTDP-L-rhamnose
# 4-Hydroxy-L-threonine
# 3-Carboxy-4-methyl-2-oxopentanoate
# 1,1-Dichloro-2-(dihydroxy-4'-chlorophenyl)-2-(4'-chlorophenyl)ethylene
# 3-Chloroallyl aldehyde
# D-Ribose 1,5-bisphosphate
# 2-Hydroxyisophthalic acid
# Glycerol 3-phosphate
# Glycerol 3-phosphate
# ADP-L-glycero-D-manno-heptose
# P1,P4-Bis(5'-adenosyl) tetraphosphate
# 4-Hydroxymethylsalicylate
# 1-(5-Phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino]imidazole-4-carboxamide
# 10-Formyltetrahydrofolate
# 4-Hydroxymethylcatechol
# 1-Hydroxy-2-naphthoate
# LL-2,6-Diaminoheptanedioate
# L-Ornithine
# N-Methylhistamine
# 3,4-Dihydroxyphenylacetate
# L-Ornithine
# 2-Methylcitrate
# all-trans-Heptaprenyl diphosphate
# Guanosine 3'-diphosphate 5'-triphosphate
# dihydrosirohydrochlorin
# Sorbose 1-phosphate
# L-Lactaldehyde
# 4-Amino-5-hydroxymethyl-2-methylpyrimidine
# Succinate semialdehyde-thiamin diphosphate anion
# 3-(3-Hydroxy-phenyl)-propanoic acid
# 3-(3-Hydroxy-phenyl)-propanoic acid
# 2-(Formamido)-N1-(5-phospho-D-ribosyl) acetamidine
# 3-Hydroxy-5-oxohexanoyl-CoA
# L-Threonine
# L-Threonine
# N2-Acetyl-L-ornithine
# Propanoyl phosphate
# (R)-2-Methylmalate
# 5-Methyltetrahydrofolate
# Glycolaldehyde
# 7-Methyl-3-oxo-6-octenoyl-CoA
# 2,3-Bis(3-hydroxytetradecanoyl)-beta-D-glucosaminyl 1-phosphate
# (+)-(3S,4R)-cis-3,4-Dihydroxy-3,4-dihydrofluorene
# D-1-Aminopropan-2-ol O-phosphate
# Dihydrolipoylprotein
# 5,10-Methylenetetrahydrofolate
# 2-Naphthoyl-CoA
# 4-Hydroxymethylsalicylaldehyde
# D-Lactaldehyde
# 2-Hydroxy-5-methyl-cis,cis-muconic semialdehyde
# 2,3,2',3'-Tetrakis(3-hydroxytetradecanoyl)-D-glucosaminyl-1,6-beta-D-glucosamine 1-phosphate
# 4-Methylthio-2-oxobutanoate
# L-Metanephrine
# Thioredoxin
# L-Normetanephrine
# 2-Methylpropanoyl-CoA
# 4-Phospho-L-aspartate
# 2-Hydroxy-4-(1-oxo-1,3-dihydro-2Hinden-2-ylidene)-but-2-enoic acid
# alpha-Oxo-benzeneacetic acid
# N-((R)-Pantothenoyl)-L-cysteine
# Dihydroneopterin phosphate
# (S)-3-Hydroxy-2-methylbutyryl-CoA
# L-Glutamate 5-phosphate
# L-erythro-4-Hydroxyglutamate
# 3-Phospho-D-glycerate
# 3-Phospho-D-glycerate
# 3-Methyl-cis,cis-hexadienedioate
# 2-Hydroxy-4-(2-oxo-1,3-dihydro-2Hinden-1-ylidene)but-2-enoic acid
# 4-Chlorobenzoate
# Thymine
# alpha-D-Ribose 1-phosphate
# 1-(2-Carboxyphenylamino)-1'-deoxy-D-ribulose 5'-phosphate
# Benzoyl phosphate
# 2,6-Dichlorophenol
# 5-Carboxymethyl-2-hydroxymuconate
# 1-Phenanthrol
# (R)-2,3-Dihydroxy-3-methylbutanoate
# 3-(2-Aminoethyl)-1H-indol-5-ol
# 2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate
# 2-Methylmaleate
# ph
# 1,2-Bis(4-hydroxyphenyl)-2-propanol
# alpha-Oxo-benzeneacetic acid
# D-Arabinose 5-phosphate
# Glycerone phosphate
# 2-Aminomuconate semialdehyde
# Malonate semialdehyde
# 1-deoxy-D-xylulose 5-phosphate
# Coproporphyrinogen III
# 2,5-Diamino-6-(5'-phosphoribosylamino)-4-pyrimidineone
# D-Mannitol 1-phosphate
# 4-Methylmuconolactone
# Succinic semialdehyde
# 2-Methylacetoacetyl-CoA
# 2,3-Bis(4-hydroxyphenyl)-1,2-propanediol
# 2-Hexaprenyl-3-methyl-6-methoxy-1,4-benzoquinone
# 1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate
# 5,6-Dihydrouracil
# 4-Hydroxybenzaldehyde
# S-(Hydroxymethyl)glutathione
# 1-(5'-Phosphoribosyl)-5-amino-4-(N-succinocarboxamide)-imidazole
# 5-(3'-Carboxy-3'-oxopropyl)-4,6-dihydroxypicolinate
# Ethanolamine
# 4,8-Dihydroxyquinoline
# 4-Hydroxyphenylacetate
# 4-Hydroxyphenylacetate
# 6-Oxo-2-hydroxy-7-(4'-chlorophenyl)-3,8,8-trichloroocta-2E,4E,7E-trienoate
# Se-Adenosylselenohomocysteine
# 2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl)dihydropteridine triphosphate
# 2-Hydroxy-6-oxo-6-phenylhexa-2,4-dienoate
# Phenylacetic acid
# Phenylacetic acid
# chorismate
# L-Fucose 1-phosphate
# (R)-S-Lactoylglutathione
# L-Fucose 1-phosphate
# O-Phospho-4-hydroxy-L-threonine
# 1-Oxa-2-oxo-3-hydroxycycloheptane
# N-Acetyl-L-glutamyl 5-phosphate
# 4-Chlorocatechol
# N-[(R)-4'-Phosphopantothenoyl]-L-cysteine
# Anthranilate
# Anthranilate
# N-Formylmethionyl-tRNA
# Phylloquinone
# Tetrahydropteroyltri-L-glutamate
# Phenylboronic acid
# Inositol 1-phosphate
# D-Glycero-D-manno-heptose 1-phosphate
# 3-Phosphohydroxypyruvate
# 2-Phenylacetamide
# D-Mannose 6-phosphate
# L-Histidinol phosphate
# 4-Fluoro-L-threonine
# D-Mannose 6-phosphate
# 4-Fluoro-L-threonine
# 4'-Hydroxyacetophenone
# 2-Hydroxy-5-methyl-cis,cis-muconate
# O-Succinyl-L-homoserine
# D-Ribulose 5-phosphate
# Diphosphate
# 5-Hydroxyindoleacetaldehyde
# 3-Methoxy-4-hydroxyphenylglycolaldehyde
# Celloheptaose
# Naphthyl-2-hydroxymethyl-succinyl CoA
# (S)-2-Methylbutanoyl-CoA
# 2,5-Dichloro-carboxymethylenebut-2-en-4-olide
# (2-Naphthyl)methanol
# 4-Methyl-2-oxopentanoate
# 6-Chlorohydroxyquinol
# Reduced thioredoxin
# 6-Chlorohydroxyquinol
# S-Adenosylmethioninamine
# 2-Amino-7,8-dihydro-4-hydroxy-6-(diphosphooxymethyl)pteridine
# 1-Naphthaldehyde
# Xanthosine 5'-phosphate
# Methylamine
# 4-(3-Hydroxy-2-naphthyl)-2-oxobut-3-enoic acid
# 5-Dehydro-4-deoxy-D-glucarate
# Ethylamine
# 3-(4-Hydroxyphenyl)pyruvate
# 2-Oxohept-3-enedioate
# Phenylpyruvate
# 3-Hydroxybenzaldehyde
# p-Tolualdehyde
# 3,4-dihydroxy-2-butanone 4-phosphate
# 3-Amino-2-oxopropyl phosphate
# alpha-Amino-gamma-cyanobutanoate
# 6-Carboxyhexanoate
# 2-Amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine
# N,N-Dimethylglycine
# O-Acetyl-L-homoserine
# (S)-3-Hydroxy-3-methylglutaryl-CoA
# trans-4-Carboxymethylenebut-2-en-4-olide
# Biphenyl-2,3-diol
# Biphenyl-2,3-diol
# (R)-Pantothenate
# 2-C-methyl-D-erythritol 2,4-cyclodiphosphate
# (R)-Pantothenate
# 4-Phospho-D-erythronate
# Bisphenol A
# dTDP-4-dehydro-6-deoxy-alpha-D-glucose
# Nicotinamide adenine dinucleotide phosphate
# 2-Octaprenyl-6-methoxy-1,4-benzoquinol
# Oxidized thioredoxin
# 4-Methyl-5-(2-phosphoethyl)-thiazole
# Orotidine 5'-phosphate
# D-Glycero-D-manno-heptose 7-phosphate
# Pantetheine 4'-phosphate
# Selenomethionyl-tRNA(Met)
# S-Aminomethyldihydrolipoylprotein
# 3-(2,3-Dihydroxyphenyl)propanoate
# (S)-Dihydroorotate
# 2-phospho-4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol
# 2-Oxo-3-hydroxy-4-phosphobutanoate
# 3-Methylbutanoyl-CoA
# 3-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 2-Hydroxymuconate semialdehyde
# 2,3-Dihydroxy-4'-chlorobiphenyl
# ADP-D-glycero-D-manno-heptose
# 4-Fluorocatechol
# 3-Methylsalicylaldehyde
# 6-Oxo-2-hydroxy-7-(4'-chlorophenyl)-3,8,8,8-tetrachloroocta-2E,4E-dienoate
# 2-Acyl-sn-glycero-3-phosphoethanolamine
# 3,4-Dihydroxyphenylacetaldehyde
# Dihydrolipoamide-E
# 6-phospho-D-glucono-1,5-lactone
# Chloroacetaldehyde
# 5'-Phosphoribosylglycinamide
# 3-Methylsalicylate
# Meso-2,6-Diaminoheptanedioate
# 3-Hydroxy-5-methylhex-4-enoyl-CoA
# Meso-2,6-Diaminoheptanedioate
# Bis(4'-chlorophenyl)acetate
# 2-Dehydro-3-deoxy-D-gluconate
# 2-Dehydro-3-deoxy-D-gluconate
# L-Tryptophan
# D-Glucose 1-phosphate
# L-Tryptophan
# UDP-3-O-(3-hydroxytetradecanoyl)-D-glucosamine
# 4-Carboxy-4-hydroxy-2-oxoadipate
# 2-Aminoacrylate Dehydroalanine
# cis-2,3-Dihydrodiol 1,1,1-Trichloro-2,2-bis(4'-chlorophenyl)ethane cis-2,3-Dihydrodiol
# Oxidized glutathione
# Naphthyl-2-methylene-succinyl-CoA
# 2-Phosphoglycolate
# 2-Hydroxyphenylacetate
# Choline
# Choline
# Xanthine
# 3,4-Dihydroxybenzoate
# Anthracene
# D-Phenylalanine
# Nicotinamide adenine dinucleotide phosphate -reduced
# 6-Carboxyhex-2-enoyl-CoA
# Xanthine
# Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-D-glutamylmeso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# Methylglyoxal
# 3,4-Dihydroxybenzoate
# (R)-Methylmalonyl-CoA
# 2-Acyl-sn-glycero-3-phosphoserine
# S-(3-Methylbutanoyl)-dihydrolipoamide-E
# (S)-Methylmalonate semialdehyde
# 2-Carboxy-2,3-dihydro-5,6-dihydroxyindole
# D-Glyceraldehyde
# D-Glyceraldehyde
# 2,3-Dihydrodipicolinate
# Farnesyl diphosphate
# O-Phospho-L-homoserine
# 2,6-Dihydroxycyclohexane-1-carboxyl-CoA
# 4-Hydroxyphenylacetaldehyde
# 3-Hydroxyanthranilate
# sn-Glycero-3-phosphocholine
# 2-Hydroxyethylenedicarboxylate
# Phenanthrene-1,2-oxide
# cis-3-Chloroallyl aldehyde
# Pyridoxine 5'-phosphate
# (S)-2-Aceto-2-hydroxybutanoate
# 2-Chloro-cis,cis-muconate
# Ethanol
# 3,4-Dihydroxyfluorene
# 2-Chloromaleylacetate
# 2-Hydroxy-6-keto-2,4-heptadienoate
# Ethanol
# C1-(3-Indolyl)-glycerol 3-phosphate
# Selenohomocysteine
# 2-Octaprenyl-6-hydroxyphenol
# 2-Oxo-2,3-dihydrofuran-5-acetate
# cis-2-Methylaconitate
# 4-Hydroxyphenylglyoxylate
# heptadecanoyl-ACP (C17:0 ACP)
# 3-Carboxy-3-hydroxy-4-methylpentanoate
# 3'-Phosphoadenylylselenate
# N-Succinyl-2-L-amino-6-oxoheptanedioate
# 3-Dehydroshikimate
# 3-(Imidazol-4-yl)-2-oxopropyl phosphate
# Shikimate 5-phosphate
# 3-[6-(Carboxymethylene)cyclohexa-2,4-dien-1-ylidene]-2-oxopropanate
# 5-(3'-Carboxy-3'-oxopropenyl)-4,6-dihydroxypicolinate
# 2-Methylbenzaldehyde
# Benzaldehyde
# Benzaldehyde
# Chloroacetic acid
# Cyclohexane-1-carboxylate
# Dihydrolipoamide
# 3-Sulfocatechol
# 3-Dehydroquinate
# D-Fructose 6-phosphate
# Protoheme
# Tetrahydrobiopterin
# 2-Octaprenylphenol
# Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutaminyl-meso-2,6-diaminopimeloyl-(glycyl)5-D-alanyl-D-alanine
# Pyridoxal 5'-phosphate
# L-Allo-threonine
# 5,6-Dimethylbenzimidazole
# Xanthosine
# trans-3-Chloro-2-propene-1-ol
# alpha,alpha'-Trehalose 6-phosphate
# 2,4-Dihydroxyhept-2-enedioate
# Dethiobiotin
# Pantetheine
# 2-Amino-3-oxo-4-phosphonooxybutyrate
# Hypoxanthine
# 3-Methylbenzaldehyde
# Hypoxanthine
# Undecaprenyl phosphate
# 3-(2-Carboxyvinyl)naphthalene-2-carboxylic acid
# Guanosine 3',5'-bis(diphosphate)
# Phosphatidylglycerophosphate
# N2-Formyl-N1-(5-phospho-D-ribosyl) glycinamide
# Parathion
# N-Cyclohexylformamide
# 4-Hydroxyphenylacetylglycine
# Pseudouridine 5'-phosphate
# Xanthosine
# 2-Acyl-sn-glycero-3-phosphocholine
# 4-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# Ribulose-1,5-bisphosphate
# 4-Hydroxy-benzyl alcohol

# %%
## Add reaction glycerol dehydrogenase 
## Reaction: glycerol + NADP+ = D-glyceraldehyde + NADPH + H+ [RN:R01041]
Glycerol_dehydrogenase = Reaction('1.1.1.72') 
Glycerol_dehydrogenase.add_metabolites({EX_glycerol_e: -1,
                            model.metabolites.nadp_c: -1,
                            glyceraldehyde_c: 1,
                          model.metabolites.nadph_c: 1,
                            model.metabolites.h_c: 1, 
                              })
print(Glycerol_dehydrogenase.build_reaction_string())
# Out:
# EX_glycerol_e + nadp_c --> glyceraldehyde_c + h_c + nadph_c

# %%
### aldehyde + NAD+ + H2O = a carboxylate + NADH + H+

### Check for aldehyde
print("###### check aldehyde")
for metabolite in model.metabolites.query('aldehyde', 'name'):
    print(metabolite.name)
#not found
#add aldehyde
aldehyde_c = Metabolite(id='aldehyde_c ', compartment='c')

### Check for NAD+
print("###### check NAD+")
for metabolite in model.metabolites.query('nad', 'name'):
    print(metabolite.name)
#not found
#shortcut in model?
print(model.metabolites.nad_c)

### Check for H2O
print("###### check H2O")
for metabolite in model.metabolites.query('H2O', 'name'):
    print(metabolite.name)
## found
## check name in model
print("model: ", model.metabolites.h2o_c)

### Check for NADH
print("###### check carboxylate")
for metabolite in model.metabolites.query('carboxylate', 'name'):
    print(metabolite.name)
## found
## check name in model
print("model: ", model.metabolites.carboxylate_c)

### Check for NADH
print("###### check NADH")
for metabolite in model.metabolites.query('nadh', 'name'):
    print(metabolite.name)
#not found
#short cut in model?
print(model.metabolites.nadh_c)

### Check for  H+
### H+ already found in glycerol dehydrogenase reaction
# Out:
# ###### check aldehyde
# 5-Chloro-2-hydroxymuconic semialdehyde
# 3,4-Dihydroxymandelaldehyde
# Phenylacetaldehyde
# Betaine aldehyde
# L-Glutamate 1-semialdehyde
# D-Glyceraldehyde 3-phosphate
# Methylimidazole acetaldehyde
# Imidazole-4-acetaldehyde
# 4-Carboxy-2-hydroxymuconate semialdehyde
# Sulfoacetaldehyde
# 2-Amino-3-carboxymuconate semialdehyde
# L-Aspartate 4-semialdehyde
# Indole-3-acetaldehyde
# Gentisate aldehyde
# 3-Chloro-2-hydroxymuconic semialdehyde
# beta-Aminopropion aldehyde
# Aminoacetaldehyde
# Fluoroacetaldehyde
# Acetaldehyde
# Acetaldehyde
# 3-Methoxy-4-hydroxyphenylacetaldehyde
# (Z)-4-Hydroxyphenylacetaldehyde-oxime
# L-4-Hydroxyglutamate semialdehyde
# N-Acetyl-L-glutamate 5-semialdehyde
# L-Glutamate 5-semialdehyde
# 2-Naphthaldehyde
# 3-Chloroallyl aldehyde
# L-Lactaldehyde
# Succinate semialdehyde-thiamin diphosphate anion
# Glycolaldehyde
# 4-Hydroxymethylsalicylaldehyde
# D-Lactaldehyde
# 2-Hydroxy-5-methyl-cis,cis-muconic semialdehyde
# 2-Aminomuconate semialdehyde
# Malonate semialdehyde
# Succinic semialdehyde
# 4-Hydroxybenzaldehyde
# 5-Hydroxyindoleacetaldehyde
# 3-Methoxy-4-hydroxyphenylglycolaldehyde
# 1-Naphthaldehyde
# 3-Hydroxybenzaldehyde
# p-Tolualdehyde
# 2-Hydroxymuconate semialdehyde
# 3-Methylsalicylaldehyde
# 3,4-Dihydroxyphenylacetaldehyde
# Chloroacetaldehyde
# (S)-Methylmalonate semialdehyde
# D-Glyceraldehyde
# D-Glyceraldehyde
# 4-Hydroxyphenylacetaldehyde
# cis-3-Chloroallyl aldehyde
# 2-Methylbenzaldehyde
# Benzaldehyde
# Benzaldehyde
# 3-Methylbenzaldehyde
# ###### check NAD+
# nonadecanoic acid (C19:0)
# nonadecanoyl-ACP (C19:0 ACP)
# nad_c
# ###### check H2O
# H2O
# H2O
# H2O2
# model:  h2o_c
# ###### check carboxylate
# 2-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 2-Hydroxy-2-hydropyrone-4,6-dicarboxylate
# Urea-1-carboxylate
# L-1-Pyrroline-3-hydroxy-5-carboxylate
# 5-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# (E)-4-Oxobut-1-ene-1,2,4-tricarboxylate
# 1-Pyrroline-5-carboxylate
# carboxylate
# 2-Pyrone-4,6-dicarboxylate
# 1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate
# Cyclopropanecarboxylate
# 3-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 1-Aminocyclopropane-1-carboxylate
# 2-Hydroxyethylenedicarboxylate
# 5-Amino-4-imidazole carboxylate
# Cyclohexane-1-carboxylate
# 4-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# model:  carboxylate_c
# ###### check NADH
# nadh_c

# %%
## Add reaction glycerol dehydrogenase 
## Reaction: aldehyde + NAD+ + H2O = carboxylate + NADH + H+
Oxidoreductase = Reaction('1.2.1.3') 
Oxidoreductase.add_metabolites({aldehyde_c: -1,
                            model.metabolites.nad_c: -1,
                            model.metabolites.h2o_c: -1,
                          model.metabolites.carboxylate_c: 1,
                            model.metabolites.nadh_c: 1, 
                              model.metabolites.h_c: 1,
                              })
print(Oxidoreductase.build_reaction_string())
# Out:
# aldehyde_c  + h2o_c + nad_c --> carboxylate_c + h_c + nadh_c

# %%
### ATP + D-glycerate = ADP + 3-phospho-D-glycerate

### Check for ATP
print("###### check ATP")
for metabolite in model.metabolites.query('atp', 'name'):
    print(metabolite.name)
# found
## check name in model
print(model.metabolites.atp_c)

### Check for glycerate
print("###### check glycerate")
for metabolite in model.metabolites.query('glycerate', 'name'):
    print(metabolite.name)
# not found
# add new
glycerate_c = Metabolite(id='glycerate_c', compartment='c')

### Check for ADP
print("###### check ADP")
for metabolite in model.metabolites.query('ADP', 'name'):
    print(metabolite.name)
## found
## check name in model
print("model: ", model.metabolites.adp_c)

### Check for 3-phospho-D-glycerate
print("###### check 3-phospho-D-glycerate")
for metabolite in model.metabolites.query('3-phospho-D-glycerate', 'name'):
    print(metabolite.name)
##found in glycerate search
## check name in model
#model.metabolites.get_by_id('3gp_c')
#model.metabolites.3gp_c
#the wanted metabolite check 3-phospho-D-glycerate could be found as 3PG_c in the model through model.metabolites but no futher informations could be 
#gained with the two specific commands model.metabolites.get_by_id('3gp_c') and model.metabolites.3gp_c
#The website https://www.ebi.ac.uk/pdbe-srv/pdbechem/chemicalCompound/show/3PG also refers that the 3PG shortcut ist the right one.
#Forced solution -> add 3-phospho-D-glycerate as a new metabolite
new_3pg_c = Metabolite(id='new_3pg_c', compartment='c')
# Out:
# ###### check ATP
# atp_c
# ###### check glycerate
# 3-Phospho-D-glycerate
# 3-Phospho-D-glycerate
# ###### check ADP
# ADP-D-ribose
# dADP
# ADP-L-glycero-D-manno-heptose
# ADP-D-glycero-D-manno-heptose
# ADP
# model:  adp_c
# ###### check 3-phospho-D-glycerate

# %%
## Add reaction gTransferases 
## ATP + D-glycerate = ADP + 3-phospho-D-glycerate
Transferases = Reaction('2.7.1.31')  
Transferases.add_metabolites({model.metabolites.atp_c: -1,
                            glycerate_c: -1,
                            model.metabolites.adp_c: 1,
                            new_3pg_c: 1
                              })
print(Transferases.build_reaction_string())
# Out:
# atp_c + glycerate_c --> adp_c + new_3pg_c

# %%
####################################
#### What is the maximum production rate of PHB growing on fructose
medium = model.medium
medium
# Out:
# {'EX_fe2_e': 10.0,
#  'EX_mg2_e': 10.0,
#  'EX_pi_e': 100.0,
#  'EX_cobalt2_e': 10.0,
#  'EX_cl_e': 10.0,
#  'EX_k_e': 10.0,
#  'EX_fe3_e': 10.0,
#  'EX_so4_e': 10.0,
#  'EX_fru_e': 3.0,
#  'EX_nh4_e': 10.0,
#  'EX_na_e': 10.0,
#  'EX_o2_e': 18.5,
#  'EX_mobd_e': 10.0,
#  'EX_h2o_e': 1000.0,
#  'EX_h_e': 100.0}

# %%
#### with only fructose as C-source
with model:
    medium = model.medium
    medium ['EX_fru_e'] = 10
    model.medium = medium
    print(medium)
    model.objective = model.reactions.phb_c
    phb_production_fru = model.optimize().objective_value
    print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_fru)
    print("Theoretical max. yield [mmol-phb / mmol-fru]:", phb_production_fru / (-1*model.reactions.EX_fru_e.flux))
# Out:
# {'EX_fe2_e': 10.0, 'EX_mg2_e': 10.0, 'EX_pi_e': 100.0, 'EX_cobalt2_e': 10.0, 'EX_cl_e': 10.0, 'EX_k_e': 10.0, 'EX_fe3_e': 10.0, 'EX_so4_e': 10.0, 'EX_fru_e': 10, 'EX_nh4_e': 10.0, 'EX_na_e': 10.0, 'EX_o2_e': 18.5, 'EX_mobd_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 100.0}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\cobra\core\dictlist.py in __getattr__(self, attr)
#     451         try:
# --> 452             return DictList.get_by_id(self, attr)
#     453         except KeyError:
#
# ~\anaconda3\lib\site-packages\cobra\core\dictlist.py in get_by_id(self, id)
#      56         """return the element with a matching id"""
# ---> 57         return list.__getitem__(self, self._dict[id])
#      58
#
# KeyError: 'phb_c'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-2104034017b9> in <module>
#       5     model.medium = medium
#       6     print(medium)
# ----> 7     model.objective = model.reactions.phb_c
#       8     phb_production_fru = model.optimize().objective_value
#       9     print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_fru)
#
# ~\anaconda3\lib\site-packages\cobra\core\dictlist.py in __getattr__(self, attr)
#     452             return DictList.get_by_id(self, attr)
#     453         except KeyError:
# --> 454             raise AttributeError("DictList has no attribute or entry %s" % attr)
#     455
#     456     def __dir__(self):
#
# AttributeError: DictList has no attribute or entry phb_c

# %%
#### with only glycerol as C-source 
medium = model.medium
print(medium)
## adding glyercol to media, switching off fructose intake
medium ["EX_glycerol_e"] = 10
medium ['EX_fru_e'] = 0
print(medium)
model.objective = model.reactions.EX_pbhb_e
phb_production_gly = model.optimize().objective_value
print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_gly)
print("Theoretical max. yield [mmol-phb / mmol-phb]:", phb_production_gly / (-1*model.reactions.EX_glycerol_e.flux))

# %%
### This code doesnt work for some reason ... 
# with model:
#    medium = model.medium
 #   medium ['EX_fru_e'] = 0
  #  medium ['EX_glycerol_e'] = 10
  #  model.medium = medium
  #  print(medium)
  #  model.objective = model.reactions.EX_pbhb_e
  #  phb_production_fru = model.optimize().objective_value
  #  print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_fru)
  #  print("Theoretical max. yield [mmol-succ / mmol-ac]:", phb_production_fru / (-1*model.reactions.EX_fru_e.flux))
