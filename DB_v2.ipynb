# %%
import cobra.test
import os
from os.path import join
from cobra.io import read_sbml_model
model = cobra.io.load_json_model(join("RehMBEL1391_sbml_L3V1.json"))

# %%
#model.metabolites

# %%
####Check if it´s glycerin####
model.metabolites.gly_c
model.metabolites.gly_c.elements
###gly_c is glycine
model.metabolites.glyc3p_c
model.metabolites.glyc3p_c
###glyc3p_c is Glycerol 3-phosphate and included in the glycerol pathway
# Out:
# <Metabolite glyc3p_c at 0x7fd2ba9ce700>

# %%
for metabolite in model.metabolites.query('glycerin', 'name'):
    print(metabolite.name)

# %%
### Check for glycerol
for metabolite in model.metabolites.query('glycerol', 'name'):
    print(metabolite.name)
### No direct glycerol pathway so far
# Out:
# CDP-diacylglycerol
# D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate
# Triacylglycerol
# 1,2-Diacyl-sn-glycerol
# Phosphatidylglycerol
# Glycerophosphoglycerol
# 1-Acyl-sn-glycerol 3-phosphate
# 1-Acylglycerol
# C1-(3-Indolyl)-glycerol 3-phosphate

# %%
from cobra.io import read_sbml_model
from cobra import Reaction, Metabolite, flux_analysis
from cobra.flux_analysis import flux_variability_analysis
import pandas as pd

# %%
### TEST #### 
model.metabolites.h_c
model.metabolites.nadph_c
model.metabolites.nadp_c
model.metabolites.h2o_c
model.metabolites
# Out:
# [<Metabolite zoe_c at 0x7fd2ba873dc0>,
#  <Metabolite 3hbz_c at 0x7fd2ba873ee0>,
#  <Metabolite hco3_c at 0x7fd2ba873f40>,
#  <Metabolite actp_c at 0x7fd2ba873fa0>,
#  <Metabolite glytrna_c at 0x7fd2ba88d190>,
#  <Metabolite phaccoa_c at 0x7fd2ba88d2e0>,
#  <Metabolite 2h3mbzpyr_c at 0x7fd2ba88d1c0>,
#  <Metabolite mettrna_c at 0x7fd2ba88d490>,
#  <Metabolite ugmd_c at 0x7fd2ba88d0d0>,
#  <Metabolite adprib_c at 0x7fd2ba88d4c0>,
#  <Metabolite nicrnt_c at 0x7fd2ba88d280>,
#  <Metabolite selnp_c at 0x7fd2ba88d6d0>,
#  <Metabolite gln__L_c at 0x7fd2ba88d760>,
#  <Metabolite c170_c at 0x7fd2ba88da00>,
#  <Metabolite c2ch4cmo_c at 0x7fd2ba88d5e0>,
#  <Metabolite gln__L_e at 0x7fd2ba88dbe0>,
#  <Metabolite galctn__D_c at 0x7fd2ba88d9a0>,
#  <Metabolite trnaile_c at 0x7fd2ba88dcd0>,
#  <Metabolite dctp_c at 0x7fd2ba88db80>,
#  <Metabolite hppr_c at 0x7fd2ba88dd00>,
#  <Metabolite galctn__D_e at 0x7fd2ba88dca0>,
#  <Metabolite ps_cho_c at 0x7fd2ba88de80>,
#  <Metabolite alac__S_c at 0x7fd2ba88dee0>,
#  <Metabolite im4ac_c at 0x7fd2ba8992e0>,
#  <Metabolite peamn_c at 0x7fd2ba8991c0>,
#  <Metabolite 2m2ecoa_c at 0x7fd2ba899460>,
#  <Metabolite tetdecacid_e at 0x7fd2ba899280>,
#  <Metabolite 15dap_e at 0x7fd2ba899520>,
#  <Metabolite 15dap_c at 0x7fd2ba899400>,
#  <Metabolite tetdecacid_c at 0x7fd2ba899580>,
#  <Metabolite id3act_c at 0x7fd2ba8995e0>,
#  <Metabolite cinnm_c at 0x7fd2ba899760>,
#  <Metabolite gcarmclc_c at 0x7fd2ba899640>,
#  <Metabolite quln_c at 0x7fd2ba8997c0>,
#  <Metabolite 5ch2hmcs_c at 0x7fd2ba899820>,
#  <Metabolite 5a4ic_c at 0x7fd2ba8999a0>,
#  <Metabolite dhf_c at 0x7fd2ba8998e0>,
#  <Metabolite pppi_c at 0x7fd2ba899b20>,
#  <Metabolite 5mta_c at 0x7fd2ba899a00>,
#  <Metabolite 4hmdn_c at 0x7fd2ba899cd0>,
#  <Metabolite thcys_c at 0x7fd2ba899880>,
#  <Metabolite cdpdag_MRSA_c at 0x7fd2ba899d90>,
#  <Metabolite 3hbz_e at 0x7fd2ba899ca0>,
#  <Metabolite 4faac_c at 0x7fd2ba899ee0>,
#  <Metabolite 4nph_c at 0x7fd2ba899dc0>,
#  <Metabolite anthcoa_c at 0x7fd2ba899f40>,
#  <Metabolite cenchddd_c at 0x7fd2ba899fa0>,
#  <Metabolite 4aphdob_c at 0x7fd2ba87f160>,
#  <Metabolite fum_c at 0x7fd2ba87f040>,
#  <Metabolite amdz_c at 0x7fd2ba87f1c0>,
#  <Metabolite glycolate_e at 0x7fd2ba87f220>,
#  <Metabolite glycolate_c at 0x7fd2ba87f3a0>,
#  <Metabolite acac_e at 0x7fd2ba87f340>,
#  <Metabolite fum_e at 0x7fd2ba87f4c0>,
#  <Metabolite met__D_e at 0x7fd2ba87f520>,
#  <Metabolite acac_c at 0x7fd2ba87f6a0>,
#  <Metabolite adrn_c at 0x7fd2ba87f580>,
#  <Metabolite gam1p_c at 0x7fd2ba87f760>,
#  <Metabolite ctbtcoa_c at 0x7fd2ba87f790>,
#  <Metabolite xu5p__D_c at 0x7fd2ba87f8e0>,
#  <Metabolite met__D_c at 0x7fd2ba87f7c0>,
#  <Metabolite trnaphe_c at 0x7fd2ba87f940>,
#  <Metabolite bglycogen_c at 0x7fd2ba87f9a0>,
#  <Metabolite rdmbzi_c at 0x7fd2ba87fb20>,
#  <Metabolite 34dhmald_c at 0x7fd2ba87fb80>,
#  <Metabolite gmhep17bp_c at 0x7fd2ba87fd00>,
#  <Metabolite ac_c at 0x7fd2ba87fd60>,
#  <Metabolite 4sulcat_c at 0x7fd2ba87fee0>,
#  <Metabolite ac_e at 0x7fd2ba87fdc0>,
#  <Metabolite acala_c at 0x7fd2ba87ffa0>,
#  <Metabolite octadecacid_e at 0x7fd2ba87ffd0>,
#  <Metabolite b2coa_c at 0x7fd2ba87fa60>,
#  <Metabolite palmACP_c at 0x7fd2ba87f280>,
#  <Metabolite pe_cho_c at 0x7fd2ba8a3160>,
#  <Metabolite octadecacid_c at 0x7fd2ba8a3040>,
#  <Metabolite sql_c at 0x7fd2ba8a31c0>,
#  <Metabolite trnaser_c at 0x7fd2ba8a3100>,
#  <Metabolite pacald_c at 0x7fd2ba8a3340>,
#  <Metabolite nad_c at 0x7fd2ba8a33a0>,
#  <Metabolite cacac_c at 0x7fd2ba8a3520>,
#  <Metabolite 3flcmuc_c at 0x7fd2ba8a3400>,
#  <Metabolite 2oad_c at 0x7fd2ba8a36a0>,
#  <Metabolite HC00229_c at 0x7fd2ba8a3580>,
#  <Metabolite 2hhpdd_c at 0x7fd2ba8a3760>,
#  <Metabolite ptolat_c at 0x7fd2ba8a3640>,
#  <Metabolite HC00229_e at 0x7fd2ba8a37c0>,
#  <Metabolite 15gl_c at 0x7fd2ba8a3820>,
#  <Metabolite g3ps_c at 0x7fd2ba8a39a0>,
#  <Metabolite ppcoa_c at 0x7fd2ba8a3880>,
#  <Metabolite 16dh24checc_c at 0x7fd2ba8a3a00>,
#  <Metabolite hmnapth_c at 0x7fd2ba8a3b50>,
#  <Metabolite 2amoeccoa_c at 0x7fd2ba8a3ca0>,
#  <Metabolite micit_c at 0x7fd2ba8a3be0>,
#  <Metabolite dcyt_c at 0x7fd2ba8a3d00>,
#  <Metabolite e4p_c at 0x7fd2ba8a3d60>,
#  <Metabolite dcyt_e at 0x7fd2ba8a3e80>,
#  <Metabolite rmn_e at 0x7fd2ba8a3a60>,
#  <Metabolite cytd_e at 0x7fd2ba8a3f40>,
#  <Metabolite c141ACP_c at 0x7fd2ba8a3fa0>,
#  <Metabolite rmn_c at 0x7fd2ba8b0160>,
#  <Metabolite cytd_c at 0x7fd2ba8b0040>,
#  <Metabolite 4nphp_c at 0x7fd2ba8b0220>,
#  <Metabolite 13dpg_c at 0x7fd2ba8b0250>,
#  <Metabolite pser_c at 0x7fd2ba8b03d0>,
#  <Metabolite tol4sul_c at 0x7fd2ba8b0280>,
#  <Metabolite 3hpcoa_c at 0x7fd2ba8b0400>,
#  <Metabolite c150ACP_c at 0x7fd2ba8b0460>,
#  <Metabolite betald_c at 0x7fd2ba8b05e0>,
#  <Metabolite eig3p_c at 0x7fd2ba8b0520>,
#  <Metabolite 5apru_c at 0x7fd2ba8b0760>,
#  <Metabolite dhna_c at 0x7fd2ba8b0640>,
#  <Metabolite 2h3cbzpyr_c at 0x7fd2ba8b07c0>,
#  <Metabolite dmpp_c at 0x7fd2ba8b0820>,
#  <Metabolite lac__L_c at 0x7fd2ba8b09a0>,
#  <Metabolite crn_c at 0x7fd2ba8b0880>,
#  <Metabolite LPS_c at 0x7fd2ba8b0a60>,
#  <Metabolite guadbutn_c at 0x7fd2ba8b0940>,
#  <Metabolite gtspmd_c at 0x7fd2ba8b0b80>,
#  <Metabolite lac__L_e at 0x7fd2ba8b0be0>,
#  <Metabolite crn_e at 0x7fd2ba8b0a90>,
#  <Metabolite glu1sa_c at 0x7fd2ba8bc0d0>,
#  <Metabolite fol_c at 0x7fd2ba8bc160>,
#  <Metabolite g3p_c at 0x7fd2ba8bc190>,
#  <Metabolite trnamet_c at 0x7fd2ba8bc2e0>,
#  <Metabolite aicar_c at 0x7fd2ba8bc1c0>,
#  <Metabolite thm_c at 0x7fd2ba8bc340>,
#  <Metabolite thm_e at 0x7fd2ba8bc3a0>,
#  <Metabolite napth2ms_c at 0x7fd2ba8bc520>,
#  <Metabolite cdp4dh6doglc_c at 0x7fd2ba8bc400>,
#  <Metabolite 26dchhq_c at 0x7fd2ba8bc580>,
#  <Metabolite laminoacid_c at 0x7fd2ba8bc5e0>,
#  <Metabolite thmpp_c at 0x7fd2ba8bc760>,
#  <Metabolite 2hba_e at 0x7fd2ba8bc640>,
#  <Metabolite 2mp2coa_c at 0x7fd2ba8bc8e0>,
#  <Metabolite 2hba_c at 0x7fd2ba8bc7c0>,
#  <Metabolite 2fchdc_c at 0x7fd2ba8bc940>,
#  <Metabolite 4chphac_c at 0x7fd2ba8bc9a0>,
#  <Metabolite sbzcoa_c at 0x7fd2ba8bcb50>,
#  <Metabolite g3pe_c at 0x7fd2ba8bcb80>,
#  <Metabolite c161_c at 0x7fd2ba8bcd60>,
#  <Metabolite 24danit_c at 0x7fd2ba8bcd90>,
#  <Metabolite fe2_c at 0x7fd2ba8bcee0>,
#  <Metabolite tchrocat_c at 0x7fd2ba8bcdc0>,
#  <Metabolite fe2_e at 0x7fd2ba8bcfa0>,
#  <Metabolite BIOMASS_c at 0x7fd2ba8bcfd0>,
#  <Metabolite phe__L_c at 0x7fd2ba8d50d0>,
#  <Metabolite 25dop_c at 0x7fd2ba8d5100>,
#  <Metabolite tcynt_c at 0x7fd2ba8d5220>,
#  <Metabolite cholp_c at 0x7fd2ba8d5160>,
#  <Metabolite xylt_c at 0x7fd2ba8d5280>,
#  <Metabolite 2aobut_c at 0x7fd2ba8d52b0>,
#  <Metabolite phe__L_e at 0x7fd2ba8d53d0>,
#  <Metabolite trnaleu_c at 0x7fd2ba8d5340>,
#  <Metabolite mk_c at 0x7fd2ba8d56a0>,
#  <Metabolite dann_c at 0x7fd2ba8d5430>,
#  <Metabolite ggbap_c at 0x7fd2ba8d5730>,
#  <Metabolite protmn_c at 0x7fd2ba8d5760>,
#  <Metabolite 2pg_c at 0x7fd2ba8d5880>,
#  <Metabolite 2pg_e at 0x7fd2ba8d57c0>,
#  <Metabolite psdp_c at 0x7fd2ba8d58e0>,
#  <Metabolite 3hxkynam_c at 0x7fd2ba8d5910>,
#  <Metabolite 5hxkyn_c at 0x7fd2ba8d5a60>,
#  <Metabolite hmb4pp_c at 0x7fd2ba8d59a0>,
#  <Metabolite g3pi_c at 0x7fd2ba8d5ac0>,
#  <Metabolite 3sulmc_c at 0x7fd2ba8d5b80>,
#  <Metabolite 4ampm_c at 0x7fd2ba8d5cd0>,
#  <Metabolite lk2lipiv_c at 0x7fd2ba8d5af0>,
#  <Metabolite dpcoa_c at 0x7fd2ba8d5d60>,
#  <Metabolite cchexo_c at 0x7fd2ba8d5d90>,
#  <Metabolite thbn_c at 0x7fd2ba8d5eb0>,
#  <Metabolite val__L_c at 0x7fd2ba8d5df0>,
#  <Metabolite val__L_e at 0x7fd2ba8d5fa0>,
#  <Metabolite 3aibt_c at 0x7fd2ba8d5fd0>,
#  <Metabolite cyst__L_c at 0x7fd2ba8e2130>,
#  <Metabolite d3dg_c at 0x7fd2ba8e21c0>,
#  <Metabolite pmcoa_c at 0x7fd2ba8e2430>,
#  <Metabolite valtrna_c at 0x7fd2ba8e2370>,
#  <Metabolite succoa_c at 0x7fd2ba8e24c0>,
#  <Metabolite trnahis_c at 0x7fd2ba8e2490>,
#  <Metabolite RNA_c at 0x7fd2ba8e2610>,
#  <Metabolite thymd_c at 0x7fd2ba8e2550>,
#  <Metabolite pbng_c at 0x7fd2ba8e2670>,
#  <Metabolite 5fthf_c at 0x7fd2ba8e25e0>,
#  <Metabolite dhpt_c at 0x7fd2ba8e2790>,
#  <Metabolite 56dthm_c at 0x7fd2ba8e27c0>,
#  <Metabolite thymd_e at 0x7fd2ba8e28e0>,
#  <Metabolite mlzac_c at 0x7fd2ba8e2820>,
#  <Metabolite ala_B_c at 0x7fd2ba8e29a0>,
#  <Metabolite fadh2_c at 0x7fd2ba8e29d0>,
#  <Metabolite 3psme_c at 0x7fd2ba8e2a30>,
#  <Metabolite im4act_c at 0x7fd2ba8e2a60>,
#  <Metabolite 2h2hpd_c at 0x7fd2ba8e2bb0>,
#  <Metabolite damp_c at 0x7fd2ba8e28b0>,
#  <Metabolite dadp_c at 0x7fd2ba8e2c10>,
#  <Metabolite ala__L_c at 0x7fd2ba8e2cd0>,
#  <Metabolite seasmet_c at 0x7fd2ba8e2df0>,
#  <Metabolite ala__L_e at 0x7fd2ba8e2d30>,
#  <Metabolite udpgal_c at 0x7fd2ba8e2e50>,
#  <Metabolite Lcyst_c at 0x7fd2ba8e2f10>,
#  <Metabolite gcoa_c at 0x7fd2ba8e2dc0>,
#  <Metabolite 3flrcatech_c at 0x7fd2ba8c70a0>,
#  <Metabolite op4en_c at 0x7fd2ba8c70d0>,
#  <Metabolite hccho_c at 0x7fd2ba8c71c0>,
#  <Metabolite gagcya_c at 0x7fd2ba8c7220>,
#  <Metabolite ppp9_c at 0x7fd2ba8c73a0>,
#  <Metabolite 46dhoxquin_c at 0x7fd2ba8c7280>,
#  <Metabolite 3ophb_c at 0x7fd2ba8c7400>,
#  <Metabolite dhcinnm_c at 0x7fd2ba8c7460>,
#  <Metabolite hcys__L_c at 0x7fd2ba8c7580>,
#  <Metabolite 2hchd_c at 0x7fd2ba8c7520>,
#  <Metabolite 34dhoxpeg_c at 0x7fd2ba8c7640>,
#  <Metabolite trnatyr_c at 0x7fd2ba8c76a0>,
#  <Metabolite 5m3o4hcoa_c at 0x7fd2ba8c7850>,
#  <Metabolite pran_c at 0x7fd2ba8c7820>,
#  <Metabolite hcyst_c at 0x7fd2ba8c7940>,
#  <Metabolite protrna_c at 0x7fd2ba8c79a0>,
#  <Metabolite cchlam_c at 0x7fd2ba8c7b20>,
#  <Metabolite 3hcinnm_e at 0x7fd2ba8c7a00>,
#  <Metabolite 3hcinnm_c at 0x7fd2ba8c7b80>,
#  <Metabolite f1p_c at 0x7fd2ba8c7be0>,
#  <Metabolite q8_c at 0x7fd2ba8c7d60>,
#  <Metabolite cechddd_c at 0x7fd2ba8c7c40>,
#  <Metabolite prbamp_c at 0x7fd2ba8c7e80>,
#  <Metabolite skm_c at 0x7fd2ba8c7700>,
#  <Metabolite glutrna_c at 0x7fd2ba8c7c70>,
#  <Metabolite so3_c at 0x7fd2ba8c7e50>,
#  <Metabolite tg160_c at 0x7fd2ba8c7d30>,
#  <Metabolite didp_c at 0x7fd2ba8c7f40>,
#  <Metabolite pc_c at 0x7fd2ba8ee190>,
#  <Metabolite Largn_c at 0x7fd2ba8ee1f0>,
#  <Metabolite styrene_c at 0x7fd2ba8ee0a0>,
#  <Metabolite prpp_c at 0x7fd2ba8ee250>,
#  <Metabolite 12dgr_TB_c at 0x7fd2ba8ee280>,
#  <Metabolite bf26p_c at 0x7fd2ba8ee3d0>,
#  <Metabolite pydx_c at 0x7fd2ba8ee310>,
#  <Metabolite mg2_c at 0x7fd2ba8ee430>,
#  <Metabolite hmbil_c at 0x7fd2ba8ee4f0>,
#  <Metabolite mg2_e at 0x7fd2ba8ee6d0>,
#  <Metabolite apoACP_c at 0x7fd2ba8ee610>,
#  <Metabolite bf2p_c at 0x7fd2ba8ee730>,
#  <Metabolite 4h2ohep_c at 0x7fd2ba8ee760>,
#  <Metabolite 12anthcd_c at 0x7fd2ba8ee880>,
#  <Metabolite pg_c at 0x7fd2ba8ee7c0>,
#  <Metabolite 5mtglu_c at 0x7fd2ba8ee940>,
#  <Metabolite mnapth_c at 0x7fd2ba8ee850>,
#  <Metabolite idon__L_e at 0x7fd2ba8eea60>,
#  <Metabolite idon__L_c at 0x7fd2ba8eea90>,
#  <Metabolite npthld_c at 0x7fd2ba8eeb80>,
#  <Metabolite amob_c at 0x7fd2ba8ee550>,
#  <Metabolite ppacp_c at 0x7fd2ba8eeca0>,
#  <Metabolite up4g_c at 0x7fd2ba8ee3a0>,
#  <Metabolite aa_c at 0x7fd2ba8eed90>,
#  <Metabolite 4c2hmucsah_c at 0x7fd2ba8eecd0>,
#  <Metabolite thdp_c at 0x7fd2ba8eedf0>,
#  <Metabolite gbbtn_c at 0x7fd2ba8eee20>,
#  <Metabolite adocbip_c at 0x7fd2ba8eef10>,
#  <Metabolite 3b1a_c at 0x7fd2ba8eee80>,
#  <Metabolite u1car_c at 0x7fd2ba8eeb50>,
#  <Metabolite gbbtn_e at 0x7fd2ba8f9160>,
#  <Metabolite sulald_c at 0x7fd2ba8f91c0>,
#  <Metabolite prbatp_c at 0x7fd2ba8f90d0>,
#  <Metabolite 2dmmq8_c at 0x7fd2ba8f9250>,
#  <Metabolite trnagly_c at 0x7fd2ba8f9280>,
#  <Metabolite gallate_c at 0x7fd2ba8f9400>,
#  <Metabolite trnapro_c at 0x7fd2ba8f9310>,
#  <Metabolite cit_e at 0x7fd2ba8f9520>,
#  <Metabolite iletrna_c at 0x7fd2ba8f9460>,
#  <Metabolite cit_c at 0x7fd2ba8f9550>,
#  <Metabolite caiz_c at 0x7fd2ba8f95b0>,
#  <Metabolite s2mbdlipo_c at 0x7fd2ba8f9700>,
#  <Metabolite 2a3cms_c at 0x7fd2ba8f9640>,
#  <Metabolite fprica_c at 0x7fd2ba8f9760>,
#  <Metabolite 6pgc_c at 0x7fd2ba8f9790>,
#  <Metabolite 5aprbu_c at 0x7fd2ba8f9910>,
#  <Metabolite 2naptha_c at 0x7fd2ba8f9940>,
#  <Metabolite 3hpp_c at 0x7fd2ba8f9970>,
#  <Metabolite catechol_c at 0x7fd2ba8f9c40>,
#  <Metabolite dad_2_c at 0x7fd2ba8f9d30>,
#  <Metabolite dad_2_e at 0x7fd2ba8f9c70>,
#  <Metabolite sarcs_c at 0x7fd2ba8f9d60>,
#  <Metabolite catechol_e at 0x7fd2ba8f9dc0>,
#  <Metabolite trnaasp_c at 0x7fd2ba8f9f40>,
#  <Metabolite msalc4_c at 0x7fd2ba8f9bb0>,
#  <Metabolite ahser_c at 0x7fd2ba8f9f70>,
#  <Metabolite shser_c at 0x7fd2ba8f9820>,
#  <Metabolite nitbz_c at 0x7fd2ba904100>,
#  <Metabolite nicatol_c at 0x7fd2ba904130>,
#  <Metabolite 4c2o4pent_c at 0x7fd2ba904250>,
#  <Metabolite dhid_c at 0x7fd2ba904190>,
#  <Metabolite gtp_c at 0x7fd2ba9042e0>,
#  <Metabolite kdo8p_c at 0x7fd2ba9043d0>,
#  <Metabolite adn_e at 0x7fd2ba904310>,
#  <Metabolite u23ga_c at 0x7fd2ba904400>,
#  <Metabolite g3pg_c at 0x7fd2ba904640>,
#  <Metabolite adn_c at 0x7fd2ba904670>,
#  <Metabolite bz_c at 0x7fd2ba904550>,
#  <Metabolite glu__L_e at 0x7fd2ba9046a0>,
#  <Metabolite aspsa_c at 0x7fd2ba9047f0>,
#  <Metabolite glu__L_c at 0x7fd2ba904820>,
#  <Metabolite 3o4mp_c at 0x7fd2ba904910>,
#  <Metabolite bz_e at 0x7fd2ba904880>,
#  <Metabolite grdp_c at 0x7fd2ba904b80>,
#  <Metabolite mm_c at 0x7fd2ba904580>,
#  <Metabolite rhcys_c at 0x7fd2ba904c10>,
#  <Metabolite gly_c at 0x7fd2ba904b50>,
#  <Metabolite 4ethp_c at 0x7fd2ba904d00>,
#  <Metabolite c161ACP_c at 0x7fd2ba904cd0>,
#  <Metabolite ian_c at 0x7fd2ba904e50>,
#  <Metabolite 2omhmbl_c at 0x7fd2ba904d90>,
#  <Metabolite HC01712_c at 0x7fd2ba904f10>,
#  <Metabolite 2omph_c at 0x7fd2ba904940>,
#  <Metabolite mi_c at 0x7fd2ba904fa0>,
#  <Metabolite gly_e at 0x7fd2ba904ee0>,
#  <Metabolite 2e5mhdcoa_c at 0x7fd2ba9049a0>,
#  <Metabolite Sfglutth_c at 0x7fd2ba9110a0>,
#  <Metabolite 1ag3p_c at 0x7fd2ba9111f0>,
#  <Metabolite ethap_c at 0x7fd2ba911130>,
#  <Metabolite man1p_c at 0x7fd2ba911250>,
#  <Metabolite 5fmuclac_c at 0x7fd2ba911280>,
#  <Metabolite trnaval_c at 0x7fd2ba9113a0>,
#  <Metabolite rbflvrd_c at 0x7fd2ba9112e0>,
#  <Metabolite thmmp_c at 0x7fd2ba9116d0>,
#  <Metabolite pyam5p_c at 0x7fd2ba911520>,
#  <Metabolite pi_e at 0x7fd2ba911610>,
#  <Metabolite gsn_e at 0x7fd2ba911550>,
#  <Metabolite ctbt_c at 0x7fd2ba9116a0>,
#  <Metabolite urdglyc_c at 0x7fd2ba911a60>,
#  <Metabolite gsn_c at 0x7fd2ba911b80>,
#  <Metabolite i3aa_c at 0x7fd2ba911ac0>,
#  <Metabolite phenol_e at 0x7fd2ba911be0>,
#  <Metabolite phenol_c at 0x7fd2ba911ca0>,
#  <Metabolite tchccm_c at 0x7fd2ba911dc0>,
#  <Metabolite cchccoa_c at 0x7fd2ba911d00>,
#  <Metabolite n2o_c at 0x7fd2ba911d90>,
#  <Metabolite dopa_c at 0x7fd2ba911ee0>,
#  <Metabolite 3chccm_c at 0x7fd2ba911fd0>,
#  <Metabolite gl1coa_c at 0x7fd2ba911e50>,
#  <Metabolite pi_c at 0x7fd2ba911fa0>,
#  <Metabolite 23dhmp_c at 0x7fd2ba91b040>,
#  <Metabolite tsul_e at 0x7fd2ba91b1f0>,
#  <Metabolite acmanap_c at 0x7fd2ba91b070>,
#  <Metabolite acgam6p_c at 0x7fd2ba91b250>,
#  <Metabolite c171ACP_c at 0x7fd2ba91b280>,
#  <Metabolite tsul_c at 0x7fd2ba91b3a0>,
#  <Metabolite crtn_c at 0x7fd2ba91b370>,
#  <Metabolite malcoa_c at 0x7fd2ba91b4f0>,
#  <Metabolite l1p3h5c_c at 0x7fd2ba91b4c0>,
#  <Metabolite ugmda_c at 0x7fd2ba91b640>,
#  <Metabolite 4fmuclac_c at 0x7fd2ba91b580>,
#  <Metabolite dhptn_c at 0x7fd2ba91b6a0>,
#  <Metabolite aamppn_c at 0x7fd2ba91b6d0>,
#  <Metabolite n2_c at 0x7fd2ba91b7f0>,
#  <Metabolite hpmhmbq_c at 0x7fd2ba91b760>,
#  <Metabolite cobalt2_e at 0x7fd2ba91b9d0>,
#  <Metabolite cobalt2_c at 0x7fd2ba91b910>,
#  <Metabolite adocbi_c at 0x7fd2ba91baf0>,
#  <Metabolite acetol_c at 0x7fd2ba91ba60>,
#  <Metabolite asntrna_c at 0x7fd2ba91bc40>,
#  <Metabolite slnt_c at 0x7fd2ba91bb80>,
#  <Metabolite 3oppcoa_c at 0x7fd2ba91bca0>,
#  <Metabolite dhtolen_c at 0x7fd2ba91bdc0>,
#  <Metabolite cys__L_c at 0x7fd2ba91bf40>,
#  <Metabolite uppg3_c at 0x7fd2ba91bd90>,
#  <Metabolite 5cohe_c at 0x7fd2ba91ba30>,
#  <Metabolite tartr_c at 0x7fd2ba91bfa0>,
#  <Metabolite 2c4h6at_c at 0x7fd2ba91bcd0>,
#  <Metabolite hppp_c at 0x7fd2ba9270a0>,
#  <Metabolite adipcoa_c at 0x7fd2ba927190>,
#  <Metabolite tartr_e at 0x7fd2ba9270d0>,
#  <Metabolite uppg1_c at 0x7fd2ba927250>,
#  <Metabolite maltpt_e at 0x7fd2ba927310>,
#  <Metabolite trnalys_c at 0x7fd2ba927430>,
#  <Metabolite oaa_c at 0x7fd2ba927370>,
#  <Metabolite cdpetn_c at 0x7fd2ba927490>,
#  <Metabolite r3rhbb_c at 0x7fd2ba9274c0>,
#  <Metabolite cys__L_e at 0x7fd2ba9276d0>,
#  <Metabolite trnathr_c at 0x7fd2ba9275e0>,
#  <Metabolite pyr_e at 0x7fd2ba927700>,
#  <Metabolite 2kchccoa_c at 0x7fd2ba927730>,
#  <Metabolite cpppg1_c at 0x7fd2ba927850>,
#  <Metabolite citr__L_c at 0x7fd2ba9271f0>,
#  <Metabolite maltpt_c at 0x7fd2ba927910>,
#  <Metabolite s7p_c at 0x7fd2ba927940>,
#  <Metabolite pyr_c at 0x7fd2ba927a60>,
#  <Metabolite pheacnit_c at 0x7fd2ba9279a0>,
#  <Metabolite uaccg_c at 0x7fd2ba927520>,
#  <Metabolite idlac_c at 0x7fd2ba927a30>,
#  <Metabolite icit_c at 0x7fd2ba927bb0>,
#  <Metabolite duri_e at 0x7fd2ba927be0>,
#  <Metabolite fad_c at 0x7fd2ba927d60>,
#  <Metabolite icit_e at 0x7fd2ba927ca0>,
#  <Metabolite uaagtmda_c at 0x7fd2ba927dc0>,
#  <Metabolite gua_e at 0x7fd2ba927df0>,
#  <Metabolite 4mcat_c at 0x7fd2ba927f10>,
#  <Metabolite carbs_c at 0x7fd2ba927e50>,
#  <Metabolite 3cresol_c at 0x7fd2ba934040>,
#  <Metabolite duri_c at 0x7fd2ba934100>,
#  <Metabolite gua_c at 0x7fd2ba934280>,
#  <Metabolite homogen_c at 0x7fd2ba9342b0>,
#  <Metabolite CARBO_c at 0x7fd2ba9343d0>,
#  <Metabolite 4maac_c at 0x7fd2ba934310>,
#  <Metabolite pa_c at 0x7fd2ba934550>,
#  <Metabolite r3hbn2_c at 0x7fd2ba934580>,
#  <Metabolite galt1p_c at 0x7fd2ba9346a0>,
#  <Metabolite s2mpdlipo_c at 0x7fd2ba9345e0>,
#  <Metabolite napmsccoa_c at 0x7fd2ba934700>,
#  <Metabolite hcchccoa_c at 0x7fd2ba9347f0>,
#  <Metabolite fdp_c at 0x7fd2ba934970>,
#  <Metabolite hpyr_c at 0x7fd2ba9348e0>,
#  <Metabolite lipa_c at 0x7fd2ba9347c0>,
#  <Metabolite trnagln_c at 0x7fd2ba934a30>,
#  <Metabolite r5p_c at 0x7fd2ba934b80>,
#  <Metabolite lipoe_c at 0x7fd2ba934a90>,
#  <Metabolite acgam_e at 0x7fd2ba934c70>,
#  <Metabolite spmd_e at 0x7fd2ba934c10>,
#  <Metabolite 3oxoadp_c at 0x7fd2ba934f40>,
#  <Metabolite butanal_c at 0x7fd2ba934ca0>,
#  <Metabolite amppo_c at 0x7fd2ba934f70>,
#  <Metabolite acglu_c at 0x7fd2ba934fa0>,
#  <Metabolite seld_c at 0x7fd2ba934670>,
#  <Metabolite 5mcsn_c at 0x7fd2ba93f040>,
#  <Metabolite bzonit_c at 0x7fd2ba93f160>,
#  <Metabolite hemeO_c at 0x7fd2ba93f0a0>,
#  <Metabolite aniline_c at 0x7fd2ba93f280>,
#  <Metabolite dhnpt_c at 0x7fd2ba93f340>,
#  <Metabolite norad_c at 0x7fd2ba93f430>,
#  <Metabolite csn_c at 0x7fd2ba93f2b0>,
#  <Metabolite 2flcmuc_c at 0x7fd2ba93f580>,
#  <Metabolite salc_c at 0x7fd2ba93f3d0>,
#  <Metabolite csn_e at 0x7fd2ba93f130>,
#  <Metabolite hemeA_c at 0x7fd2ba93f610>,
#  <Metabolite 4hpro_c at 0x7fd2ba93f700>,
#  <Metabolite s_c at 0x7fd2ba93f6a0>,
#  <Metabolite dhnapthsul_c at 0x7fd2ba93f880>,
#  <Metabolite omaenol_c at 0x7fd2ba93f850>,
#  <Metabolite opp_c at 0x7fd2ba93f9a0>,
#  <Metabolite uamag_c at 0x7fd2ba93f730>,
#  <Metabolite gam6p_c at 0x7fd2ba93fa30>,
#  <Metabolite 4fchcd_c at 0x7fd2ba93fa60>,
#  <Metabolite cl_c at 0x7fd2ba93fb50>,
#  <Metabolite mtolat_c at 0x7fd2ba93fac0>,
#  <Metabolite mlt_c at 0x7fd2ba93fe80>,
#  <Metabolite cysgly_c at 0x7fd2ba93fb80>,
#  <Metabolite cl_e at 0x7fd2ba93fe20>,
#  <Metabolite HC01522_c at 0x7fd2ba93ff10>,
#  <Metabolite selcyst_c at 0x7fd2ba93f550>,
#  <Metabolite adip_e at 0x7fd2ba9492e0>,
#  <Metabolite hom__L_c at 0x7fd2ba949400>,
#  <Metabolite adip_c at 0x7fd2ba949370>,
#  <Metabolite isoppam_c at 0x7fd2ba949550>,
#  <Metabolite urocan_e at 0x7fd2ba949430>,
#  <Metabolite ump_c at 0x7fd2ba949670>,
#  <Metabolite namd_c at 0x7fd2ba949340>,
#  <Metabolite 2ommb_c at 0x7fd2ba949700>,
#  <Metabolite L_dpchrm_c at 0x7fd2ba949640>,
#  <Metabolite mlt_e at 0x7fd2ba9497f0>,
#  <Metabolite urocan_c at 0x7fd2ba9498b0>,
#  <Metabolite 24dab_c at 0x7fd2ba9499a0>,
#  <Metabolite argtrna_c at 0x7fd2ba949910>,
#  <Metabolite chhmsald_c at 0x7fd2ba949a30>,
#  <Metabolite lystrna_c at 0x7fd2ba949a60>,
#  <Metabolite cn_c at 0x7fd2ba949b80>,
#  <Metabolite thrtrna_c at 0x7fd2ba949ac0>,
#  <Metabolite 2mnapth_c at 0x7fd2ba949c40>,
#  <Metabolite 3mccoa_c at 0x7fd2ba949bb0>,
#  <Metabolite pphn_c at 0x7fd2ba949d60>,
#  <Metabolite lprot_c at 0x7fd2ba949d90>,
#  <Metabolite gam_e at 0x7fd2ba949f40>,
#  <Metabolite dttp_c at 0x7fd2ba949c70>,
#  <Metabolite h2_c at 0x7fd2ba949fd0>,
#  <Metabolite k_e at 0x7fd2ba949df0>,
#  <Metabolite mclact_e at 0x7fd2ba9620a0>,
#  <Metabolite phb_e at 0x7fd2ba962280>,
#  <Metabolite k_c at 0x7fd2ba962310>,
#  <Metabolite c151_c at 0x7fd2ba962610>,
#  <Metabolite galt_e at 0x7fd2ba962550>,
#  <Metabolite asp__L_e at 0x7fd2ba962670>,
#  <Metabolite phb_c at 0x7fd2ba9625e0>,
#  <Metabolite asp__L_c at 0x7fd2ba9628b0>,
#  <Metabolite galt_c at 0x7fd2ba962820>,
#  <Metabolite malth_e at 0x7fd2ba962910>,
#  <Metabolite mclact_c at 0x7fd2ba962940>,
#  <Metabolite dgsn_c at 0x7fd2ba962a90>,
#  <Metabolite malth_c at 0x7fd2ba962250>,
#  <Metabolite dgsn_e at 0x7fd2ba962be0>,
#  <Metabolite kdo_c at 0x7fd2ba962b20>,
#  <Metabolite bapa_c at 0x7fd2ba962cd0>,
#  <Metabolite dtdpglu_c at 0x7fd2ba9627f0>,
#  <Metabolite 4r5au_c at 0x7fd2ba962d30>,
#  <Metabolite aacald_c at 0x7fd2ba962d60>,
#  <Metabolite guadbut_c at 0x7fd2ba962e80>,
#  <Metabolite 3c2hmp_c at 0x7fd2ba962dc0>,
#  <Metabolite udcpdp_c at 0x7fd2ba962ee0>,
#  <Metabolite alltt_c at 0x7fd2ba962e50>,
#  <Metabolite 2me4p_c at 0x7fd2ba962bb0>,
#  <Metabolite c4cmbo_c at 0x7fd2ba957130>,
#  <Metabolite cbl1_e at 0x7fd2ba957070>,
#  <Metabolite c3chroc_c at 0x7fd2ba9571c0>,
#  <Metabolite met__L_e at 0x7fd2ba957280>,
#  <Metabolite phacgly_c at 0x7fd2ba9574f0>,
#  <Metabolite 3mop_c at 0x7fd2ba957430>,
#  <Metabolite cbl1_c at 0x7fd2ba9575b0>,
#  <Metabolite mmcoa__S_c at 0x7fd2ba957580>,
#  <Metabolite uri_c at 0x7fd2ba957700>,
#  <Metabolite met__L_c at 0x7fd2ba957550>,
#  <Metabolite 12dhflu_c at 0x7fd2ba957730>,
#  <Metabolite 4hoxoh_c at 0x7fd2ba957760>,
#  <Metabolite amet_c at 0x7fd2ba957880>,
#  <Metabolite hop_c at 0x7fd2ba9577c0>,
#  <Metabolite kdolipid4_c at 0x7fd2ba9578b0>,
#  <Metabolite 5fchdc_c at 0x7fd2ba9579d0>,
#  <Metabolite cbp_c at 0x7fd2ba957b20>,
#  <Metabolite flald_c at 0x7fd2ba957a30>,
#  <Metabolite forant_c at 0x7fd2ba9578e0>,
#  <Metabolite fe3_e at 0x7fd2ba957e50>,
#  <Metabolite 2h4hmbnpyr_c at 0x7fd2ba957fa0>,
#  <Metabolite cynt_e at 0x7fd2ba957ee0>,
#  <Metabolite cyanr_c at 0x7fd2ba957f70>,
#  <Metabolite 5mh4ecoa_c at 0x7fd2ba957850>,
#  <Metabolite fe3_c at 0x7fd2ba9571f0>,
#  <Metabolite cynt_c at 0x7fd2ba96e040>,
#  <Metabolite uri_e at 0x7fd2ba96e190>,
#  <Metabolite 5prdmbz_c at 0x7fd2ba96e0d0>,
#  <Metabolite idp_c at 0x7fd2ba96e1f0>,
#  <Metabolite ckdo_c at 0x7fd2ba96e160>,
#  <Metabolite prlp_c at 0x7fd2ba96e310>,
#  <Metabolite itcn_c at 0x7fd2ba96e340>,
#  <Metabolite lipidA_c at 0x7fd2ba96e460>,
#  <Metabolite 2hohphd_c at 0x7fd2ba96e370>,
#  <Metabolite hpimcoa_c at 0x7fd2ba96e5b0>,
#  <Metabolite c120_c at 0x7fd2ba96e5e0>,
#  <Metabolite ammld_c at 0x7fd2ba96e490>,
#  <Metabolite chcatol_c at 0x7fd2ba96e670>,
#  <Metabolite succ_e at 0x7fd2ba96e970>,
#  <Metabolite succ_c at 0x7fd2ba96e7f0>,
#  <Metabolite itp_c at 0x7fd2ba96e9d0>,
#  <Metabolite 4mhetz_c at 0x7fd2ba96ea00>,
#  <Metabolite 3hmrsACP_c at 0x7fd2ba96eb20>,
#  <Metabolite 3vcat_c at 0x7fd2ba96ea60>,
#  <Metabolite 4hbt_e at 0x7fd2ba96eb80>,
#  <Metabolite cdpmde_c at 0x7fd2ba96eaf0>,
#  <Metabolite 4hbt_c at 0x7fd2ba96eeb0>,
#  <Metabolite napomsuccoa_c at 0x7fd2ba96edf0>,
#  <Metabolite glcur_c at 0x7fd2ba96ef70>,
#  <Metabolite ahcys_c at 0x7fd2ba96ef40>,
#  <Metabolite 2dhp_c at 0x7fd2ba96e730>,
#  <Metabolite aptrc_c at 0x7fd2ba96eca0>,
#  <Metabolite 12ppd__R_c at 0x7fd2ba96ebb0>,
#  <Metabolite Nforglu_c at 0x7fd2ba97a100>,
#  <Metabolite glcur_e at 0x7fd2ba97a130>,
#  <Metabolite sbt__D_c at 0x7fd2ba97a0d0>,
#  <Metabolite sbt__D_e at 0x7fd2ba97a430>,
#  <Metabolite 6hcecoa_c at 0x7fd2ba97a460>,
#  <Metabolite ribflav_c at 0x7fd2ba97a580>,
#  <Metabolite 3h2napth_c at 0x7fd2ba97a4c0>,
#  <Metabolite 4ppan_c at 0x7fd2ba97a550>,
#  <Metabolite acald_c at 0x7fd2ba97a6a0>,
#  <Metabolite ascb6p_c at 0x7fd2ba97a790>,
#  <Metabolite acald_e at 0x7fd2ba97a730>,
#  <Metabolite tre_e at 0x7fd2ba97a880>,
#  <Metabolite dcamp_c at 0x7fd2ba97a7c0>,
#  <Metabolite c3chp_c at 0x7fd2ba97a9a0>,
#  <Metabolite selmeth_c at 0x7fd2ba97a610>,
#  <Metabolite spmd_c at 0x7fd2ba97ab20>,
#  <Metabolite tre_c at 0x7fd2ba97a850>,
#  <Metabolite nadh_c at 0x7fd2ba97abb0>,
#  <Metabolite kdpg_c at 0x7fd2ba97abe0>,
#  <Metabolite gensa_c at 0x7fd2ba97ad00>,
#  <Metabolite gensa_e at 0x7fd2ba97ad30>,
#  <Metabolite ddm_c at 0x7fd2ba97af10>,
#  <Metabolite acgam1p_c at 0x7fd2ba97ac40>,
#  <Metabolite no2_e at 0x7fd2ba97afa0>,
#  <Metabolite urea_e at 0x7fd2ba97a970>,
#  <Metabolite 4aabut_c at 0x7fd2ba97aca0>,
#  <Metabolite no2_c at 0x7fd2ba97afd0>,
#  <Metabolite 246tchph_c at 0x7fd2ba986160>,
#  <Metabolite 6fchdc_c at 0x7fd2ba9860a0>,
#  <Metabolite PHOSPHOLIPID_c at 0x7fd2ba9861c0>,
#  <Metabolite 3mox4hpac_c at 0x7fd2ba9861f0>,
#  <Metabolite leutrna_c at 0x7fd2ba986310>,
#  <Metabolite 2dr1p_c at 0x7fd2ba986250>,
#  <Metabolite pythp_c at 0x7fd2ba9862e0>,
#  <Metabolite sbt6p_c at 0x7fd2ba986730>,
#  <Metabolite glc__D_c at 0x7fd2ba986820>,
#  <Metabolite agl_c at 0x7fd2ba9866a0>,
#  <Metabolite urea_c at 0x7fd2ba986910>,
#  <Metabolite acser_c at 0x7fd2ba986ac0>,
#  <Metabolite 2dhglcn6p_c at 0x7fd2ba986be0>,
#  <Metabolite pppg9_c at 0x7fd2ba986b20>,
#  <Metabolite 4hpheacoa_c at 0x7fd2ba986c40>,
#  <Metabolite ht5p_c at 0x7fd2ba986c70>,
#  <Metabolite scl_c at 0x7fd2ba986dc0>,
#  <Metabolite pheth910o_c at 0x7fd2ba986d00>,
#  <Metabolite ade_e at 0x7fd2ba986e20>,
#  <Metabolite 2hohphod_c at 0x7fd2ba986d90>,
#  <Metabolite flac_c at 0x7fd2ba986f10>,
#  <Metabolite ade_c at 0x7fd2ba9867f0>,
#  <Metabolite hsulpob_c at 0x7fd2ba986f40>,
#  <Metabolite gp4g_c at 0x7fd2ba992070>,
#  <Metabolite dudp_c at 0x7fd2ba9921c0>,
#  <Metabolite meli_c at 0x7fd2ba992100>,
#  <Metabolite arbt_c at 0x7fd2ba992280>,
#  <Metabolite meli_e at 0x7fd2ba992250>,
#  <Metabolite z4hphea_c at 0x7fd2ba9923d0>,
#  <Metabolite propen_c at 0x7fd2ba992310>,
#  <Metabolite ura_c at 0x7fd2ba992430>,
#  <Metabolite ascb__L_e at 0x7fd2ba992460>,
#  <Metabolite acACP_c at 0x7fd2ba992580>,
#  <Metabolite dad_5_c at 0x7fd2ba992520>,
#  <Metabolite 22bhpp_c at 0x7fd2ba992820>,
#  <Metabolite ura_e at 0x7fd2ba992880>,
#  <Metabolite pnpq_c at 0x7fd2ba9929d0>,
#  <Metabolite gdpddman_c at 0x7fd2ba992910>,
#  <Metabolite anthr910d_c at 0x7fd2ba992a30>,
#  <Metabolite glntrna_c at 0x7fd2ba992a60>,
#  <Metabolite 4hglusa_c at 0x7fd2ba992b80>,
#  <Metabolite gal_c at 0x7fd2ba992ac0>,
#  <Metabolite tym_c at 0x7fd2ba9925b0>,
#  <Metabolite uaagmda_c at 0x7fd2ba992b20>,
#  <Metabolite asn__L_e at 0x7fd2ba992df0>,
#  <Metabolite 2mac_c at 0x7fd2ba992d60>,
#  <Metabolite sl26da_c at 0x7fd2ba992f40>,
#  <Metabolite asn__L_c at 0x7fd2ba992e80>,
#  <Metabolite 6hidlac_c at 0x7fd2ba99e490>,
#  <Metabolite 6hnld_c at 0x7fd2ba99e520>,
#  <Metabolite iasp_c at 0x7fd2ba99e730>,
#  <Metabolite formt_c at 0x7fd2ba99e640>,
#  <Metabolite 4abutn_c at 0x7fd2ba99e820>,
#  <Metabolite hbzal_c at 0x7fd2ba99e5b0>,
#  <Metabolite methf_c at 0x7fd2ba99e880>,
#  <Metabolite phentrc_c at 0x7fd2ba99e790>,
#  <Metabolite pap_c at 0x7fd2ba99e910>,
#  <Metabolite pep_c at 0x7fd2ba99e9d0>,
#  <Metabolite xp4g_c at 0x7fd2ba99eaf0>,
#  <Metabolite 14hpeth_c at 0x7fd2ba99ea30>,
#  <Metabolite altrn_c at 0x7fd2ba99eb50>,
#  <Metabolite ipdp_c at 0x7fd2ba99eca0>,
#  <Metabolite uamr_c at 0x7fd2ba99edc0>,
#  <Metabolite gdpmann_c at 0x7fd2ba99ed00>,
#  <Metabolite nicrns_c at 0x7fd2ba99ee20>,
#  <Metabolite 4obtc_c at 0x7fd2ba99eee0>,
#  <Metabolite glycogen_c at 0x7fd2ba99efd0>,
#  <Metabolite histd_c at 0x7fd2ba99ee50>,
#  <Metabolite his__L_e at 0x7fd2ba99ef70>,
#  <Metabolite his__L_c at 0x7fd2ba9ab130>,
#  <Metabolite g6p_c at 0x7fd2ba9ab220>,
#  <Metabolite acg5sa_c at 0x7fd2ba9ab160>,
#  <Metabolite pram_c at 0x7fd2ba9ab280>,
#  <Metabolite 6hhn_c at 0x7fd2ba9ab2b0>,
#  <Metabolite trptrna_c at 0x7fd2ba9ab3d0>,
#  <Metabolite t3chc_c at 0x7fd2ba9ab310>,
#  <Metabolite e3mmal_c at 0x7fd2ba9ab460>,
#  <Metabolite 3mob_c at 0x7fd2ba9ab490>,
#  <Metabolite g6p_e at 0x7fd2ba9ab5b0>,
#  <Metabolite hochphhd_c at 0x7fd2ba9ab520>,
#  <Metabolite 1btol_c at 0x7fd2ba9ab790>,
#  <Metabolite 1btol_e at 0x7fd2ba9ab6d0>,
#  <Metabolite ins_e at 0x7fd2ba9ab7f0>,
#  <Metabolite ins_c at 0x7fd2ba9ab760>,
#  <Metabolite oxadpcoa_c at 0x7fd2ba9ab910>,
#  <Metabolite dmlz_c at 0x7fd2ba9ab940>,
#  <Metabolite glu5sa_c at 0x7fd2ba9abaf0>,
#  <Metabolite phetrna_c at 0x7fd2ba9aba00>,
#  <Metabolite pppn_e at 0x7fd2ba9abb80>,
#  <Metabolite 23doddt_c at 0x7fd2ba9b5220>,
#  <Metabolite pppn_c at 0x7fd2ba9b5250>,
#  <Metabolite hpheac_c at 0x7fd2ba9b53d0>,
#  <Metabolite ala__D_c at 0x7fd2ba9b5640>,
#  <Metabolite 2mahmp_c at 0x7fd2ba9b5400>,
#  <Metabolite ala__D_e at 0x7fd2ba9b5520>,
#  <Metabolite omcmc_c at 0x7fd2ba9b5700>,
#  <Metabolite c34dhphe_c at 0x7fd2ba9b57f0>,
#  <Metabolite din_e at 0x7fd2ba9b5730>,
#  <Metabolite c171_c at 0x7fd2ba9b5670>,
#  <Metabolite grxox_c at 0x7fd2ba9b57c0>,
#  <Metabolite din_c at 0x7fd2ba9b5970>,
#  <Metabolite acmana_e at 0x7fd2ba9b59a0>,
#  <Metabolite butn_c at 0x7fd2ba9b5be0>,
#  <Metabolite butn_e at 0x7fd2ba9b5430>,
#  <Metabolite 2hmc_c at 0x7fd2ba9b5c40>,
#  <Metabolite udpacgal_c at 0x7fd2ba9b5c70>,
#  <Metabolite ccppccoa_c at 0x7fd2ba9b52e0>,
#  <Metabolite adlipo_c at 0x7fd2ba9b5cd0>,
#  <Metabolite mlttr_c at 0x7fd2ba9b5e20>,
#  <Metabolite u3aga_c at 0x7fd2ba9b5df0>,
#  <Metabolite mlttr_e at 0x7fd2ba9b5fa0>,
#  <Metabolite acmana_c at 0x7fd2ba9b5d60>,
#  <Metabolite 4adcho_c at 0x7fd2ba9b5e80>,
#  <Metabolite aps_c at 0x7fd2ba9c0040>,
#  <Metabolite acha_c at 0x7fd2ba9c01f0>,
#  <Metabolite hcl_c at 0x7fd2ba9c0220>,
#  <Metabolite accoa_c at 0x7fd2ba9c0370>,
#  <Metabolite tag6p__D_c at 0x7fd2ba9c0280>,
#  <Metabolite agdpcbi_c at 0x7fd2ba9c0400>,
#  <Metabolite 8aonn_c at 0x7fd2ba9c03d0>,
#  <Metabolite gthrd_c at 0x7fd2ba9c0550>,
#  <Metabolite dtdp4d6dm_c at 0x7fd2ba9c0490>,
#  <Metabolite 12ppd__S_c at 0x7fd2ba9c05b0>,
#  <Metabolite paps_c at 0x7fd2ba9c0520>,
#  <Metabolite 12ppd__S_e at 0x7fd2ba9c06d0>,
#  <Metabolite 1pyr5c_c at 0x7fd2ba9c0700>,
#  <Metabolite 2obut_c at 0x7fd2ba9c08b0>,
#  <Metabolite 2obut_e at 0x7fd2ba9c05e0>,
#  <Metabolite 3aib_c at 0x7fd2ba9c0940>,
#  <Metabolite dchrooe_c at 0x7fd2ba9c0970>,
#  <Metabolite dtdpgal_c at 0x7fd2ba9c0a90>,
#  <Metabolite glyc__R_c at 0x7fd2ba9c09d0>,
#  <Metabolite so4_c at 0x7fd2ba9c0af0>,
#  <Metabolite so4_e at 0x7fd2ba9c0b20>,
#  <Metabolite 3moxtyr_c at 0x7fd2ba9c0c40>,
#  <Metabolite 2napald_c at 0x7fd2ba9c0b80>,
#  <Metabolite coadip_c at 0x7fd2ba9c0d00>,
#  <Metabolite thf_c at 0x7fd2ba9c0d90>,
#  <Metabolite nac_e at 0x7fd2ba9c0eb0>,
#  <Metabolite ile__L_c at 0x7fd2ba9c0df0>,
#  <Metabolite dtdprmn_c at 0x7fd2ba9c0f10>,
#  <Metabolite ile__L_e at 0x7fd2ba9c0f40>,
#  <Metabolite 4hthr_c at 0x7fd2ba9c0fa0>,
#  <Metabolite 3c4mop_c at 0x7fd2ba9ce160>,
#  <Metabolite dchdchche_c at 0x7fd2ba9ce1c0>,
#  <Metabolite utp_c at 0x7fd2ba9ce340>,
#  <Metabolite nac_c at 0x7fd2ba9ce4c0>,
#  <Metabolite 3chroald_c at 0x7fd2ba9ce2e0>,
#  <Metabolite 5hxkynam_c at 0x7fd2ba9ce520>,
#  <Metabolite r15bp_c at 0x7fd2ba9ce550>,
#  <Metabolite hxsp_c at 0x7fd2ba9ce640>,
#  <Metabolite alatrna_c at 0x7fd2ba9ce580>,
#  <Metabolite glyc3p_c at 0x7fd2ba9ce700>,
#  <Metabolite glyc3p_e at 0x7fd2ba9ce6d0>,
#  <Metabolite ccpam_c at 0x7fd2ba9ce850>,
#  <Metabolite dnad_c at 0x7fd2ba9ce6a0>,
#  <Metabolite 3but_c at 0x7fd2ba9ce670>,
#  <Metabolite adphep_LD_c at 0x7fd2ba9ce910>,
#  <Metabolite ap4a_c at 0x7fd2ba9cea00>,
#  <Metabolite benzcoa_c at 0x7fd2ba9ce9a0>,
#  <Metabolite 4hmsial_c at 0x7fd2ba9cec40>,
#  <Metabolite hf_c at 0x7fd2ba9ce940>,
#  <Metabolite prfp_c at 0x7fd2ba9ced60>,
#  <Metabolite 10fthf_c at 0x7fd2ba9cebb0>,
#  <Metabolite 3hib_c at 0x7fd2ba9cee80>,
#  <Metabolite 3hmcat_c at 0x7fd2ba9ced90>,
#  <Metabolite 1h2nap_c at 0x7fd2ba9ceeb0>,
#  <Metabolite 26dap_LL_c at 0x7fd2ba9ceee0>,
#  <Metabolite orn_c at 0x7fd2ba9cefd0>,
#  <Metabolite mhista_c at 0x7fd2ba9cefa0>,
#  <Metabolite 34dhpheac_c at 0x7fd2ba9d82b0>,
#  <Metabolite orn_e at 0x7fd2ba9d80a0>,
#  <Metabolite tol_e at 0x7fd2ba9d8430>,
#  <Metabolite tol_c at 0x7fd2ba9d8340>,
#  <Metabolite 2mcit_c at 0x7fd2ba9d8520>,
#  <Metabolite heppp_c at 0x7fd2ba9d8490>,
#  <Metabolite gdptp_c at 0x7fd2ba9d8670>,
#  <Metabolite PEPTIDO_c at 0x7fd2ba9d85b0>,
#  <Metabolite dscl_c at 0x7fd2ba9d86d0>,
#  <Metabolite 4sullac_c at 0x7fd2ba9d8700>,
#  <Metabolite srb1p_c at 0x7fd2ba9d8820>,
#  <Metabolite arg__L_e at 0x7fd2ba9d8760>,
#  <Metabolite lald__L_c at 0x7fd2ba9d8880>,
#  <Metabolite arg__L_c at 0x7fd2ba9d8940>,
#  <Metabolite 4ahmmp_c at 0x7fd2ba9d8a60>,
#  <Metabolite c141_c at 0x7fd2ba9d89d0>,
#  <Metabolite urate_c at 0x7fd2ba9d8ac0>,
#  <Metabolite histrna_c at 0x7fd2ba9d8af0>,
#  <Metabolite ssaltpp_c at 0x7fd2ba9d8c40>,
#  <Metabolite malte_c at 0x7fd2ba9d8b20>,
#  <Metabolite co1dam_c at 0x7fd2ba9d8ca0>,
#  <Metabolite acnam_c at 0x7fd2ba9d8c10>,
#  <Metabolite 3hpppn_e at 0x7fd2ba9d8ee0>,
#  <Metabolite 3hpppn_c at 0x7fd2ba9d8f10>,
#  <Metabolite acnam_e at 0x7fd2ba9d8040>,
#  <Metabolite fpram_c at 0x7fd2ba9d8f70>,
#  <Metabolite 3h5ohcoa_c at 0x7fd2ba9d8d00>,
#  <Metabolite aso3_c at 0x7fd2ba9e50d0>,
#  <Metabolite aso3_e at 0x7fd2ba9e5250>,
#  <Metabolite citnlcoa_c at 0x7fd2ba9e5070>,
#  <Metabolite thr__L_c at 0x7fd2ba9e5280>,
#  <Metabolite udp_c at 0x7fd2ba9e52b0>,
#  <Metabolite thr__L_e at 0x7fd2ba9e53d0>,
#  <Metabolite acorn_c at 0x7fd2ba9e53a0>,
#  <Metabolite k2lipiv_c at 0x7fd2ba9e5520>,
#  <Metabolite sel_c at 0x7fd2ba9e54f0>,
#  <Metabolite fru_e at 0x7fd2ba9e5670>,
#  <Metabolite ppap_c at 0x7fd2ba9e55b0>,
#  <Metabolite fru_c at 0x7fd2ba9e56d0>,
#  <Metabolite 2mm__R_c at 0x7fd2ba9e5700>,
#  <Metabolite dgtp_c at 0x7fd2ba9e57f0>,
#  <Metabolite 5mthf_c at 0x7fd2ba9e5820>,
#  <Metabolite gcald_c at 0x7fd2ba9e5940>,
#  <Metabolite akg_c at 0x7fd2ba9e5880>,
#  <Metabolite 3hbcoa_c at 0x7fd2ba9e5910>,
#  <Metabolite 7m3o6ocoa_c at 0x7fd2ba9e5a60>,
#  <Metabolite lipidX_c at 0x7fd2ba9e5b50>,
#  <Metabolite c34dhdhf_c at 0x7fd2ba9e59d0>,
#  <Metabolite nacyllaminoacid_c at 0x7fd2ba9e5bb0>,
#  <Metabolite fuc__L_e at 0x7fd2ba9e5be0>,
#  <Metabolite carboxylate_c at 0x7fd2ba9e5d00>,
#  <Metabolite fuc__L_c at 0x7fd2ba9e5cd0>,
#  <Metabolite applp_c at 0x7fd2ba9e5f10>,
#  <Metabolite dlipop_c at 0x7fd2ba9e5c40>,
#  <Metabolite hatrz_c at 0x7fd2ba9e5fa0>,
#  <Metabolite mlthf_c at 0x7fd2ba9e5ee0>,
#  <Metabolite 2naptcoa_c at 0x7fd2ba9e5fd0>,
#  <Metabolite 4hmscald_c at 0x7fd2ba9ef070>,
#  <Metabolite HC01668_c at 0x7fd2ba9ef1f0>,
#  <Metabolite lald__D_c at 0x7fd2ba9ef250>,
#  <Metabolite malACP_c at 0x7fd2ba9ef370>,
#  <Metabolite 4hlmdnit_c at 0x7fd2ba9ef3a0>,
#  <Metabolite hmccms_c at 0x7fd2ba9ef580>,
#  <Metabolite rib__D_c at 0x7fd2ba9ef4c0>,
#  <Metabolite udpg_c at 0x7fd2ba9ef5e0>,
#  <Metabolite rib__D_e at 0x7fd2ba9ef610>,
#  <Metabolite glyc_c at 0x7fd2ba9ef730>,
#  <Metabolite glyc_e at 0x7fd2ba9ef760>,
#  <Metabolite no_c at 0x7fd2ba9ef9a0>,
#  <Metabolite lipidAds_c at 0x7fd2ba9ef9d0>,
#  <Metabolite 4met2obut_c at 0x7fd2ba9efaf0>,
#  <Metabolite carpcoa_c at 0x7fd2ba9efa30>,
#  <Metabolite metp_c at 0x7fd2ba9ef0a0>,
#  <Metabolite grxrd_c at 0x7fd2ba9efc10>,
#  <Metabolite normete__L_c at 0x7fd2ba9efd60>,
#  <Metabolite 2ippm_c at 0x7fd2ba9efd30>,
#  <Metabolite cbasp_c at 0x7fd2ba9efeb0>,
#  <Metabolite 2mppacoa_c at 0x7fd2ba9efdf0>,
#  <Metabolite 4pasp_c at 0x7fd2ba9eff10>,
#  <Metabolite hodhiybe_c at 0x7fd2ba9eff40>,
#  <Metabolite ccmuc_c at 0x7fd2ba9ef670>,
#  <Metabolite ccmuc_e at 0x7fd2ba9eff70>,
#  <Metabolite aobzac_e at 0x7fd2ba9ef6a0>,
#  <Metabolite pantcys_c at 0x7fd2ba9fb070>,
#  <Metabolite hgcoa_c at 0x7fd2ba9fb220>,
#  <Metabolite air_c at 0x7fd2ba9fb130>,
#  <Metabolite dhpmp_c at 0x7fd2ba9fb2b0>,
#  <Metabolite 3hmbcoa_c at 0x7fd2ba9fb190>,
#  <Metabolite carccm_c at 0x7fd2ba9fb3d0>,
#  <Metabolite dgdp_c at 0x7fd2ba9fb400>,
#  <Metabolite glu5p_c at 0x7fd2ba9fb7c0>,
#  <Metabolite 2py46dc_c at 0x7fd2ba9fb490>,
#  <Metabolite 2h6ot_c at 0x7fd2ba9fb820>,
#  <Metabolite galct__D_c at 0x7fd2ba9fb880>,
#  <Metabolite ctp_c at 0x7fd2ba9fb9d0>,
#  <Metabolite galct__D_e at 0x7fd2ba9fba00>,
#  <Metabolite PROTEIN_c at 0x7fd2ba9fbb20>,
#  <Metabolite e4hglu_c at 0x7fd2ba9fbb50>,
#  <Metabolite alaala_c at 0x7fd2ba9fbcd0>,
#  <Metabolite dgmp_c at 0x7fd2ba9fbc10>,
#  <Metabolite 3pg_e at 0x7fd2ba9fbd30>,
#  <Metabolite 3pg_c at 0x7fd2ba9fbd60>,
#  <Metabolite spm_c at 0x7fd2ba9fbe80>,
#  <Metabolite 3mhdd_c at 0x7fd2ba9fbe50>,
#  <Metabolite igly_c at 0x7fd2ba9fbfd0>,
#  <Metabolite hodhiyb2e_c at 0x7fd2ba9fbfa0>,
#  <Metabolite pro__L_c at 0x7fd2ba9fb910>,
#  <Metabolite 4chbenz_c at 0x7fd2baa07040>,
#  <Metabolite thym_c at 0x7fd2baa07190>,
#  <Metabolite r1p_c at 0x7fd2baa070d0>,
#  <Metabolite 2cpr5p_c at 0x7fd2baa071c0>,
#  <Metabolite bzop_c at 0x7fd2baa07160>,
#  <Metabolite agm_c at 0x7fd2baa07550>,
#  <Metabolite 26dchp_c at 0x7fd2baa07400>,
#  <Metabolite dtdp_c at 0x7fd2baa075e0>,
#  <Metabolite nmn_e at 0x7fd2baa07520>,
#  <Metabolite 5cmhm_c at 0x7fd2baa07640>,
#  <Metabolite phatol_c at 0x7fd2baa07670>,
#  <Metabolite dcmp_c at 0x7fd2baa077c0>,
#  <Metabolite 23dhmb_c at 0x7fd2baa07790>,
#  <Metabolite nmn_c at 0x7fd2baa07910>,
#  <Metabolite 35cgmp_c at 0x7fd2baa07850>,
#  <Metabolite aeioh_c at 0x7fd2baa07970>,
#  <Metabolite 2dda7p_c at 0x7fd2baa079a0>,
#  <Metabolite so2_c at 0x7fd2baa07ac0>,
#  <Metabolite 2mm_c at 0x7fd2baa07730>,
#  <Metabolite forkn_c at 0x7fd2baa07b80>,
#  <Metabolite ph_c at 0x7fd2baa07a90>,
#  <Metabolite 12bhpp_c at 0x7fd2baa07ca0>,
#  <Metabolite aobzac_c at 0x7fd2baa07cd0>,
#  <Metabolite ara5p_c at 0x7fd2baa07df0>,
#  <Metabolite dhap_c at 0x7fd2baa07d30>,
#  <Metabolite 2amcs_c at 0x7fd2baa07e50>,
#  <Metabolite hivcoa_c at 0x7fd2baa07e80>,
#  <Metabolite 4abut_c at 0x7fd2baa07fa0>,
#  <Metabolite c160_c at 0x7fd2baa07ee0>,
#  <Metabolite i3ac_c at 0x7fd2baa140d0>,
#  <Metabolite citnl_c at 0x7fd2baa14100>,
#  <Metabolite msa_c at 0x7fd2baa14220>,
#  <Metabolite dxyl5p_c at 0x7fd2baa14160>,
#  <Metabolite cpppg3_c at 0x7fd2baa14280>,
#  <Metabolite 25drapp_c at 0x7fd2baa14370>,
#  <Metabolite mnl1p_c at 0x7fd2baa14670>,
#  <Metabolite xyl__D_c at 0x7fd2baa145b0>,
#  <Metabolite 4abut_e at 0x7fd2baa148e0>,
#  <Metabolite gcys_c at 0x7fd2baa142b0>,
#  <Metabolite 4mmclac_c at 0x7fd2baa14970>,
#  <Metabolite pro__L_e at 0x7fd2baa148b0>,
#  <Metabolite fmn_c at 0x7fd2baa149d0>,
#  <Metabolite sucsal_c at 0x7fd2baa14a90>,
#  <Metabolite tyrtrna_c at 0x7fd2baa14c40>,
#  <Metabolite 3rbleu_c at 0x7fd2baa14b80>,
#  <Metabolite arab__L_c at 0x7fd2baa14ca0>,
#  <Metabolite arab__L_e at 0x7fd2baa14cd0>,
#  <Metabolite 2maaccoa_c at 0x7fd2baa14dc0>,
#  <Metabolite 23bhpp_c at 0x7fd2baa14d30>,
#  <Metabolite hpmmbq_c at 0x7fd2baa14e80>,
#  <Metabolite dcdp_c at 0x7fd2baa14d60>,
#  <Metabolite cair_c at 0x7fd2baa14ee0>,
#  <Metabolite 56dhu_c at 0x7fd2baa14fa0>,
#  <Metabolite parax_c at 0x7fd2baa14f10>,
#  <Metabolite 4hbald_c at 0x7fd2baa20100>,
#  <Metabolite hmgth_c at 0x7fd2baa20190>,
#  <Metabolite saicar_c at 0x7fd2baa20370>,
#  <Metabolite 5co46dp_c at 0x7fd2baa202b0>,
#  <Metabolite for_c at 0x7fd2baa203d0>,
#  <Metabolite datp_c at 0x7fd2baa20400>,
#  <Metabolite 3hadpcoa_c at 0x7fd2baa20550>,
#  <Metabolite for_e at 0x7fd2baa20460>,
#  <Metabolite c160_e at 0x7fd2baa204c0>,
#  <Metabolite etha_c at 0x7fd2baa205e0>,
#  <Metabolite 48dhoxquin_c at 0x7fd2baa20160>,
#  <Metabolite 4hphac_c at 0x7fd2baa20580>,
#  <Metabolite M02451_c at 0x7fd2baa20730>,
#  <Metabolite 4aanit_c at 0x7fd2baa20760>,
#  <Metabolite gmp_c at 0x7fd2baa20880>,
#  <Metabolite 4hphac_e at 0x7fd2baa208e0>,
#  <Metabolite ohchtcht_c at 0x7fd2baa20ac0>,
#  <Metabolite seahcys_c at 0x7fd2baa20be0>,
#  <Metabolite trnacys_c at 0x7fd2baa20cd0>,
#  <Metabolite ahdt_c at 0x7fd2baa20c10>,
#  <Metabolite M02451_e at 0x7fd2baa20e20>,
#  <Metabolite idpyr_c at 0x7fd2baa20d90>,
#  <Metabolite uacgam_c at 0x7fd2baa20e80>,
#  <Metabolite hophd_c at 0x7fd2baa20f40>,
#  <Metabolite pac_c at 0x7fd2baa20d60>,
#  <Metabolite pac_e at 0x7fd2baa20eb0>,
#  <Metabolite chor_c at 0x7fd2baa20fd0>,
#  <Metabolite bzaccoa_c at 0x7fd2baa2c0a0>,
#  <Metabolite fsalac_c at 0x7fd2baa2c1c0>,
#  <Metabolite fuc1p__L_c at 0x7fd2baa2c130>,
#  <Metabolite lgt_s_c at 0x7fd2baa2c310>,
#  <Metabolite fuc1p__L_e at 0x7fd2baa2c250>,
#  <Metabolite phthr_c at 0x7fd2baa2c370>,
#  <Metabolite cyaala_c at 0x7fd2baa2c100>,
#  <Metabolite selcys_c at 0x7fd2baa2c490>,
#  <Metabolite nh4_e at 0x7fd2baa2c460>,
#  <Metabolite bhb_e at 0x7fd2baa2c5b0>,
#  <Metabolite oohoch_c at 0x7fd2baa2c640>,
#  <Metabolite nh4_c at 0x7fd2baa2c760>,
#  <Metabolite bhb_c at 0x7fd2baa2c670>,
#  <Metabolite acg5p_c at 0x7fd2baa2c7c0>,
#  <Metabolite ccpamd_c at 0x7fd2baa2c7f0>,
#  <Metabolite slfcys_c at 0x7fd2baa2c910>,
#  <Metabolite 4chcat_c at 0x7fd2baa2c880>,
#  <Metabolite camp_c at 0x7fd2baa2cb50>,
#  <Metabolite q8h2_c at 0x7fd2baa2c9d0>,
#  <Metabolite 4ppcys_c at 0x7fd2baa2cbb0>,
#  <Metabolite anth_c at 0x7fd2baa2cbe0>,
#  <Metabolite anth_e at 0x7fd2baa2cd00>,
#  <Metabolite 4hbzcoa_c at 0x7fd2baa2cc40>,
#  <Metabolite 3hibutcoa_c at 0x7fd2baa2cd90>,
#  <Metabolite fmettrna_c at 0x7fd2baa2cdc0>,
#  <Metabolite b5amp_c at 0x7fd2baa2cee0>,
#  <Metabolite phllqne_c at 0x7fd2baa2ce20>,
#  <Metabolite tglu_c at 0x7fd2baa2c940>,
#  <Metabolite pheborn_c at 0x7fd2baa2cf40>,
#  <Metabolite dmi1p_c at 0x7fd2baa2c850>,
#  <Metabolite gmhep1p_c at 0x7fd2baa2c3d0>,
#  <Metabolite mal__D_c at 0x7fd2baa38100>,
#  <Metabolite strcg_c at 0x7fd2baa380a0>,
#  <Metabolite 3php_c at 0x7fd2baa38070>,
#  <Metabolite M00673_c at 0x7fd2baa385b0>,
#  <Metabolite man6p_e at 0x7fd2baa38430>,
#  <Metabolite hisp_c at 0x7fd2baa38640>,
#  <Metabolite 2flrbz_c at 0x7fd2baa38670>,
#  <Metabolite mnl_e at 0x7fd2baa38850>,
#  <Metabolite 4flthr_c at 0x7fd2baa381c0>,
#  <Metabolite glx_e at 0x7fd2baa388e0>,
#  <Metabolite man6p_c at 0x7fd2baa386a0>,
#  <Metabolite 4flthr_e at 0x7fd2baa38ac0>,
#  <Metabolite glx_c at 0x7fd2baa38a30>,
#  <Metabolite 4hactph_c at 0x7fd2baa38e50>,
#  <Metabolite hmccm_c at 0x7fd2baa38d90>,
#  <Metabolite 2p1a_c at 0x7fd2baa38eb0>,
#  <Metabolite suchms_c at 0x7fd2baa38ee0>,
#  <Metabolite ru5p__D_c at 0x7fd2baa38fd0>,
#  <Metabolite ppi_c at 0x7fd2baa38f40>,
#  <Metabolite 5hoxindact_c at 0x7fd2baa38910>,
#  <Metabolite 3m4hpga_c at 0x7fd2baa41070>,
#  <Metabolite malthp_c at 0x7fd2baa410d0>,
#  <Metabolite naphmsuccoa_c at 0x7fd2baa41220>,
#  <Metabolite 3urdpp_c at 0x7fd2baa41310>,
#  <Metabolite 2mbcoa_c at 0x7fd2baa41250>,
#  <Metabolite dchrocmo_c at 0x7fd2baa41370>,
#  <Metabolite 2napthm_c at 0x7fd2baa413a0>,
#  <Metabolite ACP_c at 0x7fd2baa414c0>,
#  <Metabolite ccppc_c at 0x7fd2baa410a0>,
#  <Metabolite 4mop_c at 0x7fd2baa415e0>,
#  <Metabolite bbtcoa_c at 0x7fd2baa41490>,
#  <Metabolite amuco_c at 0x7fd2baa41640>,
#  <Metabolite malpyr_c at 0x7fd2baa41670>,
#  <Metabolite 6chq_c at 0x7fd2baa41a30>,
#  <Metabolite trdrd_c at 0x7fd2baa413d0>,
#  <Metabolite 3flrbz_c at 0x7fd2baa41ac0>,
#  ...]

# %%
############### ADDING NEW REACTIONS FOR Glycerolipid metabolism
################################################################
### glycerol + NADP+ = D-glyceraldehyde + NADPH + H+ [RN:R01041]

### Check for glycerol
print("###### check glycerol")
for metabolite in model.metabolites.query('glycerol', 'name'):
    print(metabolite.name)
### No direct glycerol pathway so far
#Add glycerol
EX_glycerol_e = Metabolite(id='EX_glycerol_e', compartment='e')

### Check for NADP+
print("###### check NADP+")
for metabolite in model.metabolites.query('nadp', 'name'):
    print(metabolite.name)
### No NADP+
### Found in model
print(model.metabolites.nadp_c)

### Check for D-glyceraldehyde
print("###### check D-glyceraldehyde")
for metabolite in model.metabolites.query('d-glyceraldehyde', 'name'):
    print(metabolite.name)
### No D-glyceraldehyde 
#add D-glyceraldehyde
glyceraldehyde_c = Metabolite(id='glyceraldehyde_c', compartment='c')

### Check for NADPH
print("###### check NADPH")
for metabolite in model.metabolites.query('nadph', 'name'):
    print(metabolite.name)
### NADPH not found
### NADPH found in model
print(model.metabolites.nadph_c)

### Check for  H+
print("###### check H+")
for metabolite in model.metabolites.query('h', 'name'):
    print(metabolite.name)
### H+ found
# Out:
# ###### check glycerol
# CDP-diacylglycerol
# D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate
# Triacylglycerol
# 1,2-Diacyl-sn-glycerol
# Phosphatidylglycerol
# Glycerophosphoglycerol
# 1-Acyl-sn-glycerol 3-phosphate
# 1-Acylglycerol
# C1-(3-Indolyl)-glycerol 3-phosphate
# ###### check NADP+
# nadp_c
# ###### check D-glyceraldehyde
# ###### check NADPH
# nadph_c
# ###### check H+
# (Z)-5-Oxohex-2-enedioate
# Acetyl phosphate
# Phenylacetyl-CoA
# 2-Hydroxy-3-methylbenzalpyruvate
# L-Methionyl-tRNA (Met)
# Selenophosphate
# heptadecanoic acid (C17:0)
# cis-2-Chloro-4-carboxymethylenebut-2-en-1,4-olide
# Phosphatidylserine
# Phenethylamine
# 2-Methylbut-2-enoyl-CoATiglyl-CoA
# 5-Chloro-2-hydroxymuconic semialdehyde
# Dihydrofolate
# Inorganic triphosphate
# 5'-Methylthioadenosine
# Thiocysteine
# 4-Nitrophenol
# Anthranilyl-CoA
# cis-3-(3-Carboxyethenyl)-3,5-cyclohexadiene-1,2-diol
# 4-(2-Aminophenyl)-2,4-dioxobutanoate
# D-Methionine
# D-Glucosamine 1-phosphate
# D-Xylulose 5-phosphate
# D-Methionine
# tRNA(Phe)
# branching glycogen
# N1-(alpha-D-ribosyl)-5,6-dimethylbenzimidazole
# 3,4-Dihydroxymandelaldehyde
# D-Glycero-D-manno-heptose 1,7-bisphosphate
# 4-Sulfocatechol
# Phosphatidylethanolamine
# Phenylacetaldehyde
# 2-Hydroxyhepta-2,4-dienedioate
# Glycerophosphoserine
# 1,6-Dihydroxy-cis-2,4-cyclohexadiene-1- carboxylic acid
# 1-Hydroxymethylnaphthalene
# 2-Amino-5-oxocyclohex-1-enecarbonyl-CoA
# methylisocitrate
# D-Erythrose 4-phosphate
# L-Rhamnose
# L-Rhamnose
# 4-Nitrophenyl phosphate
# 3-Phospho-D-glyceroyl phosphate
# O-Phospho-L-serine
# Betaine aldehyde
# D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate
# 5-Amino-6-(5'-phosphoribosylamino)uracil
# 1,4-Dihydroxy-2-naphthoate
# Dimethylallyl diphosphate
# lipopolisaccharide
# Glutathionylspermidine
# L-Glutamate 1-semialdehyde
# D-Glyceraldehyde 3-phosphate
# 1-(5'-Phosphoribosyl)-5-amino-4-imidazolecarboxamide
# Thiamin
# Thiamin
# Naphthyl-2-methyl-succinic acid
# CDP-4-dehydro-6-deoxy-D-glucose
# 2,6-Dichlorohydroquinone
# Thiamine diphosphate
# 2-Methylprop-2-enoyl-CoA
# 2-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 4-Chlorophenylacetate
# sn-Glycero-3-phosphoethanolamine
# hexadecenoate (n-C16:1)
# 3,4,6-Trichlorocatechol
# L-Phenylalanine
# Thiocyanate
# Choline phosphate
# L-Phenylalanine
# D-Glycerate 2-phosphate
# D-Glycerate 2-phosphate
# Presqualene diphosphate
# 1-Hydroxy-2-methyl-2-butenyl 4-diphosphate
# sn-Glycero-3-phospho-1-inositol
# 4-Amino-2-methyl-5-phosphomethylpyrimidine
# Dephospho-CoA
# Cyclohexanone
# L-Cystathionine
# 2-Dehydro-3-deoxy-D-glucarate
# Thymidine
# Porphobilinogen
# 5-Formyltetrahydrofolate
# Dihydropteroate
# 5,6-Dihydrothymine
# Thymidine
# Methylimidazole acetaldehyde
# 5-O-(1-Carboxyvinyl)-3-phosphoshikimate
# Imidazole-4-acetaldehyde
# 2-Hydroxy-2-hydropyrone-4,6-dicarboxylate
# Se-Adenosylselenomethionine
# 3-Fluorocatechol
# 2-Hydroxycyclohexan-1-one
# Protoporphyrin
# 4,6-Dihydroxyquinoline
# 3-Octaprenyl-4-hydroxybenzoate
# trans-2,3-Dihydroxycinnamate
# 2-Hydroxy-cis-hex-2,4-dienoate
# 3,4-Dihydroxyphenylethyleneglycol
# 5-Methyl-3-oxo-4-hexenoyl-CoA
# N-(5-Phospho-D-ribosyl)anthranilate
# Cyclohexylamine
# D-Fructose 1-phosphate
# cis-3-(Carboxy-ethyl)-3,5-cyclohexadiene-1,2-diol
# 1-(5-Phosphoribosyl)-AMP
# Shikimate
# phosphatidylcholine
# 5-Phospho-alpha-D-ribose
# beta-D-Fructose 2,6-bisphosphate
# Hydroxymethylbilane
# beta-D-Fructose 2-phosphate
# 4-Hydroxy-2-oxo-heptanedioate
# 1,2-Anthracenediol
# Phosphatidylglycerol
# 5-Methyltetrahydropteroyltri-L-glutamate
# 1-Methylnaphthalene
# Naphthalene-1,2-diol
# S-Adenosyl-4-methylthio-2-oxobutanoate
# P1,P4-Bis(5'-uridyl) tetraphosphate
# 4-Carboxy-2-hydroxymuconate semialdehyde
# 2,3,4,5-Tetrahydrodipicolinate
# Adenosyl cobinamide phosphate
# Sulfoacetaldehyde
# 1-(5-Phosphoribosyl)-ATP
# 2-Demethylmenaquinone
# 5-carboxyamino-1-(5-phospho-D-ribosyl)imidazole
# S-(2-Methylbutanoyl)-dihydrolipoamide-E
# 2-Amino-3-carboxymuconate semialdehyde
# 5-Formamido-1-(5-phospho-D-ribosyl)
# 6-Phospho-D-gluconate
# 5-Amino-6-(5'-phosphoribitylamino)uracil
# 2-Naphthoic acid
# Catechol
# Catechol
# 4-Methylsalicylate
# O-Acetylhomoserine
# O-Succinylhomoserine
# 4-Nitrocatechol
# 5,6-Dihydroxyindole
# 3-Deoxy-D-manno-octulosonate 8-phosphate
# UDP-2,3-bis(3-hydroxytetradecanoyl)glucosamine
# Glycerophosphoglycerol
# L-Aspartate 4-semialdehyde
# 3-Oxo-4-methylpentanoic acid
# Geranyl diphosphate
# Methylmalonate
# S-Ribosyl-L-homocysteine
# 4-Ethylphenol
# cis-hexadec-9-enoyl-[acyl-carrier protein]
# 2-Octaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinone
# S-Glutaryldihydrolipoamide
# 2-Octaprenyl-6-methoxyphenol
# (2E)-5-Methylhexa-2,4-dienoyl-CoA
# S-Formylglutathione
# 1-Acyl-sn-glycerol 3-phosphate
# Ethanolamine phosphate
# D-Mannose 1-phosphate
# Thiamin monophosphate
# Pyridoxamine 5'-phosphate
# Phosphate
# 4-(Trimethylammonio)but-2-enoate
# Indole-3-acetaldehyde
# Phenol
# Phenol
# 2,3,5-Trichloro-cis,cis-muconate
# Cyclohexane-1-carboxyl-CoA
# 3-Chloro-cis,cis-muconate
# Phosphate
# (R)-2,3-Dihydroxy-3-methylpentanoate
# Thiosulfate
# N-Acetyl-D-mannosamine 6-phosphate
# N-Acetyl-D-glucosamine 6-phosphate
# heptadecenoyl-ACP (C17:1 ACP)
# Thiosulfate
# L-1-Pyrroline-3-hydroxy-5-carboxylate
# Dihydrobiopterin
# alpha-Aminopropiononitrile
# 2-Hexaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinone
# 2,3-Dihydroxytoluene
# Uroporphyrinogen III
# 5-Carboxy-2-oxohept-3-enedioate
# 2-Chloro-4-hydroxy-6-amino-1,3,5-triazine
# all-trans-Hexaprenyl diphosphate
# Uroporphyrinogen I
# CDP-ethanolamine
# tRNA(Thr)
# 2-Ketocyclohexane-1-carboxyl-CoA
# Coproporphyrinogen I
# Sedoheptulose 7-phosphate
# Phenylacetonitrile
# Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutaminyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# 4-Methylcatechol
# carbohydrate
# Phosphatidate
# Galactitol 1-phosphate
# S-(2-Methylpropionyl)-dihydrolipoamide-E
# Naphthyl-2-methyl-succinyl-CoA
# 2-Hydroxycyclohexane-1-carboxyl-CoA
# D-Fructose 1,6-bisphosphate
# alpha-D-Ribose 5-phosphate
# 5-Methylcytosine
# Dihydroneopterin
# 1,2-Dihydroxynaphthalene-6-sulfonate
# 4-Carboxy-2-hydroxyhexa-2,4-dienedioate
# all-trans-Octaprenyl diphosphate
# D-Glucosamine 6-phosphate
# 4-Fluorocyclohexadiene-cis,cis-1,2-diol
# Chloride
# m-Methylbenzoate
# Chloride
# Gentisate aldehyde
# Selenocystathionine
# 2-Octaprenyl-3-methyl-6-methoxy-1,4-benzoquinone
# L-Dopachrome
# 3-Chloro-2-hydroxymuconic semialdehyde
# L-Threonyl-tRNA(Thr)
# 2-Methylnaphthalene
# 3-Methylcrotonyl-CoA
# Prephenate
# (S)-5-Oxo-2,5-dihydrofuran-2-acetate
# Poly-beta-hydroxybutyrate
# Poly-beta-hydroxybutyrate
# Maltohexaose
# (S)-5-Oxo-2,5-dihydrofuran-2-acetate
# Maltohexaose
# beta-Aminopropion aldehyde
# Aminoacetaldehyde
# 3-Carboxy-2-hydroxy-4-methylpentanoate
# Undecaprenyl diphosphate
# 2-C-methyl-D-erythritol 4-phosphate
# cis-4-Carboxymethylenebut-2-en-4-olide
# cis-3-Chloroacrylic acid
# L-Methionine
# Phenylacetylglycine
# (S)-3-Methyl-2-oxopentanoate
# (S)-Methylmalonyl-CoA
# L-Methionine
# 1,2-Dihydroxyfluorene
# 4-Hydroxy-2-oxohexanoic acid
# S-Adenosyl-L-methionine
# 5-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# Carbamoyl phosphate
# Fluoroacetaldehyde
# Formylanthranilate
# 2-Hydroxy-4-hydroxymethylbenzalpyruvate
# 5-Methylhex-4-enoyl-CoA
# N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole
# 5-[(5-Phospho-1-deoxyribulos-1-ylamino)methylideneamino]-1-(5-phosphoribosyl)imidazole-4-carboxamide
# 2,3,2'3'-Tetrakis(3-hydroxytetradecanoyl)-D-glucosaminyl-1,6-beta-D-glucosamine 1,4'-bisphosphate
# 2-Hydroxy-6-oxo-6-(2-hydroxyphenyl)-hexa-2,4-dienoate
# 3-Chlorocatechol
# 5-(2-Hydroxyethyl)-4-methylthiazole
# 3-Vinylcatechol
# 4-(Cytidine 5'-diphospho)-2-C-methyl-Derythritol
# Naphthyl-2-oxomethyl-succinyl-CoA
# S-Adenosyl-L-homocysteine
# 2-Dehydropantoate
# 6-Hydroxycyclohex-1-enecarbonyl-CoA
# 3-Hydroxy-2-naphthoate
# D-4'-Phosphopantothenate
# Acetaldehyde
# L-Ascorbate 6-phosphate
# Acetaldehyde
# Trehalose
# N6-(1,2-Dicarboxyethyl)-AMP
# cis-3-Chloro-2-propene-1-ol
# Selenomethionine
# Trehalose
# 2-Dehydro-3-deoxy-6-phospho-D-gluconate
# 2,5-Dihydroxybenzoate
# 2,5-Dihydroxybenzoate
# Bis(4'-chlorophenyl)methane
# N-Acetyl-D-glucosamine 1-phosphate
# 2,4,6-Trichlorophenol
# 6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# phospholipid
# 3-Methoxy-4-hydroxyphenylacetaldehyde
# 2-Deoxy-D-ribose 1-phosphate
# 6-Pyruvoyltetrahydropterin
# D-Sorbitol 6-phosphate
# 2-Dehydro-D-gluconate 6-phosphate
# Protoporphyrinogen IX
# 4-Hydroxyphenylacetyl-CoA
# Sirohydrochlorin
# Phenanthrene-9,10-oxide
# 2-Hydroxy-6-oxo-6-(2-hydroxyphenoxy)-hexa-2,4-dienoate
# (Z)-4-(2-Hydroxy-5-sulfonatophenyl)-2-oxo-3-butenoate
# P1,P4-Bis(5'-guanosyl) tetraphosphate
# (Z)-4-Hydroxyphenylacetaldehyde-oxime
# 2,2-Bis(4-hydroxyphenyl)-1-propanol
# 2-Phytyl-1,4-naphthoquinone
# GDP-4-dehydro-6-deoxy-D-mannose
# Anthracene-9,10-dihydrodiol
# L-4-Hydroxyglutamate semialdehyde
# Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# N-Succinyl-LL-2,6-diaminoheptanedioate
# N-Formyl-L-methionine
# 3-Hydroxybenzyl alcohol
# 5,10-Methenyltetrahydrofolate
# Phenanthracene
# Adenosine 3',5'-bisphosphate
# Phosphoenolpyruvate
# P1,P4-Bis(5'-xanthosyl) tetraphosphate
# 1-(4'-Hydroxyphenyl)ethanol
# Isopentenyl diphosphate
# D-Glucose 6-phosphate
# N-Acetyl-L-glutamate 5-semialdehyde
# 5-Phosphoribosylamine
# 6-Hydroxyhexanoic acid
# L-Tryptophanyl-tRNA(Trp)
# trans-3-Chloroacrylic acid
# D-erythro-3-Methylmalate
# 3-Methyl-2-oxobutanoate
# D-Glucose 6-phosphate
# 2-Hydroxy-6-oxo-6-(4'-chlorophenyl)-hexa-2,4-dienoate
# 6,7-Dimethyl-8-(1-D-ribityl)lumazine
# L-Glutamate 5-semialdehyde
# L-Phenylalanyl-tRNA(Phe)
# Phenylpropanoate
# 2,3-Dihydroxy 1,1,1-Trichloro-2,2-bis(4'-chlorophenyl)ethane
# Phenylpropanoate
# 3-Hydroxyphenylacetate
# 2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate
# 2-Oxo-5-methyl-cis-muconate
# (+)-cis-3,4-Dihydrophenanthrene-3,4-diol
# Thioredoxin disulfide
# S-Acetyldihydrolipoamide-E
# UDP-3-O-(3-hydroxytetradecanoyl)-N-acetylglucosamine
# 4-amino-4-deoxychorismate
# Adenosyl cobyrinate hexaamide
# hcl
# D-Tagatose 6-phosphate
# Reduced glutathione
# dTDP-4-dehydro-6-deoxy-L-mannose
# 3'-Phosphoadenylyl sulfate
# 2,5-Dichloro-4-oxohex-2-enedioate
# 3-Methoxytyramine
# 2-Naphthaldehyde
# 2-Chloro-3-oxoadipate
# 5,6,7,8-Tetrahydrofolate
# dTDP-L-rhamnose
# 4-Hydroxy-L-threonine
# 3-Carboxy-4-methyl-2-oxopentanoate
# 1,1-Dichloro-2-(dihydroxy-4'-chlorophenyl)-2-(4'-chlorophenyl)ethylene
# 3-Chloroallyl aldehyde
# D-Ribose 1,5-bisphosphate
# 2-Hydroxyisophthalic acid
# Glycerol 3-phosphate
# Glycerol 3-phosphate
# ADP-L-glycero-D-manno-heptose
# P1,P4-Bis(5'-adenosyl) tetraphosphate
# 4-Hydroxymethylsalicylate
# 1-(5-Phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino]imidazole-4-carboxamide
# 10-Formyltetrahydrofolate
# 4-Hydroxymethylcatechol
# 1-Hydroxy-2-naphthoate
# LL-2,6-Diaminoheptanedioate
# L-Ornithine
# N-Methylhistamine
# 3,4-Dihydroxyphenylacetate
# L-Ornithine
# 2-Methylcitrate
# all-trans-Heptaprenyl diphosphate
# Guanosine 3'-diphosphate 5'-triphosphate
# dihydrosirohydrochlorin
# Sorbose 1-phosphate
# L-Lactaldehyde
# 4-Amino-5-hydroxymethyl-2-methylpyrimidine
# Succinate semialdehyde-thiamin diphosphate anion
# 3-(3-Hydroxy-phenyl)-propanoic acid
# 3-(3-Hydroxy-phenyl)-propanoic acid
# 2-(Formamido)-N1-(5-phospho-D-ribosyl) acetamidine
# 3-Hydroxy-5-oxohexanoyl-CoA
# L-Threonine
# L-Threonine
# N2-Acetyl-L-ornithine
# Propanoyl phosphate
# (R)-2-Methylmalate
# 5-Methyltetrahydrofolate
# Glycolaldehyde
# 7-Methyl-3-oxo-6-octenoyl-CoA
# 2,3-Bis(3-hydroxytetradecanoyl)-beta-D-glucosaminyl 1-phosphate
# (+)-(3S,4R)-cis-3,4-Dihydroxy-3,4-dihydrofluorene
# D-1-Aminopropan-2-ol O-phosphate
# Dihydrolipoylprotein
# 5,10-Methylenetetrahydrofolate
# 2-Naphthoyl-CoA
# 4-Hydroxymethylsalicylaldehyde
# D-Lactaldehyde
# 2-Hydroxy-5-methyl-cis,cis-muconic semialdehyde
# 2,3,2',3'-Tetrakis(3-hydroxytetradecanoyl)-D-glucosaminyl-1,6-beta-D-glucosamine 1-phosphate
# 4-Methylthio-2-oxobutanoate
# L-Metanephrine
# Thioredoxin
# L-Normetanephrine
# 2-Methylpropanoyl-CoA
# 4-Phospho-L-aspartate
# 2-Hydroxy-4-(1-oxo-1,3-dihydro-2Hinden-2-ylidene)-but-2-enoic acid
# alpha-Oxo-benzeneacetic acid
# N-((R)-Pantothenoyl)-L-cysteine
# Dihydroneopterin phosphate
# (S)-3-Hydroxy-2-methylbutyryl-CoA
# L-Glutamate 5-phosphate
# L-erythro-4-Hydroxyglutamate
# 3-Phospho-D-glycerate
# 3-Phospho-D-glycerate
# 3-Methyl-cis,cis-hexadienedioate
# 2-Hydroxy-4-(2-oxo-1,3-dihydro-2Hinden-1-ylidene)but-2-enoic acid
# 4-Chlorobenzoate
# Thymine
# alpha-D-Ribose 1-phosphate
# 1-(2-Carboxyphenylamino)-1'-deoxy-D-ribulose 5'-phosphate
# Benzoyl phosphate
# 2,6-Dichlorophenol
# 5-Carboxymethyl-2-hydroxymuconate
# 1-Phenanthrol
# (R)-2,3-Dihydroxy-3-methylbutanoate
# 3-(2-Aminoethyl)-1H-indol-5-ol
# 2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate
# 2-Methylmaleate
# ph
# 1,2-Bis(4-hydroxyphenyl)-2-propanol
# alpha-Oxo-benzeneacetic acid
# D-Arabinose 5-phosphate
# Glycerone phosphate
# 2-Aminomuconate semialdehyde
# Malonate semialdehyde
# 1-deoxy-D-xylulose 5-phosphate
# Coproporphyrinogen III
# 2,5-Diamino-6-(5'-phosphoribosylamino)-4-pyrimidineone
# D-Mannitol 1-phosphate
# 4-Methylmuconolactone
# Succinic semialdehyde
# 2-Methylacetoacetyl-CoA
# 2,3-Bis(4-hydroxyphenyl)-1,2-propanediol
# 2-Hexaprenyl-3-methyl-6-methoxy-1,4-benzoquinone
# 1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate
# 5,6-Dihydrouracil
# 4-Hydroxybenzaldehyde
# S-(Hydroxymethyl)glutathione
# 1-(5'-Phosphoribosyl)-5-amino-4-(N-succinocarboxamide)-imidazole
# 5-(3'-Carboxy-3'-oxopropyl)-4,6-dihydroxypicolinate
# Ethanolamine
# 4,8-Dihydroxyquinoline
# 4-Hydroxyphenylacetate
# 4-Hydroxyphenylacetate
# 6-Oxo-2-hydroxy-7-(4'-chlorophenyl)-3,8,8-trichloroocta-2E,4E,7E-trienoate
# Se-Adenosylselenohomocysteine
# 2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl)dihydropteridine triphosphate
# 2-Hydroxy-6-oxo-6-phenylhexa-2,4-dienoate
# Phenylacetic acid
# Phenylacetic acid
# chorismate
# L-Fucose 1-phosphate
# (R)-S-Lactoylglutathione
# L-Fucose 1-phosphate
# O-Phospho-4-hydroxy-L-threonine
# 1-Oxa-2-oxo-3-hydroxycycloheptane
# N-Acetyl-L-glutamyl 5-phosphate
# 4-Chlorocatechol
# N-[(R)-4'-Phosphopantothenoyl]-L-cysteine
# Anthranilate
# Anthranilate
# N-Formylmethionyl-tRNA
# Phylloquinone
# Tetrahydropteroyltri-L-glutamate
# Phenylboronic acid
# Inositol 1-phosphate
# D-Glycero-D-manno-heptose 1-phosphate
# 3-Phosphohydroxypyruvate
# 2-Phenylacetamide
# D-Mannose 6-phosphate
# L-Histidinol phosphate
# 4-Fluoro-L-threonine
# D-Mannose 6-phosphate
# 4-Fluoro-L-threonine
# 4'-Hydroxyacetophenone
# 2-Hydroxy-5-methyl-cis,cis-muconate
# O-Succinyl-L-homoserine
# D-Ribulose 5-phosphate
# Diphosphate
# 5-Hydroxyindoleacetaldehyde
# 3-Methoxy-4-hydroxyphenylglycolaldehyde
# Celloheptaose
# Naphthyl-2-hydroxymethyl-succinyl CoA
# (S)-2-Methylbutanoyl-CoA
# 2,5-Dichloro-carboxymethylenebut-2-en-4-olide
# (2-Naphthyl)methanol
# 4-Methyl-2-oxopentanoate
# 6-Chlorohydroxyquinol
# Reduced thioredoxin
# 6-Chlorohydroxyquinol
# S-Adenosylmethioninamine
# 2-Amino-7,8-dihydro-4-hydroxy-6-(diphosphooxymethyl)pteridine
# 1-Naphthaldehyde
# Xanthosine 5'-phosphate
# Methylamine
# 4-(3-Hydroxy-2-naphthyl)-2-oxobut-3-enoic acid
# 5-Dehydro-4-deoxy-D-glucarate
# Ethylamine
# 3-(4-Hydroxyphenyl)pyruvate
# 2-Oxohept-3-enedioate
# Phenylpyruvate
# 3-Hydroxybenzaldehyde
# p-Tolualdehyde
# 3,4-dihydroxy-2-butanone 4-phosphate
# 3-Amino-2-oxopropyl phosphate
# alpha-Amino-gamma-cyanobutanoate
# 6-Carboxyhexanoate
# 2-Amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine
# N,N-Dimethylglycine
# O-Acetyl-L-homoserine
# (S)-3-Hydroxy-3-methylglutaryl-CoA
# trans-4-Carboxymethylenebut-2-en-4-olide
# Biphenyl-2,3-diol
# Biphenyl-2,3-diol
# (R)-Pantothenate
# 2-C-methyl-D-erythritol 2,4-cyclodiphosphate
# (R)-Pantothenate
# 4-Phospho-D-erythronate
# Bisphenol A
# dTDP-4-dehydro-6-deoxy-alpha-D-glucose
# Nicotinamide adenine dinucleotide phosphate
# 2-Octaprenyl-6-methoxy-1,4-benzoquinol
# Oxidized thioredoxin
# 4-Methyl-5-(2-phosphoethyl)-thiazole
# Orotidine 5'-phosphate
# D-Glycero-D-manno-heptose 7-phosphate
# Pantetheine 4'-phosphate
# Selenomethionyl-tRNA(Met)
# S-Aminomethyldihydrolipoylprotein
# 3-(2,3-Dihydroxyphenyl)propanoate
# (S)-Dihydroorotate
# 2-phospho-4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol
# 2-Oxo-3-hydroxy-4-phosphobutanoate
# 3-Methylbutanoyl-CoA
# 3-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 2-Hydroxymuconate semialdehyde
# 2,3-Dihydroxy-4'-chlorobiphenyl
# ADP-D-glycero-D-manno-heptose
# 4-Fluorocatechol
# 3-Methylsalicylaldehyde
# 6-Oxo-2-hydroxy-7-(4'-chlorophenyl)-3,8,8,8-tetrachloroocta-2E,4E-dienoate
# 2-Acyl-sn-glycero-3-phosphoethanolamine
# 3,4-Dihydroxyphenylacetaldehyde
# Dihydrolipoamide-E
# 6-phospho-D-glucono-1,5-lactone
# Chloroacetaldehyde
# 5'-Phosphoribosylglycinamide
# 3-Methylsalicylate
# Meso-2,6-Diaminoheptanedioate
# 3-Hydroxy-5-methylhex-4-enoyl-CoA
# Meso-2,6-Diaminoheptanedioate
# Bis(4'-chlorophenyl)acetate
# 2-Dehydro-3-deoxy-D-gluconate
# 2-Dehydro-3-deoxy-D-gluconate
# L-Tryptophan
# D-Glucose 1-phosphate
# L-Tryptophan
# UDP-3-O-(3-hydroxytetradecanoyl)-D-glucosamine
# 4-Carboxy-4-hydroxy-2-oxoadipate
# 2-Aminoacrylate Dehydroalanine
# cis-2,3-Dihydrodiol 1,1,1-Trichloro-2,2-bis(4'-chlorophenyl)ethane cis-2,3-Dihydrodiol
# Oxidized glutathione
# Naphthyl-2-methylene-succinyl-CoA
# 2-Phosphoglycolate
# 2-Hydroxyphenylacetate
# Choline
# Choline
# Xanthine
# 3,4-Dihydroxybenzoate
# Anthracene
# D-Phenylalanine
# Nicotinamide adenine dinucleotide phosphate -reduced
# 6-Carboxyhex-2-enoyl-CoA
# Xanthine
# Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-D-glutamylmeso-2,6-diaminopimeloyl-D-alanyl-D-alanine
# Methylglyoxal
# 3,4-Dihydroxybenzoate
# (R)-Methylmalonyl-CoA
# 2-Acyl-sn-glycero-3-phosphoserine
# S-(3-Methylbutanoyl)-dihydrolipoamide-E
# (S)-Methylmalonate semialdehyde
# 2-Carboxy-2,3-dihydro-5,6-dihydroxyindole
# D-Glyceraldehyde
# D-Glyceraldehyde
# 2,3-Dihydrodipicolinate
# Farnesyl diphosphate
# O-Phospho-L-homoserine
# 2,6-Dihydroxycyclohexane-1-carboxyl-CoA
# 4-Hydroxyphenylacetaldehyde
# 3-Hydroxyanthranilate
# sn-Glycero-3-phosphocholine
# 2-Hydroxyethylenedicarboxylate
# Phenanthrene-1,2-oxide
# cis-3-Chloroallyl aldehyde
# Pyridoxine 5'-phosphate
# (S)-2-Aceto-2-hydroxybutanoate
# 2-Chloro-cis,cis-muconate
# Ethanol
# 3,4-Dihydroxyfluorene
# 2-Chloromaleylacetate
# 2-Hydroxy-6-keto-2,4-heptadienoate
# Ethanol
# C1-(3-Indolyl)-glycerol 3-phosphate
# Selenohomocysteine
# 2-Octaprenyl-6-hydroxyphenol
# 2-Oxo-2,3-dihydrofuran-5-acetate
# cis-2-Methylaconitate
# 4-Hydroxyphenylglyoxylate
# heptadecanoyl-ACP (C17:0 ACP)
# 3-Carboxy-3-hydroxy-4-methylpentanoate
# 3'-Phosphoadenylylselenate
# N-Succinyl-2-L-amino-6-oxoheptanedioate
# 3-Dehydroshikimate
# 3-(Imidazol-4-yl)-2-oxopropyl phosphate
# Shikimate 5-phosphate
# 3-[6-(Carboxymethylene)cyclohexa-2,4-dien-1-ylidene]-2-oxopropanate
# 5-(3'-Carboxy-3'-oxopropenyl)-4,6-dihydroxypicolinate
# 2-Methylbenzaldehyde
# Benzaldehyde
# Benzaldehyde
# Chloroacetic acid
# Cyclohexane-1-carboxylate
# Dihydrolipoamide
# 3-Sulfocatechol
# 3-Dehydroquinate
# D-Fructose 6-phosphate
# Protoheme
# Tetrahydrobiopterin
# 2-Octaprenylphenol
# Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-D-glutaminyl-meso-2,6-diaminopimeloyl-(glycyl)5-D-alanyl-D-alanine
# Pyridoxal 5'-phosphate
# L-Allo-threonine
# 5,6-Dimethylbenzimidazole
# Xanthosine
# trans-3-Chloro-2-propene-1-ol
# alpha,alpha'-Trehalose 6-phosphate
# 2,4-Dihydroxyhept-2-enedioate
# Dethiobiotin
# Pantetheine
# 2-Amino-3-oxo-4-phosphonooxybutyrate
# Hypoxanthine
# 3-Methylbenzaldehyde
# Hypoxanthine
# Undecaprenyl phosphate
# 3-(2-Carboxyvinyl)naphthalene-2-carboxylic acid
# Guanosine 3',5'-bis(diphosphate)
# Phosphatidylglycerophosphate
# N2-Formyl-N1-(5-phospho-D-ribosyl) glycinamide
# Parathion
# N-Cyclohexylformamide
# 4-Hydroxyphenylacetylglycine
# Pseudouridine 5'-phosphate
# Xanthosine
# 2-Acyl-sn-glycero-3-phosphocholine
# 4-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# Ribulose-1,5-bisphosphate
# 4-Hydroxy-benzyl alcohol

# %%
## Add reaction glycerol dehydrogenase 
## Reaction: glycerol + NADP+ = D-glyceraldehyde + NADPH + H+ [RN:R01041]
Glycerol_dehydrogenase = Reaction('1.1.1.72') 
Glycerol_dehydrogenase.add_metabolites({EX_glycerol_e: -1,
                            model.metabolites.nadp_c: -1,
                            glyceraldehyde_c: 1,
                          model.metabolites.nadph_c: 1,
                            model.metabolites.h_c: 1, 
                              })
print(Glycerol_dehydrogenase.build_reaction_string())
# Out:
# EX_glycerol_e + nadp_c --> glyceraldehyde_c + h_c + nadph_c

# %%
### aldehyde + NAD+ + H2O = a carboxylate + NADH + H+

### Check for aldehyde
print("###### check aldehyde")
for metabolite in model.metabolites.query('aldehyde', 'name'):
    print(metabolite.name)
#not found
#add aldehyde
aldehyde_c = Metabolite(id='aldehyde_c ', compartment='c')

### Check for NAD+
print("###### check NAD+")
for metabolite in model.metabolites.query('nad', 'name'):
    print(metabolite.name)
#not found
#short cut in model?
print(model.metabolites.nad_c)

### Check for H2O
print("###### check H2O")
for metabolite in model.metabolites.query('H2O', 'name'):
    print(metabolite.name)
## found
## check name in model
print("model: ", model.metabolites.h2o_c)

### Check for NADH
print("###### check carboxylate")
for metabolite in model.metabolites.query('carboxylate', 'name'):
    print(metabolite.name)
## found
## check name in model
print("model: ", model.metabolites.carboxylate_c)

### Check for NADH
print("###### check NADH")
for metabolite in model.metabolites.query('nadh', 'name'):
    print(metabolite.name)
#not found
#short cut in model?
print(model.metabolites.nadh_c)

### Check for  H+
### H+ already found in glycerol dehydrogenase reaction
# Out:
# ###### check aldehyde
# 5-Chloro-2-hydroxymuconic semialdehyde
# 3,4-Dihydroxymandelaldehyde
# Phenylacetaldehyde
# Betaine aldehyde
# L-Glutamate 1-semialdehyde
# D-Glyceraldehyde 3-phosphate
# Methylimidazole acetaldehyde
# Imidazole-4-acetaldehyde
# 4-Carboxy-2-hydroxymuconate semialdehyde
# Sulfoacetaldehyde
# 2-Amino-3-carboxymuconate semialdehyde
# L-Aspartate 4-semialdehyde
# Indole-3-acetaldehyde
# Gentisate aldehyde
# 3-Chloro-2-hydroxymuconic semialdehyde
# beta-Aminopropion aldehyde
# Aminoacetaldehyde
# Fluoroacetaldehyde
# Acetaldehyde
# Acetaldehyde
# 3-Methoxy-4-hydroxyphenylacetaldehyde
# (Z)-4-Hydroxyphenylacetaldehyde-oxime
# L-4-Hydroxyglutamate semialdehyde
# N-Acetyl-L-glutamate 5-semialdehyde
# L-Glutamate 5-semialdehyde
# 2-Naphthaldehyde
# 3-Chloroallyl aldehyde
# L-Lactaldehyde
# Succinate semialdehyde-thiamin diphosphate anion
# Glycolaldehyde
# 4-Hydroxymethylsalicylaldehyde
# D-Lactaldehyde
# 2-Hydroxy-5-methyl-cis,cis-muconic semialdehyde
# 2-Aminomuconate semialdehyde
# Malonate semialdehyde
# Succinic semialdehyde
# 4-Hydroxybenzaldehyde
# 5-Hydroxyindoleacetaldehyde
# 3-Methoxy-4-hydroxyphenylglycolaldehyde
# 1-Naphthaldehyde
# 3-Hydroxybenzaldehyde
# p-Tolualdehyde
# 2-Hydroxymuconate semialdehyde
# 3-Methylsalicylaldehyde
# 3,4-Dihydroxyphenylacetaldehyde
# Chloroacetaldehyde
# (S)-Methylmalonate semialdehyde
# D-Glyceraldehyde
# D-Glyceraldehyde
# 4-Hydroxyphenylacetaldehyde
# cis-3-Chloroallyl aldehyde
# 2-Methylbenzaldehyde
# Benzaldehyde
# Benzaldehyde
# 3-Methylbenzaldehyde
# ###### check NAD+
# nonadecanoic acid (C19:0)
# nonadecanoyl-ACP (C19:0 ACP)
# nad_c
# ###### check H2O
# H2O
# H2O
# H2O2
# model:  h2o_c
# ###### check carboxylate
# 2-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 2-Hydroxy-2-hydropyrone-4,6-dicarboxylate
# Urea-1-carboxylate
# L-1-Pyrroline-3-hydroxy-5-carboxylate
# 5-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# (E)-4-Oxobut-1-ene-1,2,4-tricarboxylate
# 1-Pyrroline-5-carboxylate
# carboxylate
# 2-Pyrone-4,6-dicarboxylate
# 1-(5-Phospho-D-ribosyl)-5-amino-4-imidazolecarboxylate
# Cyclopropanecarboxylate
# 3-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# 1-Aminocyclopropane-1-carboxylate
# 2-Hydroxyethylenedicarboxylate
# 5-Amino-4-imidazole carboxylate
# Cyclohexane-1-carboxylate
# 4-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate
# model:  carboxylate_c
# ###### check NADH
# nadh_c

# %%
## Add reaction glycerol dehydrogenase 
## Reaction: aldehyde + NAD+ + H2O = carboxylate + NADH + H+
Oxidoreductase = Reaction('1.2.1.3') 
Oxidoreductase.add_metabolites({aldehyde_c: -1,
                            model.metabolites.nad_c: -1,
                            model.metabolites.h2o_c: -1,
                          model.metabolites.carboxylate_c: 1,
                            model.metabolites.nadh_c: 1, 
                              model.metabolites.h_c: 1,
                              })
print(Oxidoreductase.build_reaction_string())
# Out:
# aldehyde_c  + h2o_c + nad_c --> carboxylate_c + h_c + nadh_c

# %%
### ATP + D-glycerate = ADP + 3-phospho-D-glycerate

### Check for ATP
print("###### check ATP")
for metabolite in model.metabolites.query('atp', 'name'):
    print(metabolite.name)
# found
## check name in model
print(model.metabolites.atp_c)

### Check for glycerate
print("###### check glycerate")
for metabolite in model.metabolites.query('glycerate', 'name'):
    print(metabolite.name)
# not found
# add new
glycerate_c = Metabolite(id='glycerate_c', compartment='c')

### Check for ADP
print("###### check ADP")
for metabolite in model.metabolites.query('ADP', 'name'):
    print(metabolite.name)
## found
## check name in model
print("model: ", model.metabolites.adp_c)

### Check for 3-phospho-D-glycerate
print("###### check 3-phospho-D-glycerate")
for metabolite in model.metabolites.query('3-phospho-D-glycerate', 'name'):
    print(metabolite.name)
##found in glycerate search
## check name in model
#model.metabolites.get_by_id('3gp_c')
#model.metabolites.3gp_c
#the wanted metabolite check 3-phospho-D-glycerate could be found as 3PG_c in the model through model.metabolites but no futher informations could be 
#gained with the two specific commands model.metabolites.get_by_id('3gp_c') and model.metabolites.3gp_c
#The website https://www.ebi.ac.uk/pdbe-srv/pdbechem/chemicalCompound/show/3PG also refers that the 3PG shortcut ist the right one.
#Forced solution -> add 3-phospho-D-glycerate as a new metabolite
new_3pg_c = Metabolite(id='new_3pg_c', compartment='c')
# Out:
# ###### check ATP
# atp_c
# ###### check glycerate
# 3-Phospho-D-glycerate
# 3-Phospho-D-glycerate
# ###### check ADP
# ADP-D-ribose
# dADP
# ADP-L-glycero-D-manno-heptose
# ADP-D-glycero-D-manno-heptose
# ADP
# model:  adp_c
# ###### check 3-phospho-D-glycerate

# %%
## Add reaction gTransferases 
## ATP + D-glycerate = ADP + 3-phospho-D-glycerate
Transferases = Reaction('2.7.1.31')  
Transferases.add_metabolites({model.metabolites.atp_c: -1,
                            glycerate_c: -1,
                            model.metabolites.adp_c: 1,
                            new_3pg_c: 1
                              })
print(Transferases.build_reaction_string())
# Out:
# atp_c + glycerate_c --> adp_c + new_3pg_c

# %%
####################################
#### What is the maximum production rate of PHB growing on fructose
medium = model.medium
medium
# Out:
# {'EX_fe2_e': 10.0,
#  'EX_mg2_e': 10.0,
#  'EX_pi_e': 100.0,
#  'EX_cobalt2_e': 10.0,
#  'EX_cl_e': 10.0,
#  'EX_k_e': 10.0,
#  'EX_fe3_e': 10.0,
#  'EX_so4_e': 10.0,
#  'EX_fru_e': 3.0,
#  'EX_nh4_e': 10.0,
#  'EX_na_e': 10.0,
#  'EX_o2_e': 18.5,
#  'EX_mobd_e': 10.0,
#  'EX_h2o_e': 1000.0,
#  'EX_h_e': 100.0}

# %%
#### with only fructose as C-source
with model:
    medium = model.medium
    medium ['EX_fru_e'] = 10
    model.medium = medium
    print(medium)
    model.objective = model.reactions.EX_pbhb_e
    phb_production_fru = model.optimize().objective_value
    print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_fru)
    print("Theoretical max. yield [mmol-phb / mmol-fru]:", phb_production_fru / (-1*model.reactions.EX_fru_e.flux))
# Out:
# {'EX_fe2_e': 10.0, 'EX_mg2_e': 10.0, 'EX_pi_e': 100.0, 'EX_cobalt2_e': 10.0, 'EX_cl_e': 10.0, 'EX_k_e': 10.0, 'EX_fe3_e': 10.0, 'EX_so4_e': 10.0, 'EX_fru_e': 10, 'EX_nh4_e': 10.0, 'EX_na_e': 10.0, 'EX_o2_e': 18.5, 'EX_mobd_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 100.0}
# Max. phb production [mmol gDW^-1 h^-1]: 12.542372881355933
# Theoretical max. yield [mmol-succ / mmol-ac]: 1.2542372881355932

# %%
#### with only glycerol as C-source 
medium = model.medium
print(medium)
## adding glyercol to media, switching off fructose intake
medium ["EX_glycerol_e"] = 10
medium ['EX_fru_e'] = 0
print(medium)
model.objective = model.reactions.EX_pbhb_e
phb_production_gly = model.optimize().objective_value
print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_gly)
print("Theoretical max. yield [mmol-phb / mmol-phb]:", phb_production_gly / (-1*model.reactions.EX_glycerol_e.flux))
# Out:
# {'EX_fe2_e': 10.0, 'EX_mg2_e': 10.0, 'EX_pi_e': 100.0, 'EX_cobalt2_e': 10.0, 'EX_cl_e': 10.0, 'EX_k_e': 10.0, 'EX_fe3_e': 10.0, 'EX_so4_e': 10.0, 'EX_fru_e': 3.0, 'EX_nh4_e': 10.0, 'EX_na_e': 10.0, 'EX_o2_e': 18.5, 'EX_mobd_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 100.0}
# {'EX_fe2_e': 10.0, 'EX_mg2_e': 10.0, 'EX_pi_e': 100.0, 'EX_cobalt2_e': 10.0, 'EX_cl_e': 10.0, 'EX_k_e': 10.0, 'EX_fe3_e': 10.0, 'EX_so4_e': 10.0, 'EX_fru_e': 0, 'EX_nh4_e': 10.0, 'EX_na_e': 10.0, 'EX_o2_e': 18.5, 'EX_mobd_e': 10.0, 'EX_h2o_e': 1000.0, 'EX_h_e': 100.0, 'EX_glycerol_e': 10}
# Max. phb production [mmol gDW^-1 h^-1]: 3.76271186440678
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/cobra/core/dictlist.py in __getattr__(self, attr)
#     451         try:
# --> 452             return DictList.get_by_id(self, attr)
#     453         except KeyError:
#
# /opt/anaconda3/lib/python3.8/site-packages/cobra/core/dictlist.py in get_by_id(self, id)
#      56         """return the element with a matching id"""
# ---> 57         return list.__getitem__(self, self._dict[id])
#      58
#
# KeyError: 'EX_glycerol_e'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-8f3e34b4425c> in <module>
#       9 phb_production_gly = model.optimize().objective_value
#      10 print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_gly)
# ---> 11 print("Theoretical max. yield [mmol-phb / mmol-phb]:", phb_production_gly / (-1*model.reactions.EX_glycerol_e.flux))
#      12
#
# /opt/anaconda3/lib/python3.8/site-packages/cobra/core/dictlist.py in __getattr__(self, attr)
#     452             return DictList.get_by_id(self, attr)
#     453         except KeyError:
# --> 454             raise AttributeError("DictList has no attribute or entry %s" % attr)
#     455
#     456     def __dir__(self):
#
# AttributeError: DictList has no attribute or entry EX_glycerol_e

# %%
### This code doesnt work for some reason ... 
# with model:
#    medium = model.medium
 #   medium ['EX_fru_e'] = 0
  #  medium ['EX_glycerol_e'] = 10
  #  model.medium = medium
  #  print(medium)
  #  model.objective = model.reactions.EX_pbhb_e
  #  phb_production_fru = model.optimize().objective_value
  #  print("Max. phb production [mmol gDW^-1 h^-1]:", phb_production_fru)
  #  print("Theoretical max. yield [mmol-succ / mmol-ac]:", phb_production_fru / (-1*model.reactions.EX_fru_e.flux))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-154-c4466f83a23a> in <module>
#       3     medium ['EX_fru_e'] = 0
#       4     medium ['EX_glycerol_e'] = 10
# ----> 5     model.medium = medium
#       6     print(medium)
#       7     model.objective = model.reactions.EX_pbhb_e
#
# /opt/anaconda3/lib/python3.8/site-packages/cobra/core/model.py in medium(self, medium)
#     277         exchange_rxns = frozenset(self.exchanges)
#     278         for rxn_id, bound in medium.items():
# --> 279             rxn = self.reactions.get_by_id(rxn_id)
#     280             if rxn not in exchange_rxns:
#     281                 logger.warn(
#
# /opt/anaconda3/lib/python3.8/site-packages/cobra/core/dictlist.py in get_by_id(self, id)
#      55     def get_by_id(self, id):
#      56         """return the element with a matching id"""
# ---> 57         return list.__getitem__(self, self._dict[id])
#      58
#      59     def list_attr(self, attribute):
#
# KeyError: 'EX_glycerol_e'
